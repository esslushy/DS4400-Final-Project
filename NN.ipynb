# %%
import numpy as np
import pandas as pd
import torch
from torch import nn
from torch.utils.data import DataLoader, TensorDataset
from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import mean_squared_error, r2_score
from utils import gather_data, mean_squared_percentage_error

# %% [markdown]
# # NN Model for regression
# The goal of this model is to build and try a few variances of basic neural networks to see if they can outperform the other regression models.

# %%
x_train, x_test, y_train, y_test = gather_data()
y_train, y_test = np.reshape(y_train, (-1, 1)), np.reshape(y_test, (-1, 1))
kfold = KFold(n_splits=10, shuffle=True)
# Out:
# Index(['Log GDP per capita', 'Social support',
#        'Healthy life expectancy at birth', 'Freedom to make life choices',
#        'Generosity', 'Perceptions of corruption', 'Positive affect',
#        'Negative affect', 'Confidence in national government'],
#       dtype='object')

# %%
class NeuralNetwork(nn.Module):
    """
      Represents a Neural Network that can be constructed with a vartiety of hidden layers.
    """
    def __init__(self, input_size, num_hidden_layers, num_nodes_per_layer):
        """
          Initializes a neural network with the specified parameters

          Args:
            input_size: The size of the input feature vector
            num_hidden_layers: The number of hidden layers in the neural network
            num_nodes_per_layer: The number of nodes in each hidden layer
        """
        super().__init__()
        # Start with intialized first layer
        hidden_layers = [nn.Linear(input_size, num_nodes_per_layer)]
        for _ in range(num_hidden_layers):
            hidden_layers.append(nn.Linear(num_nodes_per_layer, num_nodes_per_layer))
            hidden_layers.append(nn.ReLU())
        self.layers = nn.Sequential(*hidden_layers, nn.Linear(num_nodes_per_layer, 1))

    def forward(self, x):
        """
          Feeds x forward through the neural network to get the prediction

          Args:
            x: The feature vector to get the prediction from
        """
        return self.layers(x)

# %%
# The following 2 functions were built with assistance from the torch documentation which has similar functions provided.
def train_loop(dataloader, model, lr=1e-5, num_epochs=200, momentum=0.9, weight_decay: float=None, loss_fn=nn.MSELoss(), early_stopping: int=None):
    """
      Runs the training loop for the model.

      Args:
        dataloader: the dataloader containing the training data
        model: the model to optimize
        lr: The learning rate for the model
        num_epochs: the number of times to repeat the training loop
        momentum: The momentum for SGD
        weight_decay: The amount of weight decay for SGD
        loss_fn: the loss function to optimize
        early_stopping: how many rounds of having a loss that doesn't improve before stopping
    """
    model_dict = {}
    best_model = {}
    best_loss = np.inf
    kept_for = 1
    optimizer = torch.optim.SGD(model.parameters(), lr=lr, momentum=momentum, weight_decay=weight_decay)
    for epoch in range(num_epochs):
        total_loss = 0
        for batch, (X, y) in enumerate(dataloader):
            # Compute prediction and loss
            pred = model(X)
            loss = loss_fn(pred, y)
            total_loss += loss.item()

            # Store model dict for early stopping
            if early_stopping:
                model_dict = model.state_dict()

            # Backpropagation
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
        
        total_loss /= len(dataloader)

        if early_stopping:
            # Determine if we should stop early
            if best_loss < total_loss:
                kept_for += 1
                if kept_for >= early_stopping:
                    model.load_state_dict(best_model)
                    return 
            else:
                best_model = model_dict
                best_loss = total_loss
                kept_for = 1


def test_loop(dataloader, model, result):
    """
      Runs the test loop for the model and outputs the result to the given dictionary

      Args:
        dataloader: The data for the model to be validated on
        model: The model to test
        result: The result dictionary to store the data in.
    """
    num_batches = len(dataloader)
    test_loss, test_r2, test_mspe = 0, 0, 0
    loss_fn = nn.MSELoss()

    with torch.no_grad():
        for X, y in dataloader:
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            test_r2 += r2_score(y.numpy(), pred.numpy())
            test_mspe += mean_squared_percentage_error(y.numpy(), pred.numpy())

    result["MSE"].append(test_loss / num_batches)
    result["R2"].append(test_r2 / num_batches)
    result["MSPE"].append(test_mspe / num_batches)

# %%
results = []
for num_hidden_layers in range(1, 3):
    for num_nodes_per_layer in [8, 16, 32, 64]:
        for lr in [1e-5, 1e-4, 1e-3]:
            for momentum in [.9, .99]:
                for weight_decay in [1e-5, 1e-4, 1e-3, .01, .1, .5]:
                    result = {
                        "num_hidden_layers": num_hidden_layers,
                        "num_nodes_per_layer": num_nodes_per_layer,
                        "lr": lr,
                        "momentum": momentum,
                        "weight_decay": weight_decay,
                        "MSE": [],
                        "R2": [],
                        "MSPE": []
                    }
                    for train_index, val_index in kfold.split(x_train, y_train):
                        train_dataset = DataLoader(TensorDataset(torch.Tensor(x_train[train_index]), torch.Tensor(y_train[train_index])), batch_size=64, shuffle=True)
                        val_dataset= DataLoader(TensorDataset(torch.Tensor(x_train[val_index]), torch.Tensor(y_train[val_index])), batch_size=64, shuffle=True)
                        model = NeuralNetwork(len(x_train[0]), num_hidden_layers=num_hidden_layers, num_nodes_per_layer=num_nodes_per_layer)
                        train_loop(train_dataset, model, lr=lr, momentum=momentum, weight_decay=weight_decay, early_stopping=25)
                        test_loop(val_dataset, model, result)            
                    result["MSE"] = np.mean(result["MSE"])
                    result["R2"] = np.mean(result["R2"])
                    result["MSPE"] = np.mean(result["MSPE"])
                    results.append(result)

# %%
results
# Out:
# [{'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.8046819478273392,
#   'R2': 0.34763551720241426,
#   'MSPE': 3.771036384119229},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 1.4261133939027786,
#   'R2': -0.23667380788148956,
#   'MSPE': 5.350006940501808},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.7884099960327149,
#   'R2': 0.3406578970787604,
#   'MSPE': 3.5839888511808837},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 1.5571848889191944,
#   'R2': -0.42851338252561905,
#   'MSPE': 5.767024894329635},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.7609119981527328,
#   'R2': 0.37364844944431547,
#   'MSPE': 3.271357686437591},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.7766244073708852,
#   'R2': 0.352499664357543,
#   'MSPE': 3.2318039330644437},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.4580639272928238,
#   'R2': 0.6463213943823407,
#   'MSPE': 2.244615399495068},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.3207131542265415,
#   'R2': 0.6858280997847683,
#   'MSPE': 1.6108115433216696},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.3428394183516502,
#   'R2': 0.6857758617319475,
#   'MSPE': 1.5714781204558381},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.32578085809946056,
#   'R2': 0.7387106020021166,
#   'MSPE': 1.5925965381955556},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.42294648140668867,
#   'R2': 0.6368230805122973,
#   'MSPE': 1.9817832273177125},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.8018698086341223,
#   'R2': 0.39985268054886214,
#   'MSPE': 2.983895656323493},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.40701107879479725,
#   'R2': 0.6816063849265316,
#   'MSPE': 1.9458640933112066},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.32570230687658,
#   'R2': 0.7406219460809139,
#   'MSPE': 1.6638479567123483},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.301581592609485,
#   'R2': 0.7191805621646381,
#   'MSPE': 1.3893991297186175},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.42091026082634936,
#   'R2': 0.6454984438828945,
#   'MSPE': 2.248904811208974},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.33911447674036027,
#   'R2': 0.7143458227897446,
#   'MSPE': 1.617351107562732},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.4693078269561132,
#   'R2': 0.6127319650857052,
#   'MSPE': 2.0609021711755884},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.39669587711493176,
#   'R2': 0.6584855183730132,
#   'MSPE': 1.7429199287987718},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.28052083080013596,
#   'R2': 0.7631980751657655,
#   'MSPE': 1.3309412636803557},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.2854095108807087,
#   'R2': 0.7472531374957483,
#   'MSPE': 1.3710817583657877},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.2900302519400914,
#   'R2': 0.7386128693360737,
#   'MSPE': 1.3558030700442767},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.3147691036264102,
#   'R2': 0.7521456736788413,
#   'MSPE': 1.5921549734687717},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.4696594496568044,
#   'R2': 0.6003510195305075,
#   'MSPE': 2.0737936787984586},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.3057296549280485,
#   'R2': 0.7465556917860043,
#   'MSPE': 1.5178161887734223},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.2701714506993691,
#   'R2': 0.7724022216504816,
#   'MSPE': 1.2498147051894306},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.3050552725791931,
#   'R2': 0.7382295806167927,
#   'MSPE': 1.5237317143026927},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.29959845095872883,
#   'R2': 0.755002066203448,
#   'MSPE': 1.4820209400013389},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.31896253426869714,
#   'R2': 0.7544302171192638,
#   'MSPE': 1.5645382786640014},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.47301637530326834,
#   'R2': 0.5861308526436014,
#   'MSPE': 2.287342112624284},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.43456242779890697,
#   'R2': 0.6471823555277996,
#   'MSPE': 2.132036470798681},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.4965823868910471,
#   'R2': 0.5674684111365924,
#   'MSPE': 2.2437920688529207},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.4052308087547621,
#   'R2': 0.6431814903607909,
#   'MSPE': 2.0085343990399678},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.40740660081307095,
#   'R2': 0.6616086104425692,
#   'MSPE': 1.9149898747076293},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.3361511247853438,
#   'R2': 0.7296370140973172,
#   'MSPE': 1.7322524684961096},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.5595552911361059,
#   'R2': 0.5335283545409533,
#   'MSPE': 2.1884556673467155},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.7321577429771423,
#   'R2': 0.37899834526148407,
#   'MSPE': 3.4462248121924475},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.795024515191714,
#   'R2': 0.37512444683669227,
#   'MSPE': 3.8875875992681643},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.74337490995725,
#   'R2': 0.3781786475254221,
#   'MSPE': 3.3200526542284265},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.7067976161837578,
#   'R2': 0.4356806323755812,
#   'MSPE': 3.2571776365541454},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.7198036223649978,
#   'R2': 0.3951639420694761,
#   'MSPE': 3.159189906272322},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.7270329574743906,
#   'R2': 0.4054924469472268,
#   'MSPE': 3.069029330003141},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.31164803554614384,
#   'R2': 0.7324485029478034,
#   'MSPE': 1.6303079930896107},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.30224890634417534,
#   'R2': 0.7373426440215207,
#   'MSPE': 1.447865774459911},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.3162519514560699,
#   'R2': 0.7147117179237705,
#   'MSPE': 1.6486027118081996},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.31169603019952774,
#   'R2': 0.7480692357397752,
#   'MSPE': 1.5379705959272503},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.3488908270994822,
#   'R2': 0.7245920625637896,
#   'MSPE': 1.735878710663228},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.45569897045691815,
#   'R2': 0.5708791728287508,
#   'MSPE': 2.086306002856505},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.3202879180510839,
#   'R2': 0.7426281661735624,
#   'MSPE': 1.6286859048455202},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.29808829724788666,
#   'R2': 0.7442244642331144,
#   'MSPE': 1.4387864314697005},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.3221177610258261,
#   'R2': 0.7441370741225632,
#   'MSPE': 1.5753460126091736},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.2844589531421661,
#   'R2': 0.7303690535787102,
#   'MSPE': 1.403850654629294},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.3399405946334203,
#   'R2': 0.7320954059019639,
#   'MSPE': 1.6951421548546564},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.4881463920076688,
#   'R2': 0.6120196064298408,
#   'MSPE': 2.1939800449204863},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.2828984588384628,
#   'R2': 0.7656919258621573,
#   'MSPE': 1.342074780235763},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.28394837478796636,
#   'R2': 0.7618639125641585,
#   'MSPE': 1.3146029863826403},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.27262885322173436,
#   'R2': 0.7753747591414729,
#   'MSPE': 1.3216610293308593},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.3039009963472684,
#   'R2': 0.731265807891269,
#   'MSPE': 1.4275465541603887},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.3157940189043681,
#   'R2': 0.7279405774758979,
#   'MSPE': 1.5114993258200662},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.45733098586400345,
#   'R2': 0.6209737347578032,
#   'MSPE': 2.145817239270216},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.2857156798243523,
#   'R2': 0.7655792917640386,
#   'MSPE': 1.409967006513416},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.32186693797508875,
#   'R2': 0.7302868761066663,
#   'MSPE': 1.5192307918473626},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.28911879460016887,
#   'R2': 0.7658302526252914,
#   'MSPE': 1.4053520458665762},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.2932273437579473,
#   'R2': 0.7582697909646134,
#   'MSPE': 1.508405674625226},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.32580290536085765,
#   'R2': 0.7244202986929046,
#   'MSPE': 1.6243572501616197},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.5009004970391591,
#   'R2': 0.5997235533130001,
#   'MSPE': 2.383906312352705},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.3063514269888401,
#   'R2': 0.7414177608445687,
#   'MSPE': 1.5522064992010294},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.2742079591999452,
#   'R2': 0.7617086712300564,
#   'MSPE': 1.2616658736152027},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.2971463975807031,
#   'R2': 0.7518072850986235,
#   'MSPE': 1.4317002071237022},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.5902757396300634,
#   'R2': 0.4680975365627832,
#   'MSPE': 2.6814222197528137},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.3262254158655803,
#   'R2': 0.7338182129460368,
#   'MSPE': 1.5210190185844294},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.5988756070534389,
#   'R2': 0.49491550465845313,
#   'MSPE': 2.2196322441514993},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.7143402735392252,
#   'R2': 0.4045664483672781,
#   'MSPE': 3.2838487369243543},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.7116963237524032,
#   'R2': 0.41626072638885814,
#   'MSPE': 3.2348299382085144},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.6802943219741187,
#   'R2': 0.45015518366974466,
#   'MSPE': 3.1480546860080776},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.7633090337117513,
#   'R2': 0.3522384167228705,
#   'MSPE': 3.5990070075624514},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.6888804654280345,
#   'R2': 0.42631525615287763,
#   'MSPE': 3.3205002448474517},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.7316540032625198,
#   'R2': 0.4146101300233342,
#   'MSPE': 3.0786743997172876},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.30876171042521794,
#   'R2': 0.7191360595173596,
#   'MSPE': 1.4641079402556925},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.30703732371330256,
#   'R2': 0.7385951935504653,
#   'MSPE': 1.5384141470992354},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.30132128099600475,
#   'R2': 0.7283054121991104,
#   'MSPE': 1.3818066333881533},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.2913438297808171,
#   'R2': 0.730020189066927,
#   'MSPE': 1.3863150598575371},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.32139673282702763,
#   'R2': 0.6952797304401077,
#   'MSPE': 1.5943713181398134},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.46982141137123107,
#   'R2': 0.6241175683923789,
#   'MSPE': 2.097026105744369},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.3055987243851026,
#   'R2': 0.7501585723917837,
#   'MSPE': 1.4416105136501067},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.29804965356985724,
#   'R2': 0.7510431916614554,
#   'MSPE': 1.422743240107942},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.29809957047303515,
#   'R2': 0.7346836962864306,
#   'MSPE': 1.4835317847742275},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.31438754114011924,
#   'R2': 0.7284515727414467,
#   'MSPE': 1.4692271754352584},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.3184248499572277,
#   'R2': 0.7476109413718908,
#   'MSPE': 1.53630249583247},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.49718992710113535,
#   'R2': 0.5992883667910032,
#   'MSPE': 2.321458625503712},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.2701086868842443,
#   'R2': 0.7675814454331265,
#   'MSPE': 1.2818159008718502},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.3011696455379328,
#   'R2': 0.7414091337095917,
#   'MSPE': 1.4740491647160412},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.28590907057126363,
#   'R2': 0.7720820820929257,
#   'MSPE': 1.400239457272821},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.285283200442791,
#   'R2': 0.7685300595324469,
#   'MSPE': 1.4846753492725617},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.29285027484099074,
#   'R2': 0.751372990791583,
#   'MSPE': 1.4371134190246313},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.4484357153375943,
#   'R2': 0.5999541185816251,
#   'MSPE': 2.0347064390138847},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.3063746144374212,
#   'R2': 0.7698008491914352,
#   'MSPE': 1.6636396459106244},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.29738730217019715,
#   'R2': 0.7444303308151022,
#   'MSPE': 1.3976835204532954},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.3019757941365242,
#   'R2': 0.7330431909430773,
#   'MSPE': 1.435192728866682},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.3036412345866362,
#   'R2': 0.7073295063150192,
#   'MSPE': 1.3734716733428414},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.30933704227209097,
#   'R2': 0.7484575552441473,
#   'MSPE': 1.4792749073092986},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.46249540597200384,
#   'R2': 0.6084430056225855,
#   'MSPE': 2.183877476443997},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.28663414071003596,
#   'R2': 0.7508857076129231,
#   'MSPE': 1.3946011926828308},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.2760957404971123,
#   'R2': 0.7700012797818497,
#   'MSPE': 1.344015406576371},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.30907107392946875,
#   'R2': 0.7306159394059576,
#   'MSPE': 1.4077338930031265},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.323433680832386,
#   'R2': 0.741592961176393,
#   'MSPE': 1.5860844988639307},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.3172490971783797,
#   'R2': 0.7105744335883376,
#   'MSPE': 1.4952277902494928},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.48901947736740115,
#   'R2': 0.5181861056124694,
#   'MSPE': 1.952419856262177},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.6233192880948385,
#   'R2': 0.49337840499244867,
#   'MSPE': 2.9168577189322074},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.6366543908913931,
#   'R2': 0.4402697257809951,
#   'MSPE': 3.054164462732245},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.5855660140514374,
#   'R2': 0.5130741371097534,
#   'MSPE': 2.6507362294377703},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.5811252653598785,
#   'R2': 0.5225904724387834,
#   'MSPE': 2.696721887761595},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.6454357286294301,
#   'R2': 0.4559505081445619,
#   'MSPE': 2.8219560729433786},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.7099032054344814,
#   'R2': 0.44092670250802507,
#   'MSPE': 3.054600968166734},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.3107700382669767,
#   'R2': 0.7279943665068671,
#   'MSPE': 1.4943245330806634},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.2862506702542305,
#   'R2': 0.7453588320801364,
#   'MSPE': 1.366624967712495},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.28138675677279623,
#   'R2': 0.7666675770372209,
#   'MSPE': 1.3309277397476964},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.27877845068772633,
#   'R2': 0.7577206289773029,
#   'MSPE': 1.3200904116636576},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.32309020062287647,
#   'R2': 0.7414497883885703,
#   'MSPE': 1.5641427835016841},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.4929511696100234,
#   'R2': 0.5923470077260566,
#   'MSPE': 2.094625401207142},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.30678469588359203,
#   'R2': 0.7491730297628304,
#   'MSPE': 1.442997432454969},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.2901854420701663,
#   'R2': 0.7602467650459418,
#   'MSPE': 1.483079937446599},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.28891860470175745,
#   'R2': 0.7636587703606674,
#   'MSPE': 1.3271995606559395},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.2935001882414022,
#   'R2': 0.7611523349394596,
#   'MSPE': 1.6445251292727814},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.305199383944273,
#   'R2': 0.7094027225148583,
#   'MSPE': 1.4207450421809247},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.47058441241582233,
#   'R2': 0.623729476800739,
#   'MSPE': 2.1686529370043615},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.2931299388408661,
#   'R2': 0.738517498327705,
#   'MSPE': 1.4415623295600668},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.27650429680943495,
#   'R2': 0.7552349726402896,
#   'MSPE': 1.2884063166895448},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.2659540211160977,
#   'R2': 0.7875701399335296,
#   'MSPE': 1.2628805374895984},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.2970339857041836,
#   'R2': 0.7448096641612149,
#   'MSPE': 1.3586607153969583},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.3096777086456617,
#   'R2': 0.735410433723162,
#   'MSPE': 1.5146497239575092},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.4741609325011572,
#   'R2': 0.609041771178805,
#   'MSPE': 2.056237105092015},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.2970277066032092,
#   'R2': 0.7687562175860554,
#   'MSPE': 1.5210727605065613},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.28306309680143993,
#   'R2': 0.7594442792670018,
#   'MSPE': 1.3169096422503994},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.30655971070130666,
#   'R2': 0.7224974597048556,
#   'MSPE': 1.4165122987646044},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.306726070245107,
#   'R2': 0.7394917809562366,
#   'MSPE': 1.4890070351762603},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.29800939162572226,
#   'R2': 0.7567885505694874,
#   'MSPE': 1.487556938505308},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.4573798194527626,
#   'R2': 0.6417705304831214,
#   'MSPE': 2.0679461169573994},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.27771709437171616,
#   'R2': 0.7731474083363532,
#   'MSPE': 1.3440811744599477},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.32374111662308375,
#   'R2': 0.7315964199322768,
#   'MSPE': 1.5223442402320226},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.3821804374456406,
#   'R2': 0.6769095553001864,
#   'MSPE': 1.9145492100241512},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.3255614325404167,
#   'R2': 0.7264920298680533,
#   'MSPE': 1.5627552415573536},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.3464759801824887,
#   'R2': 0.7023066814270286,
#   'MSPE': 1.6602414858649777},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.5421309143304824,
#   'R2': 0.5576411583989968,
#   'MSPE': 2.19191822844247},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 1.70338940123717,
#   'R2': -0.47291708225112883,
#   'MSPE': 6.1881377655222565},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.8758482327063879,
#   'R2': 0.23702679976681934,
#   'MSPE': 4.030155866698484},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.9785157740116117,
#   'R2': 0.24463289385376838,
#   'MSPE': 4.546570850705558},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.8537915180126827,
#   'R2': 0.3194690102389506,
#   'MSPE': 4.065237345945354},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.9427325000365574,
#   'R2': 0.23675419182753438,
#   'MSPE': 4.0149702748867},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 1.070193841556708,
#   'R2': 0.12369233203256318,
#   'MSPE': 4.705663178153712},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.4387373785177867,
#   'R2': 0.6462632087122048,
#   'MSPE': 2.174942226318473},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.3102067862947782,
#   'R2': 0.7552196644930099,
#   'MSPE': 1.5133830532431602},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.339585346231858,
#   'R2': 0.7310666186123533,
#   'MSPE': 1.670065804412871},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.3475327879190445,
#   'R2': 0.689062685034764,
#   'MSPE': 1.725951230548548},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.34230918884277345,
#   'R2': 0.7095533916790269,
#   'MSPE': 1.6483376025589127},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.49044708261887227,
#   'R2': 0.6112483737488814,
#   'MSPE': 2.2553056577277},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.293012747168541,
#   'R2': 0.7525666933004171,
#   'MSPE': 1.4017921126438209},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.40984787320097293,
#   'R2': 0.6590275914172754,
#   'MSPE': 2.0839897940179917},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.3135146841406823,
#   'R2': 0.7321032925146033,
#   'MSPE': 1.5567602765172568},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.5099107809364797,
#   'R2': 0.5850428762935564,
#   'MSPE': 2.383384641560942},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.4050854469339053,
#   'R2': 0.6455568228297532,
#   'MSPE': 1.7388754814035363},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.4981608162323634,
#   'R2': 0.6088494544670615,
#   'MSPE': 2.5362458449760172},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.39025857448577883,
#   'R2': 0.6701660990931135,
#   'MSPE': 2.0210781026481075},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.4137391671538353,
#   'R2': 0.6644008390843253,
#   'MSPE': 2.0571454005748633},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.39924181426564853,
#   'R2': 0.6215185580996,
#   'MSPE': 1.871907556137879},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.35126411244273187,
#   'R2': 0.6599094264954389,
#   'MSPE': 1.601572631660736},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.3936870125432809,
#   'R2': 0.6742235584898957,
#   'MSPE': 1.7999012661966105},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.6579618304967881,
#   'R2': 0.48215786895522805,
#   'MSPE': 2.7552013865888414},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.2683252053956191,
#   'R2': 0.781133175751445,
#   'MSPE': 1.33553878968638},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.3790283938248952,
#   'R2': 0.6791856477821457,
#   'MSPE': 1.700506027919626},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.3913320444524288,
#   'R2': 0.6848116828105384,
#   'MSPE': 1.735252153053127},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.2945609101404747,
#   'R2': 0.7581607855097204,
#   'MSPE': 1.462303837196845},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.2838497705757618,
#   'R2': 0.7586636440699847,
#   'MSPE': 1.3277152743228158},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.4577199588219325,
#   'R2': 0.6267610328956763,
#   'MSPE': 2.2015021764908473},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.837553956111272,
#   'R2': 0.3528842410811862,
#   'MSPE': 3.972851618597604},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.6783444029589494,
#   'R2': 0.45460162686760164,
#   'MSPE': 3.1020253190695484},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 1.0503747021158536,
#   'R2': 0.08237050758990053,
#   'MSPE': 4.5848071389841},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.7929367984334628,
#   'R2': 0.33751683191543874,
#   'MSPE': 3.6450674492075583},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.38167179351051644,
#   'R2': 0.689271616288041,
#   'MSPE': 1.7118185631592162},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.5275795911749205,
#   'R2': 0.5898078732088645,
#   'MSPE': 2.3756546224232276},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.8810886243979136,
#   'R2': 0.2750301108903451,
#   'MSPE': 4.057619753811094},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 1.4293131480614345,
#   'R2': -0.08108060775247869,
#   'MSPE': 5.126514029548024},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.8491518080234528,
#   'R2': 0.32455044463531196,
#   'MSPE': 4.170355060786912},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.8755255669355393,
#   'R2': 0.26933561553508273,
#   'MSPE': 4.030890702599226},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.785671063264211,
#   'R2': 0.36766120838754845,
#   'MSPE': 3.6133409024338525},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.8176035592953363,
#   'R2': 0.33700247477856954,
#   'MSPE': 3.5976458361579318},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.2886240541934967,
#   'R2': 0.7713206999579391,
#   'MSPE': 1.3568708797766251},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.30691883613665905,
#   'R2': 0.748034869805321,
#   'MSPE': 1.490795724752425},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.3294544930259387,
#   'R2': 0.7223967310708777,
#   'MSPE': 1.521671483989316},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.3231601441899935,
#   'R2': 0.7456219724926606,
#   'MSPE': 1.6831438156841982},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.3420684650540352,
#   'R2': 0.6983209265592293,
#   'MSPE': 1.8159470327123248},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.49260960817337035,
#   'R2': 0.5757742956150744,
#   'MSPE': 2.2746214343968667},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.2839125593503316,
#   'R2': 0.7660542467233357,
#   'MSPE': 1.365333257167779},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.3011649745206038,
#   'R2': 0.7550887720274072,
#   'MSPE': 1.4949559568041804},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.3125985577702522,
#   'R2': 0.746245987102933,
#   'MSPE': 1.5948692590675573},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.3156060511867205,
#   'R2': 0.729655003968416,
#   'MSPE': 1.501683071537903},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.3257886258264383,
#   'R2': 0.7110558692143876,
#   'MSPE': 1.6458391319170143},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.4654302150011064,
#   'R2': 0.6061080483357089,
#   'MSPE': 2.2223442394963717},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.2687787239750226,
#   'R2': 0.7475403730353554,
#   'MSPE': 1.3387889265920025},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.27915878246227893,
#   'R2': 0.7702640836568168,
#   'MSPE': 1.4591968341288393},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.338270478695631,
#   'R2': 0.7142226549448337,
#   'MSPE': 1.6397832656711941},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.2668776656190554,
#   'R2': 0.7717525660630101,
#   'MSPE': 1.2808782509481065},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.2905648584167163,
#   'R2': 0.7583875406417575,
#   'MSPE': 1.4032028415099238},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.4090263441205025,
#   'R2': 0.649583475308236,
#   'MSPE': 1.8661480445903957},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.26467016339302063,
#   'R2': 0.7643958141920992,
#   'MSPE': 1.2903357558704986},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.287049222489198,
#   'R2': 0.7643211756476292,
#   'MSPE': 1.314894831363074},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.27973109508554134,
#   'R2': 0.7770405683170807,
#   'MSPE': 1.3850216955097037},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.29483144829670593,
#   'R2': 0.7435798598765969,
#   'MSPE': 1.3790731894962414},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.2793135104080041,
#   'R2': 0.7476025629834054,
#   'MSPE': 1.398713333494585},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.4669870937863986,
#   'R2': 0.6283533330965978,
#   'MSPE': 2.160619841418182},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.6295161023736001,
#   'R2': 0.5154377223218922,
#   'MSPE': 2.9057270069277346},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.7804000724107027,
#   'R2': 0.36348338380981976,
#   'MSPE': 3.8970253395499896},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.6112553442517916,
#   'R2': 0.504864061336489,
#   'MSPE': 2.6893515092781692},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.6739076487720013,
#   'R2': 0.4361712765051526,
#   'MSPE': 3.043935703057231},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.36161629706621173,
#   'R2': 0.7043259373793054,
#   'MSPE': 1.588793062990663},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.5087670519948005,
#   'R2': 0.5866904249114289,
#   'MSPE': 2.1995255610708035},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.7100109438101451,
#   'R2': 0.41795219374493026,
#   'MSPE': 3.2639610206689498},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.802851163347562,
#   'R2': 0.36137380468100844,
#   'MSPE': 3.8489597783696774},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.7553568055232367,
#   'R2': 0.3747606209897963,
#   'MSPE': 3.6528808523834955},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.744245939453443,
#   'R2': 0.37783515920006105,
#   'MSPE': 3.7014935024534212},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.7593959838151932,
#   'R2': 0.33384219480610033,
#   'MSPE': 3.3163804363346463},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.7565789361794788,
#   'R2': 0.35370417585231584,
#   'MSPE': 3.38726157510672},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.29059302036960916,
#   'R2': 0.7658357826815975,
#   'MSPE': 1.4017653223033053},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.29004320402940115,
#   'R2': 0.7573302354117868,
#   'MSPE': 1.4129554660934391},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.3016414061188698,
#   'R2': 0.7476705723573431,
#   'MSPE': 1.4402837377756534},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.31771987403432533,
#   'R2': 0.7365721477964355,
#   'MSPE': 1.753196823457726},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.3184104964137077,
#   'R2': 0.7405656686349475,
#   'MSPE': 1.5457717943089928},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.46856830765803653,
#   'R2': 0.6124403283249463,
#   'MSPE': 2.116515745568757},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.3068160697817802,
#   'R2': 0.7149214253010631,
#   'MSPE': 1.3815610691190068},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.2947303819159667,
#   'R2': 0.7573228804924137,
#   'MSPE': 1.5032956150896621},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.2961413582166036,
#   'R2': 0.7558400617998846,
#   'MSPE': 1.4414253737307106},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.28289652963479356,
#   'R2': 0.769966381352592,
#   'MSPE': 1.3489437160656008},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.3113459294040998,
#   'R2': 0.736610386219532,
#   'MSPE': 1.50541365494707},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.43853646218776704,
#   'R2': 0.6432799696997316,
#   'MSPE': 1.9698524494852983},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.2788675072292487,
#   'R2': 0.7441072231031569,
#   'MSPE': 1.3650393172759903},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.26192603980501494,
#   'R2': 0.7840488091012527,
#   'MSPE': 1.278309210702175},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.2573568854480982,
#   'R2': 0.7742094559465296,
#   'MSPE': 1.2011611699644063},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.2716555374364058,
#   'R2': 0.7547897085066195,
#   'MSPE': 1.2830500392186823},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.283641820649306,
#   'R2': 0.7697979375127535,
#   'MSPE': 1.3761548802839836},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.42199152534206713,
#   'R2': 0.659227362470222,
#   'MSPE': 1.9873604967701017},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.2847877122461796,
#   'R2': 0.7574637634396447,
#   'MSPE': 1.3683910891789979},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.2871061035742362,
#   'R2': 0.7564079288347496,
#   'MSPE': 1.3055660236965527},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.289659483730793,
#   'R2': 0.7538615971420044,
#   'MSPE': 1.4194856285390378},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.29416299040118854,
#   'R2': 0.753079965137591,
#   'MSPE': 1.340702503562124},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.28369835317134856,
#   'R2': 0.7675258954073765,
#   'MSPE': 1.4146540591474432},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.4680981447299321,
#   'R2': 0.6135456160508824,
#   'MSPE': 2.191920078387766},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.3174202928940455,
#   'R2': 0.7338203177544851,
#   'MSPE': 1.5124730607776933},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.3755549396077792,
#   'R2': 0.6857304480094539,
#   'MSPE': 1.890811685830204},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.5597652663787207,
#   'R2': 0.5168827625982334,
#   'MSPE': 2.772944884638142},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.287770106146733,
#   'R2': 0.752034921699868,
#   'MSPE': 1.3980653285133566},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.33434134026368456,
#   'R2': 0.7002174105720755,
#   'MSPE': 1.562856284882685},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.47894795536994933,
#   'R2': 0.5900330999344627,
#   'MSPE': 2.1849286204410925},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.6812298665444055,
#   'R2': 0.4441704679965808,
#   'MSPE': 3.2736201753670513},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.6541336248318355,
#   'R2': 0.48890211874728867,
#   'MSPE': 3.113813009677511},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.716734528541565,
#   'R2': 0.42382196646139086,
#   'MSPE': 3.5718742487105453},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.6560829321543376,
#   'R2': 0.4375196026745881,
#   'MSPE': 3.0343102163287123},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.6903640737136205,
#   'R2': 0.4108711828817178,
#   'MSPE': 3.197234385938506},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.7052330613136292,
#   'R2': 0.4200672400441345,
#   'MSPE': 3.1528860575171427},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.2909860653181871,
#   'R2': 0.7366231239587042,
#   'MSPE': 1.3602257350629026},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.29805129418770465,
#   'R2': 0.7582370445535211,
#   'MSPE': 1.5736234633985793},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.2831756293773651,
#   'R2': 0.7601948130915678,
#   'MSPE': 1.3127151053549364},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.30174675608674684,
#   'R2': 0.7582158907938296,
#   'MSPE': 1.542001466991173},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.3218226631482442,
#   'R2': 0.7338237526750068,
#   'MSPE': 1.7101223007634736},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.47997005879879007,
#   'R2': 0.6091915643815485,
#   'MSPE': 2.4412595186232013},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.2954651186863581,
#   'R2': 0.7621060333196289,
#   'MSPE': 1.4061157153260828},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.27643521924813585,
#   'R2': 0.7514258080401663,
#   'MSPE': 1.2601008959998836},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.2909766634305318,
#   'R2': 0.7285189087348153,
#   'MSPE': 1.3537219467789234},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.30904592908918854,
#   'R2': 0.7438777607812087,
#   'MSPE': 1.4755487665439948},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.3179098444680373,
#   'R2': 0.7407267642257352,
#   'MSPE': 1.6134991905078142},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.44927145838737487,
#   'R2': 0.6211452715191439,
#   'MSPE': 1.9362556644611888},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.2694628993670146,
#   'R2': 0.7834700641480017,
#   'MSPE': 1.576514458095636},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.27981958190600076,
#   'R2': 0.7476499881184745,
#   'MSPE': 1.3060571519526267},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.2929982036352158,
#   'R2': 0.7712772678452937,
#   'MSPE': 1.5619800236038486},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.27762194598714507,
#   'R2': 0.7777265254069123,
#   'MSPE': 1.31659697487273},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.29272496228416756,
#   'R2': 0.7517223064604683,
#   'MSPE': 1.4130836349883764},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.4247353355089823,
#   'R2': 0.6438731771788577,
#   'MSPE': 1.8559166137129068},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.28550436571240423,
#   'R2': 0.76180877415016,
#   'MSPE': 1.4469689241318842},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.25703807870546974,
#   'R2': 0.7872408391806608,
#   'MSPE': 1.2496729673949458},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.2819469066957633,
#   'R2': 0.7382811798126898,
#   'MSPE': 1.2455763148538994},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.2885672464966774,
#   'R2': 0.7556449716208775,
#   'MSPE': 1.3516653835246661},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.3092898721496264,
#   'R2': 0.7471726271409846,
#   'MSPE': 1.5037617529507237},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.4262605766455332,
#   'R2': 0.6492857088299023,
#   'MSPE': 1.9630374922181921},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.26158651411533357,
#   'R2': 0.7831063026963083,
#   'MSPE': 1.2136999431132065},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.2589205980300903,
#   'R2': 0.786697878032885,
#   'MSPE': 1.2418141310112645},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.3964436421791713,
#   'R2': 0.6898106069875948,
#   'MSPE': 1.9802270353197902},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.31069954484701157,
#   'R2': 0.7468686993381527,
#   'MSPE': 1.6326531886377118},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.33046677584449446,
#   'R2': 0.7343112177610099,
#   'MSPE': 1.6137833524532994},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.5177862495183945,
#   'R2': 0.5447295716037244,
#   'MSPE': 2.1102100229737433}]

# %%
import json
with open("nn_results.json", "wt") as f:
    json.dump(results, f)

# %%
# Sort by lowest MSE
sorted(results, key=lambda x: x["MSE"])
# Out:
# [{'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.25703807870546974,
#   'R2': 0.7872408391806608,
#   'MSPE': 1.2496729673949458},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.2573568854480982,
#   'R2': 0.7742094559465296,
#   'MSPE': 1.2011611699644063},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.2589205980300903,
#   'R2': 0.786697878032885,
#   'MSPE': 1.2418141310112645},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.26158651411533357,
#   'R2': 0.7831063026963083,
#   'MSPE': 1.2136999431132065},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.26192603980501494,
#   'R2': 0.7840488091012527,
#   'MSPE': 1.278309210702175},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.26467016339302063,
#   'R2': 0.7643958141920992,
#   'MSPE': 1.2903357558704986},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.2659540211160977,
#   'R2': 0.7875701399335296,
#   'MSPE': 1.2628805374895984},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.2668776656190554,
#   'R2': 0.7717525660630101,
#   'MSPE': 1.2808782509481065},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.2683252053956191,
#   'R2': 0.781133175751445,
#   'MSPE': 1.33553878968638},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.2687787239750226,
#   'R2': 0.7475403730353554,
#   'MSPE': 1.3387889265920025},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.2694628993670146,
#   'R2': 0.7834700641480017,
#   'MSPE': 1.576514458095636},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.2701086868842443,
#   'R2': 0.7675814454331265,
#   'MSPE': 1.2818159008718502},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.2701714506993691,
#   'R2': 0.7724022216504816,
#   'MSPE': 1.2498147051894306},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.2716555374364058,
#   'R2': 0.7547897085066195,
#   'MSPE': 1.2830500392186823},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.27262885322173436,
#   'R2': 0.7753747591414729,
#   'MSPE': 1.3216610293308593},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.2742079591999452,
#   'R2': 0.7617086712300564,
#   'MSPE': 1.2616658736152027},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.2760957404971123,
#   'R2': 0.7700012797818497,
#   'MSPE': 1.344015406576371},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.27643521924813585,
#   'R2': 0.7514258080401663,
#   'MSPE': 1.2601008959998836},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.27650429680943495,
#   'R2': 0.7552349726402896,
#   'MSPE': 1.2884063166895448},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.27762194598714507,
#   'R2': 0.7777265254069123,
#   'MSPE': 1.31659697487273},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.27771709437171616,
#   'R2': 0.7731474083363532,
#   'MSPE': 1.3440811744599477},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.27877845068772633,
#   'R2': 0.7577206289773029,
#   'MSPE': 1.3200904116636576},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.2788675072292487,
#   'R2': 0.7441072231031569,
#   'MSPE': 1.3650393172759903},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.27915878246227893,
#   'R2': 0.7702640836568168,
#   'MSPE': 1.4591968341288393},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.2793135104080041,
#   'R2': 0.7476025629834054,
#   'MSPE': 1.398713333494585},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.27973109508554134,
#   'R2': 0.7770405683170807,
#   'MSPE': 1.3850216955097037},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.27981958190600076,
#   'R2': 0.7476499881184745,
#   'MSPE': 1.3060571519526267},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.28052083080013596,
#   'R2': 0.7631980751657655,
#   'MSPE': 1.3309412636803557},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.28138675677279623,
#   'R2': 0.7666675770372209,
#   'MSPE': 1.3309277397476964},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.2819469066957633,
#   'R2': 0.7382811798126898,
#   'MSPE': 1.2455763148538994},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.28289652963479356,
#   'R2': 0.769966381352592,
#   'MSPE': 1.3489437160656008},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.2828984588384628,
#   'R2': 0.7656919258621573,
#   'MSPE': 1.342074780235763},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.28306309680143993,
#   'R2': 0.7594442792670018,
#   'MSPE': 1.3169096422503994},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.2831756293773651,
#   'R2': 0.7601948130915678,
#   'MSPE': 1.3127151053549364},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.283641820649306,
#   'R2': 0.7697979375127535,
#   'MSPE': 1.3761548802839836},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.28369835317134856,
#   'R2': 0.7675258954073765,
#   'MSPE': 1.4146540591474432},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.2838497705757618,
#   'R2': 0.7586636440699847,
#   'MSPE': 1.3277152743228158},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.2839125593503316,
#   'R2': 0.7660542467233357,
#   'MSPE': 1.365333257167779},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.28394837478796636,
#   'R2': 0.7618639125641585,
#   'MSPE': 1.3146029863826403},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.2844589531421661,
#   'R2': 0.7303690535787102,
#   'MSPE': 1.403850654629294},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.2847877122461796,
#   'R2': 0.7574637634396447,
#   'MSPE': 1.3683910891789979},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.285283200442791,
#   'R2': 0.7685300595324469,
#   'MSPE': 1.4846753492725617},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.2854095108807087,
#   'R2': 0.7472531374957483,
#   'MSPE': 1.3710817583657877},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.28550436571240423,
#   'R2': 0.76180877415016,
#   'MSPE': 1.4469689241318842},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.2857156798243523,
#   'R2': 0.7655792917640386,
#   'MSPE': 1.409967006513416},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.28590907057126363,
#   'R2': 0.7720820820929257,
#   'MSPE': 1.400239457272821},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.2862506702542305,
#   'R2': 0.7453588320801364,
#   'MSPE': 1.366624967712495},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.28663414071003596,
#   'R2': 0.7508857076129231,
#   'MSPE': 1.3946011926828308},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.287049222489198,
#   'R2': 0.7643211756476292,
#   'MSPE': 1.314894831363074},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.2871061035742362,
#   'R2': 0.7564079288347496,
#   'MSPE': 1.3055660236965527},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.287770106146733,
#   'R2': 0.752034921699868,
#   'MSPE': 1.3980653285133566},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.2885672464966774,
#   'R2': 0.7556449716208775,
#   'MSPE': 1.3516653835246661},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.2886240541934967,
#   'R2': 0.7713206999579391,
#   'MSPE': 1.3568708797766251},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.28891860470175745,
#   'R2': 0.7636587703606674,
#   'MSPE': 1.3271995606559395},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.28911879460016887,
#   'R2': 0.7658302526252914,
#   'MSPE': 1.4053520458665762},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.289659483730793,
#   'R2': 0.7538615971420044,
#   'MSPE': 1.4194856285390378},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.2900302519400914,
#   'R2': 0.7386128693360737,
#   'MSPE': 1.3558030700442767},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.29004320402940115,
#   'R2': 0.7573302354117868,
#   'MSPE': 1.4129554660934391},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.2901854420701663,
#   'R2': 0.7602467650459418,
#   'MSPE': 1.483079937446599},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.2905648584167163,
#   'R2': 0.7583875406417575,
#   'MSPE': 1.4032028415099238},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.29059302036960916,
#   'R2': 0.7658357826815975,
#   'MSPE': 1.4017653223033053},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.2909766634305318,
#   'R2': 0.7285189087348153,
#   'MSPE': 1.3537219467789234},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.2909860653181871,
#   'R2': 0.7366231239587042,
#   'MSPE': 1.3602257350629026},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.2913438297808171,
#   'R2': 0.730020189066927,
#   'MSPE': 1.3863150598575371},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.29272496228416756,
#   'R2': 0.7517223064604683,
#   'MSPE': 1.4130836349883764},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.29285027484099074,
#   'R2': 0.751372990791583,
#   'MSPE': 1.4371134190246313},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.2929982036352158,
#   'R2': 0.7712772678452937,
#   'MSPE': 1.5619800236038486},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.293012747168541,
#   'R2': 0.7525666933004171,
#   'MSPE': 1.4017921126438209},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.2931299388408661,
#   'R2': 0.738517498327705,
#   'MSPE': 1.4415623295600668},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.2932273437579473,
#   'R2': 0.7582697909646134,
#   'MSPE': 1.508405674625226},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.2935001882414022,
#   'R2': 0.7611523349394596,
#   'MSPE': 1.6445251292727814},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.29416299040118854,
#   'R2': 0.753079965137591,
#   'MSPE': 1.340702503562124},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.2945609101404747,
#   'R2': 0.7581607855097204,
#   'MSPE': 1.462303837196845},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.2947303819159667,
#   'R2': 0.7573228804924137,
#   'MSPE': 1.5032956150896621},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.29483144829670593,
#   'R2': 0.7435798598765969,
#   'MSPE': 1.3790731894962414},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.2954651186863581,
#   'R2': 0.7621060333196289,
#   'MSPE': 1.4061157153260828},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.2961413582166036,
#   'R2': 0.7558400617998846,
#   'MSPE': 1.4414253737307106},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.2970277066032092,
#   'R2': 0.7687562175860554,
#   'MSPE': 1.5210727605065613},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.2970339857041836,
#   'R2': 0.7448096641612149,
#   'MSPE': 1.3586607153969583},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.2971463975807031,
#   'R2': 0.7518072850986235,
#   'MSPE': 1.4317002071237022},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.29738730217019715,
#   'R2': 0.7444303308151022,
#   'MSPE': 1.3976835204532954},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.29800939162572226,
#   'R2': 0.7567885505694874,
#   'MSPE': 1.487556938505308},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.29804965356985724,
#   'R2': 0.7510431916614554,
#   'MSPE': 1.422743240107942},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.29805129418770465,
#   'R2': 0.7582370445535211,
#   'MSPE': 1.5736234633985793},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.29808829724788666,
#   'R2': 0.7442244642331144,
#   'MSPE': 1.4387864314697005},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.29809957047303515,
#   'R2': 0.7346836962864306,
#   'MSPE': 1.4835317847742275},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.29959845095872883,
#   'R2': 0.755002066203448,
#   'MSPE': 1.4820209400013389},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.3011649745206038,
#   'R2': 0.7550887720274072,
#   'MSPE': 1.4949559568041804},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.3011696455379328,
#   'R2': 0.7414091337095917,
#   'MSPE': 1.4740491647160412},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.30132128099600475,
#   'R2': 0.7283054121991104,
#   'MSPE': 1.3818066333881533},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.301581592609485,
#   'R2': 0.7191805621646381,
#   'MSPE': 1.3893991297186175},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.3016414061188698,
#   'R2': 0.7476705723573431,
#   'MSPE': 1.4402837377756534},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.30174675608674684,
#   'R2': 0.7582158907938296,
#   'MSPE': 1.542001466991173},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.3019757941365242,
#   'R2': 0.7330431909430773,
#   'MSPE': 1.435192728866682},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.30224890634417534,
#   'R2': 0.7373426440215207,
#   'MSPE': 1.447865774459911},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.3036412345866362,
#   'R2': 0.7073295063150192,
#   'MSPE': 1.3734716733428414},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.3039009963472684,
#   'R2': 0.731265807891269,
#   'MSPE': 1.4275465541603887},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.3050552725791931,
#   'R2': 0.7382295806167927,
#   'MSPE': 1.5237317143026927},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.305199383944273,
#   'R2': 0.7094027225148583,
#   'MSPE': 1.4207450421809247},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.3055987243851026,
#   'R2': 0.7501585723917837,
#   'MSPE': 1.4416105136501067},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.3057296549280485,
#   'R2': 0.7465556917860043,
#   'MSPE': 1.5178161887734223},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.3063514269888401,
#   'R2': 0.7414177608445687,
#   'MSPE': 1.5522064992010294},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.3063746144374212,
#   'R2': 0.7698008491914352,
#   'MSPE': 1.6636396459106244},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.30655971070130666,
#   'R2': 0.7224974597048556,
#   'MSPE': 1.4165122987646044},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.306726070245107,
#   'R2': 0.7394917809562366,
#   'MSPE': 1.4890070351762603},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.30678469588359203,
#   'R2': 0.7491730297628304,
#   'MSPE': 1.442997432454969},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.3068160697817802,
#   'R2': 0.7149214253010631,
#   'MSPE': 1.3815610691190068},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.30691883613665905,
#   'R2': 0.748034869805321,
#   'MSPE': 1.490795724752425},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.30703732371330256,
#   'R2': 0.7385951935504653,
#   'MSPE': 1.5384141470992354},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.30876171042521794,
#   'R2': 0.7191360595173596,
#   'MSPE': 1.4641079402556925},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.30904592908918854,
#   'R2': 0.7438777607812087,
#   'MSPE': 1.4755487665439948},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.30907107392946875,
#   'R2': 0.7306159394059576,
#   'MSPE': 1.4077338930031265},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.3092898721496264,
#   'R2': 0.7471726271409846,
#   'MSPE': 1.5037617529507237},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.30933704227209097,
#   'R2': 0.7484575552441473,
#   'MSPE': 1.4792749073092986},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.3096777086456617,
#   'R2': 0.735410433723162,
#   'MSPE': 1.5146497239575092},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.3102067862947782,
#   'R2': 0.7552196644930099,
#   'MSPE': 1.5133830532431602},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.31069954484701157,
#   'R2': 0.7468686993381527,
#   'MSPE': 1.6326531886377118},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.3107700382669767,
#   'R2': 0.7279943665068671,
#   'MSPE': 1.4943245330806634},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.3113459294040998,
#   'R2': 0.736610386219532,
#   'MSPE': 1.50541365494707},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.31164803554614384,
#   'R2': 0.7324485029478034,
#   'MSPE': 1.6303079930896107},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.31169603019952774,
#   'R2': 0.7480692357397752,
#   'MSPE': 1.5379705959272503},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.3125985577702522,
#   'R2': 0.746245987102933,
#   'MSPE': 1.5948692590675573},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.3135146841406823,
#   'R2': 0.7321032925146033,
#   'MSPE': 1.5567602765172568},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.31438754114011924,
#   'R2': 0.7284515727414467,
#   'MSPE': 1.4692271754352584},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.3147691036264102,
#   'R2': 0.7521456736788413,
#   'MSPE': 1.5921549734687717},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.3156060511867205,
#   'R2': 0.729655003968416,
#   'MSPE': 1.501683071537903},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.3157940189043681,
#   'R2': 0.7279405774758979,
#   'MSPE': 1.5114993258200662},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.3162519514560699,
#   'R2': 0.7147117179237705,
#   'MSPE': 1.6486027118081996},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.3172490971783797,
#   'R2': 0.7105744335883376,
#   'MSPE': 1.4952277902494928},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.3174202928940455,
#   'R2': 0.7338203177544851,
#   'MSPE': 1.5124730607776933},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.31771987403432533,
#   'R2': 0.7365721477964355,
#   'MSPE': 1.753196823457726},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.3179098444680373,
#   'R2': 0.7407267642257352,
#   'MSPE': 1.6134991905078142},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.3184104964137077,
#   'R2': 0.7405656686349475,
#   'MSPE': 1.5457717943089928},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.3184248499572277,
#   'R2': 0.7476109413718908,
#   'MSPE': 1.53630249583247},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.31896253426869714,
#   'R2': 0.7544302171192638,
#   'MSPE': 1.5645382786640014},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.3202879180510839,
#   'R2': 0.7426281661735624,
#   'MSPE': 1.6286859048455202},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.3207131542265415,
#   'R2': 0.6858280997847683,
#   'MSPE': 1.6108115433216696},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.32139673282702763,
#   'R2': 0.6952797304401077,
#   'MSPE': 1.5943713181398134},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.3218226631482442,
#   'R2': 0.7338237526750068,
#   'MSPE': 1.7101223007634736},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.32186693797508875,
#   'R2': 0.7302868761066663,
#   'MSPE': 1.5192307918473626},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.3221177610258261,
#   'R2': 0.7441370741225632,
#   'MSPE': 1.5753460126091736},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.32309020062287647,
#   'R2': 0.7414497883885703,
#   'MSPE': 1.5641427835016841},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.3231601441899935,
#   'R2': 0.7456219724926606,
#   'MSPE': 1.6831438156841982},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.323433680832386,
#   'R2': 0.741592961176393,
#   'MSPE': 1.5860844988639307},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.32374111662308375,
#   'R2': 0.7315964199322768,
#   'MSPE': 1.5223442402320226},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.3255614325404167,
#   'R2': 0.7264920298680533,
#   'MSPE': 1.5627552415573536},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.32570230687658,
#   'R2': 0.7406219460809139,
#   'MSPE': 1.6638479567123483},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.32578085809946056,
#   'R2': 0.7387106020021166,
#   'MSPE': 1.5925965381955556},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.3257886258264383,
#   'R2': 0.7110558692143876,
#   'MSPE': 1.6458391319170143},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.32580290536085765,
#   'R2': 0.7244202986929046,
#   'MSPE': 1.6243572501616197},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.3262254158655803,
#   'R2': 0.7338182129460368,
#   'MSPE': 1.5210190185844294},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.3294544930259387,
#   'R2': 0.7223967310708777,
#   'MSPE': 1.521671483989316},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.33046677584449446,
#   'R2': 0.7343112177610099,
#   'MSPE': 1.6137833524532994},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.33434134026368456,
#   'R2': 0.7002174105720755,
#   'MSPE': 1.562856284882685},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.3361511247853438,
#   'R2': 0.7296370140973172,
#   'MSPE': 1.7322524684961096},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.338270478695631,
#   'R2': 0.7142226549448337,
#   'MSPE': 1.6397832656711941},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.33911447674036027,
#   'R2': 0.7143458227897446,
#   'MSPE': 1.617351107562732},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.339585346231858,
#   'R2': 0.7310666186123533,
#   'MSPE': 1.670065804412871},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.3399405946334203,
#   'R2': 0.7320954059019639,
#   'MSPE': 1.6951421548546564},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.3420684650540352,
#   'R2': 0.6983209265592293,
#   'MSPE': 1.8159470327123248},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.34230918884277345,
#   'R2': 0.7095533916790269,
#   'MSPE': 1.6483376025589127},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.3428394183516502,
#   'R2': 0.6857758617319475,
#   'MSPE': 1.5714781204558381},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.3464759801824887,
#   'R2': 0.7023066814270286,
#   'MSPE': 1.6602414858649777},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.3475327879190445,
#   'R2': 0.689062685034764,
#   'MSPE': 1.725951230548548},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.3488908270994822,
#   'R2': 0.7245920625637896,
#   'MSPE': 1.735878710663228},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.35126411244273187,
#   'R2': 0.6599094264954389,
#   'MSPE': 1.601572631660736},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.36161629706621173,
#   'R2': 0.7043259373793054,
#   'MSPE': 1.588793062990663},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.3755549396077792,
#   'R2': 0.6857304480094539,
#   'MSPE': 1.890811685830204},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.3790283938248952,
#   'R2': 0.6791856477821457,
#   'MSPE': 1.700506027919626},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.38167179351051644,
#   'R2': 0.689271616288041,
#   'MSPE': 1.7118185631592162},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.3821804374456406,
#   'R2': 0.6769095553001864,
#   'MSPE': 1.9145492100241512},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.39025857448577883,
#   'R2': 0.6701660990931135,
#   'MSPE': 2.0210781026481075},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.3913320444524288,
#   'R2': 0.6848116828105384,
#   'MSPE': 1.735252153053127},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.3936870125432809,
#   'R2': 0.6742235584898957,
#   'MSPE': 1.7999012661966105},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.3964436421791713,
#   'R2': 0.6898106069875948,
#   'MSPE': 1.9802270353197902},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.39669587711493176,
#   'R2': 0.6584855183730132,
#   'MSPE': 1.7429199287987718},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.39924181426564853,
#   'R2': 0.6215185580996,
#   'MSPE': 1.871907556137879},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.4050854469339053,
#   'R2': 0.6455568228297532,
#   'MSPE': 1.7388754814035363},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.4052308087547621,
#   'R2': 0.6431814903607909,
#   'MSPE': 2.0085343990399678},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.40701107879479725,
#   'R2': 0.6816063849265316,
#   'MSPE': 1.9458640933112066},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.40740660081307095,
#   'R2': 0.6616086104425692,
#   'MSPE': 1.9149898747076293},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.4090263441205025,
#   'R2': 0.649583475308236,
#   'MSPE': 1.8661480445903957},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.40984787320097293,
#   'R2': 0.6590275914172754,
#   'MSPE': 2.0839897940179917},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.4137391671538353,
#   'R2': 0.6644008390843253,
#   'MSPE': 2.0571454005748633},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.42091026082634936,
#   'R2': 0.6454984438828945,
#   'MSPE': 2.248904811208974},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.42199152534206713,
#   'R2': 0.659227362470222,
#   'MSPE': 1.9873604967701017},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.42294648140668867,
#   'R2': 0.6368230805122973,
#   'MSPE': 1.9817832273177125},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.4247353355089823,
#   'R2': 0.6438731771788577,
#   'MSPE': 1.8559166137129068},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.4262605766455332,
#   'R2': 0.6492857088299023,
#   'MSPE': 1.9630374922181921},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.43456242779890697,
#   'R2': 0.6471823555277996,
#   'MSPE': 2.132036470798681},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.43853646218776704,
#   'R2': 0.6432799696997316,
#   'MSPE': 1.9698524494852983},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.4387373785177867,
#   'R2': 0.6462632087122048,
#   'MSPE': 2.174942226318473},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.4484357153375943,
#   'R2': 0.5999541185816251,
#   'MSPE': 2.0347064390138847},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.44927145838737487,
#   'R2': 0.6211452715191439,
#   'MSPE': 1.9362556644611888},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.45569897045691815,
#   'R2': 0.5708791728287508,
#   'MSPE': 2.086306002856505},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.45733098586400345,
#   'R2': 0.6209737347578032,
#   'MSPE': 2.145817239270216},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.4573798194527626,
#   'R2': 0.6417705304831214,
#   'MSPE': 2.0679461169573994},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.4577199588219325,
#   'R2': 0.6267610328956763,
#   'MSPE': 2.2015021764908473},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.4580639272928238,
#   'R2': 0.6463213943823407,
#   'MSPE': 2.244615399495068},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.46249540597200384,
#   'R2': 0.6084430056225855,
#   'MSPE': 2.183877476443997},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.4654302150011064,
#   'R2': 0.6061080483357089,
#   'MSPE': 2.2223442394963717},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.4669870937863986,
#   'R2': 0.6283533330965978,
#   'MSPE': 2.160619841418182},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.4680981447299321,
#   'R2': 0.6135456160508824,
#   'MSPE': 2.191920078387766},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.46856830765803653,
#   'R2': 0.6124403283249463,
#   'MSPE': 2.116515745568757},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.4693078269561132,
#   'R2': 0.6127319650857052,
#   'MSPE': 2.0609021711755884},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.4696594496568044,
#   'R2': 0.6003510195305075,
#   'MSPE': 2.0737936787984586},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.46982141137123107,
#   'R2': 0.6241175683923789,
#   'MSPE': 2.097026105744369},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.47058441241582233,
#   'R2': 0.623729476800739,
#   'MSPE': 2.1686529370043615},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.47301637530326834,
#   'R2': 0.5861308526436014,
#   'MSPE': 2.287342112624284},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.4741609325011572,
#   'R2': 0.609041771178805,
#   'MSPE': 2.056237105092015},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.47894795536994933,
#   'R2': 0.5900330999344627,
#   'MSPE': 2.1849286204410925},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.47997005879879007,
#   'R2': 0.6091915643815485,
#   'MSPE': 2.4412595186232013},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.4881463920076688,
#   'R2': 0.6120196064298408,
#   'MSPE': 2.1939800449204863},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.48901947736740115,
#   'R2': 0.5181861056124694,
#   'MSPE': 1.952419856262177},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.49044708261887227,
#   'R2': 0.6112483737488814,
#   'MSPE': 2.2553056577277},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.49260960817337035,
#   'R2': 0.5757742956150744,
#   'MSPE': 2.2746214343968667},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.4929511696100234,
#   'R2': 0.5923470077260566,
#   'MSPE': 2.094625401207142},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.4965823868910471,
#   'R2': 0.5674684111365924,
#   'MSPE': 2.2437920688529207},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.49718992710113535,
#   'R2': 0.5992883667910032,
#   'MSPE': 2.321458625503712},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.4981608162323634,
#   'R2': 0.6088494544670615,
#   'MSPE': 2.5362458449760172},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.5009004970391591,
#   'R2': 0.5997235533130001,
#   'MSPE': 2.383906312352705},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.5087670519948005,
#   'R2': 0.5866904249114289,
#   'MSPE': 2.1995255610708035},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.5099107809364797,
#   'R2': 0.5850428762935564,
#   'MSPE': 2.383384641560942},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.5177862495183945,
#   'R2': 0.5447295716037244,
#   'MSPE': 2.1102100229737433},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.5275795911749205,
#   'R2': 0.5898078732088645,
#   'MSPE': 2.3756546224232276},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.5421309143304824,
#   'R2': 0.5576411583989968,
#   'MSPE': 2.19191822844247},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.5595552911361059,
#   'R2': 0.5335283545409533,
#   'MSPE': 2.1884556673467155},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.5597652663787207,
#   'R2': 0.5168827625982334,
#   'MSPE': 2.772944884638142},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.5811252653598785,
#   'R2': 0.5225904724387834,
#   'MSPE': 2.696721887761595},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.5855660140514374,
#   'R2': 0.5130741371097534,
#   'MSPE': 2.6507362294377703},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.5902757396300634,
#   'R2': 0.4680975365627832,
#   'MSPE': 2.6814222197528137},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.5988756070534389,
#   'R2': 0.49491550465845313,
#   'MSPE': 2.2196322441514993},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.6112553442517916,
#   'R2': 0.504864061336489,
#   'MSPE': 2.6893515092781692},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.6233192880948385,
#   'R2': 0.49337840499244867,
#   'MSPE': 2.9168577189322074},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.6295161023736001,
#   'R2': 0.5154377223218922,
#   'MSPE': 2.9057270069277346},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.6366543908913931,
#   'R2': 0.4402697257809951,
#   'MSPE': 3.054164462732245},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.6454357286294301,
#   'R2': 0.4559505081445619,
#   'MSPE': 2.8219560729433786},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.6541336248318355,
#   'R2': 0.48890211874728867,
#   'MSPE': 3.113813009677511},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.6560829321543376,
#   'R2': 0.4375196026745881,
#   'MSPE': 3.0343102163287123},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.6579618304967881,
#   'R2': 0.48215786895522805,
#   'MSPE': 2.7552013865888414},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.6739076487720013,
#   'R2': 0.4361712765051526,
#   'MSPE': 3.043935703057231},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.6783444029589494,
#   'R2': 0.45460162686760164,
#   'MSPE': 3.1020253190695484},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.6802943219741187,
#   'R2': 0.45015518366974466,
#   'MSPE': 3.1480546860080776},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.6812298665444055,
#   'R2': 0.4441704679965808,
#   'MSPE': 3.2736201753670513},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.6888804654280345,
#   'R2': 0.42631525615287763,
#   'MSPE': 3.3205002448474517},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.6903640737136205,
#   'R2': 0.4108711828817178,
#   'MSPE': 3.197234385938506},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.7052330613136292,
#   'R2': 0.4200672400441345,
#   'MSPE': 3.1528860575171427},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.7067976161837578,
#   'R2': 0.4356806323755812,
#   'MSPE': 3.2571776365541454},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.7099032054344814,
#   'R2': 0.44092670250802507,
#   'MSPE': 3.054600968166734},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.7100109438101451,
#   'R2': 0.41795219374493026,
#   'MSPE': 3.2639610206689498},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.7116963237524032,
#   'R2': 0.41626072638885814,
#   'MSPE': 3.2348299382085144},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.7143402735392252,
#   'R2': 0.4045664483672781,
#   'MSPE': 3.2838487369243543},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.716734528541565,
#   'R2': 0.42382196646139086,
#   'MSPE': 3.5718742487105453},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.7198036223649978,
#   'R2': 0.3951639420694761,
#   'MSPE': 3.159189906272322},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.7270329574743906,
#   'R2': 0.4054924469472268,
#   'MSPE': 3.069029330003141},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.7316540032625198,
#   'R2': 0.4146101300233342,
#   'MSPE': 3.0786743997172876},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.7321577429771423,
#   'R2': 0.37899834526148407,
#   'MSPE': 3.4462248121924475},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.74337490995725,
#   'R2': 0.3781786475254221,
#   'MSPE': 3.3200526542284265},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.744245939453443,
#   'R2': 0.37783515920006105,
#   'MSPE': 3.7014935024534212},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.7553568055232367,
#   'R2': 0.3747606209897963,
#   'MSPE': 3.6528808523834955},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.7565789361794788,
#   'R2': 0.35370417585231584,
#   'MSPE': 3.38726157510672},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.7593959838151932,
#   'R2': 0.33384219480610033,
#   'MSPE': 3.3163804363346463},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.7609119981527328,
#   'R2': 0.37364844944431547,
#   'MSPE': 3.271357686437591},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.7633090337117513,
#   'R2': 0.3522384167228705,
#   'MSPE': 3.5990070075624514},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.7766244073708852,
#   'R2': 0.352499664357543,
#   'MSPE': 3.2318039330644437},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.7804000724107027,
#   'R2': 0.36348338380981976,
#   'MSPE': 3.8970253395499896},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.785671063264211,
#   'R2': 0.36766120838754845,
#   'MSPE': 3.6133409024338525},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.7884099960327149,
#   'R2': 0.3406578970787604,
#   'MSPE': 3.5839888511808837},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.7929367984334628,
#   'R2': 0.33751683191543874,
#   'MSPE': 3.6450674492075583},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.795024515191714,
#   'R2': 0.37512444683669227,
#   'MSPE': 3.8875875992681643},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.8018698086341223,
#   'R2': 0.39985268054886214,
#   'MSPE': 2.983895656323493},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.802851163347562,
#   'R2': 0.36137380468100844,
#   'MSPE': 3.8489597783696774},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.8046819478273392,
#   'R2': 0.34763551720241426,
#   'MSPE': 3.771036384119229},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.8176035592953363,
#   'R2': 0.33700247477856954,
#   'MSPE': 3.5976458361579318},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.837553956111272,
#   'R2': 0.3528842410811862,
#   'MSPE': 3.972851618597604},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.8491518080234528,
#   'R2': 0.32455044463531196,
#   'MSPE': 4.170355060786912},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.8537915180126827,
#   'R2': 0.3194690102389506,
#   'MSPE': 4.065237345945354},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.8755255669355393,
#   'R2': 0.26933561553508273,
#   'MSPE': 4.030890702599226},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.8758482327063879,
#   'R2': 0.23702679976681934,
#   'MSPE': 4.030155866698484},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.8810886243979136,
#   'R2': 0.2750301108903451,
#   'MSPE': 4.057619753811094},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.9427325000365574,
#   'R2': 0.23675419182753438,
#   'MSPE': 4.0149702748867},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.9785157740116117,
#   'R2': 0.24463289385376838,
#   'MSPE': 4.546570850705558},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 1.0503747021158536,
#   'R2': 0.08237050758990053,
#   'MSPE': 4.5848071389841},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 1.070193841556708,
#   'R2': 0.12369233203256318,
#   'MSPE': 4.705663178153712},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 1.4261133939027786,
#   'R2': -0.23667380788148956,
#   'MSPE': 5.350006940501808},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 1.4293131480614345,
#   'R2': -0.08108060775247869,
#   'MSPE': 5.126514029548024},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 1.5571848889191944,
#   'R2': -0.42851338252561905,
#   'MSPE': 5.767024894329635},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 1.70338940123717,
#   'R2': -0.47291708225112883,
#   'MSPE': 6.1881377655222565}]

# %%
# Sort by highest R2
sorted(results, key=lambda x: x["R2"], reverse=True)
# Out:
# [{'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.2659540211160977,
#   'R2': 0.7875701399335296,
#   'MSPE': 1.2628805374895984},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.25703807870546974,
#   'R2': 0.7872408391806608,
#   'MSPE': 1.2496729673949458},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.2589205980300903,
#   'R2': 0.786697878032885,
#   'MSPE': 1.2418141310112645},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.26192603980501494,
#   'R2': 0.7840488091012527,
#   'MSPE': 1.278309210702175},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.2694628993670146,
#   'R2': 0.7834700641480017,
#   'MSPE': 1.576514458095636},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.26158651411533357,
#   'R2': 0.7831063026963083,
#   'MSPE': 1.2136999431132065},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.2683252053956191,
#   'R2': 0.781133175751445,
#   'MSPE': 1.33553878968638},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.27762194598714507,
#   'R2': 0.7777265254069123,
#   'MSPE': 1.31659697487273},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.27973109508554134,
#   'R2': 0.7770405683170807,
#   'MSPE': 1.3850216955097037},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.27262885322173436,
#   'R2': 0.7753747591414729,
#   'MSPE': 1.3216610293308593},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.2573568854480982,
#   'R2': 0.7742094559465296,
#   'MSPE': 1.2011611699644063},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.27771709437171616,
#   'R2': 0.7731474083363532,
#   'MSPE': 1.3440811744599477},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.2701714506993691,
#   'R2': 0.7724022216504816,
#   'MSPE': 1.2498147051894306},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.28590907057126363,
#   'R2': 0.7720820820929257,
#   'MSPE': 1.400239457272821},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.2668776656190554,
#   'R2': 0.7717525660630101,
#   'MSPE': 1.2808782509481065},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.2886240541934967,
#   'R2': 0.7713206999579391,
#   'MSPE': 1.3568708797766251},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.2929982036352158,
#   'R2': 0.7712772678452937,
#   'MSPE': 1.5619800236038486},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.27915878246227893,
#   'R2': 0.7702640836568168,
#   'MSPE': 1.4591968341288393},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.2760957404971123,
#   'R2': 0.7700012797818497,
#   'MSPE': 1.344015406576371},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.28289652963479356,
#   'R2': 0.769966381352592,
#   'MSPE': 1.3489437160656008},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.3063746144374212,
#   'R2': 0.7698008491914352,
#   'MSPE': 1.6636396459106244},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.283641820649306,
#   'R2': 0.7697979375127535,
#   'MSPE': 1.3761548802839836},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.2970277066032092,
#   'R2': 0.7687562175860554,
#   'MSPE': 1.5210727605065613},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.285283200442791,
#   'R2': 0.7685300595324469,
#   'MSPE': 1.4846753492725617},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.2701086868842443,
#   'R2': 0.7675814454331265,
#   'MSPE': 1.2818159008718502},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.28369835317134856,
#   'R2': 0.7675258954073765,
#   'MSPE': 1.4146540591474432},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.28138675677279623,
#   'R2': 0.7666675770372209,
#   'MSPE': 1.3309277397476964},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.2839125593503316,
#   'R2': 0.7660542467233357,
#   'MSPE': 1.365333257167779},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.29059302036960916,
#   'R2': 0.7658357826815975,
#   'MSPE': 1.4017653223033053},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.28911879460016887,
#   'R2': 0.7658302526252914,
#   'MSPE': 1.4053520458665762},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.2828984588384628,
#   'R2': 0.7656919258621573,
#   'MSPE': 1.342074780235763},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.2857156798243523,
#   'R2': 0.7655792917640386,
#   'MSPE': 1.409967006513416},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.26467016339302063,
#   'R2': 0.7643958141920992,
#   'MSPE': 1.2903357558704986},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.287049222489198,
#   'R2': 0.7643211756476292,
#   'MSPE': 1.314894831363074},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.28891860470175745,
#   'R2': 0.7636587703606674,
#   'MSPE': 1.3271995606559395},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.28052083080013596,
#   'R2': 0.7631980751657655,
#   'MSPE': 1.3309412636803557},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.2954651186863581,
#   'R2': 0.7621060333196289,
#   'MSPE': 1.4061157153260828},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.28394837478796636,
#   'R2': 0.7618639125641585,
#   'MSPE': 1.3146029863826403},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.28550436571240423,
#   'R2': 0.76180877415016,
#   'MSPE': 1.4469689241318842},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.2742079591999452,
#   'R2': 0.7617086712300564,
#   'MSPE': 1.2616658736152027},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.2935001882414022,
#   'R2': 0.7611523349394596,
#   'MSPE': 1.6445251292727814},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.2901854420701663,
#   'R2': 0.7602467650459418,
#   'MSPE': 1.483079937446599},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.2831756293773651,
#   'R2': 0.7601948130915678,
#   'MSPE': 1.3127151053549364},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.28306309680143993,
#   'R2': 0.7594442792670018,
#   'MSPE': 1.3169096422503994},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.2838497705757618,
#   'R2': 0.7586636440699847,
#   'MSPE': 1.3277152743228158},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.2905648584167163,
#   'R2': 0.7583875406417575,
#   'MSPE': 1.4032028415099238},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.2932273437579473,
#   'R2': 0.7582697909646134,
#   'MSPE': 1.508405674625226},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.29805129418770465,
#   'R2': 0.7582370445535211,
#   'MSPE': 1.5736234633985793},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.30174675608674684,
#   'R2': 0.7582158907938296,
#   'MSPE': 1.542001466991173},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.2945609101404747,
#   'R2': 0.7581607855097204,
#   'MSPE': 1.462303837196845},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.27877845068772633,
#   'R2': 0.7577206289773029,
#   'MSPE': 1.3200904116636576},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.2847877122461796,
#   'R2': 0.7574637634396447,
#   'MSPE': 1.3683910891789979},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.29004320402940115,
#   'R2': 0.7573302354117868,
#   'MSPE': 1.4129554660934391},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.2947303819159667,
#   'R2': 0.7573228804924137,
#   'MSPE': 1.5032956150896621},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.29800939162572226,
#   'R2': 0.7567885505694874,
#   'MSPE': 1.487556938505308},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.2871061035742362,
#   'R2': 0.7564079288347496,
#   'MSPE': 1.3055660236965527},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.2961413582166036,
#   'R2': 0.7558400617998846,
#   'MSPE': 1.4414253737307106},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.2885672464966774,
#   'R2': 0.7556449716208775,
#   'MSPE': 1.3516653835246661},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.27650429680943495,
#   'R2': 0.7552349726402896,
#   'MSPE': 1.2884063166895448},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.3102067862947782,
#   'R2': 0.7552196644930099,
#   'MSPE': 1.5133830532431602},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.3011649745206038,
#   'R2': 0.7550887720274072,
#   'MSPE': 1.4949559568041804},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.29959845095872883,
#   'R2': 0.755002066203448,
#   'MSPE': 1.4820209400013389},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.2716555374364058,
#   'R2': 0.7547897085066195,
#   'MSPE': 1.2830500392186823},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.31896253426869714,
#   'R2': 0.7544302171192638,
#   'MSPE': 1.5645382786640014},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.289659483730793,
#   'R2': 0.7538615971420044,
#   'MSPE': 1.4194856285390378},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.29416299040118854,
#   'R2': 0.753079965137591,
#   'MSPE': 1.340702503562124},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.293012747168541,
#   'R2': 0.7525666933004171,
#   'MSPE': 1.4017921126438209},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.3147691036264102,
#   'R2': 0.7521456736788413,
#   'MSPE': 1.5921549734687717},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.287770106146733,
#   'R2': 0.752034921699868,
#   'MSPE': 1.3980653285133566},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.2971463975807031,
#   'R2': 0.7518072850986235,
#   'MSPE': 1.4317002071237022},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.29272496228416756,
#   'R2': 0.7517223064604683,
#   'MSPE': 1.4130836349883764},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.27643521924813585,
#   'R2': 0.7514258080401663,
#   'MSPE': 1.2601008959998836},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.29285027484099074,
#   'R2': 0.751372990791583,
#   'MSPE': 1.4371134190246313},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.29804965356985724,
#   'R2': 0.7510431916614554,
#   'MSPE': 1.422743240107942},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.28663414071003596,
#   'R2': 0.7508857076129231,
#   'MSPE': 1.3946011926828308},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.3055987243851026,
#   'R2': 0.7501585723917837,
#   'MSPE': 1.4416105136501067},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.30678469588359203,
#   'R2': 0.7491730297628304,
#   'MSPE': 1.442997432454969},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.30933704227209097,
#   'R2': 0.7484575552441473,
#   'MSPE': 1.4792749073092986},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.31169603019952774,
#   'R2': 0.7480692357397752,
#   'MSPE': 1.5379705959272503},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.30691883613665905,
#   'R2': 0.748034869805321,
#   'MSPE': 1.490795724752425},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.3016414061188698,
#   'R2': 0.7476705723573431,
#   'MSPE': 1.4402837377756534},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.27981958190600076,
#   'R2': 0.7476499881184745,
#   'MSPE': 1.3060571519526267},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.3184248499572277,
#   'R2': 0.7476109413718908,
#   'MSPE': 1.53630249583247},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.2793135104080041,
#   'R2': 0.7476025629834054,
#   'MSPE': 1.398713333494585},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.2687787239750226,
#   'R2': 0.7475403730353554,
#   'MSPE': 1.3387889265920025},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.2854095108807087,
#   'R2': 0.7472531374957483,
#   'MSPE': 1.3710817583657877},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.3092898721496264,
#   'R2': 0.7471726271409846,
#   'MSPE': 1.5037617529507237},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.31069954484701157,
#   'R2': 0.7468686993381527,
#   'MSPE': 1.6326531886377118},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.3057296549280485,
#   'R2': 0.7465556917860043,
#   'MSPE': 1.5178161887734223},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.3125985577702522,
#   'R2': 0.746245987102933,
#   'MSPE': 1.5948692590675573},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.3231601441899935,
#   'R2': 0.7456219724926606,
#   'MSPE': 1.6831438156841982},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.2862506702542305,
#   'R2': 0.7453588320801364,
#   'MSPE': 1.366624967712495},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.2970339857041836,
#   'R2': 0.7448096641612149,
#   'MSPE': 1.3586607153969583},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.29738730217019715,
#   'R2': 0.7444303308151022,
#   'MSPE': 1.3976835204532954},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.29808829724788666,
#   'R2': 0.7442244642331144,
#   'MSPE': 1.4387864314697005},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.3221177610258261,
#   'R2': 0.7441370741225632,
#   'MSPE': 1.5753460126091736},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.2788675072292487,
#   'R2': 0.7441072231031569,
#   'MSPE': 1.3650393172759903},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.30904592908918854,
#   'R2': 0.7438777607812087,
#   'MSPE': 1.4755487665439948},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.29483144829670593,
#   'R2': 0.7435798598765969,
#   'MSPE': 1.3790731894962414},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.3202879180510839,
#   'R2': 0.7426281661735624,
#   'MSPE': 1.6286859048455202},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.323433680832386,
#   'R2': 0.741592961176393,
#   'MSPE': 1.5860844988639307},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.32309020062287647,
#   'R2': 0.7414497883885703,
#   'MSPE': 1.5641427835016841},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.3063514269888401,
#   'R2': 0.7414177608445687,
#   'MSPE': 1.5522064992010294},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.3011696455379328,
#   'R2': 0.7414091337095917,
#   'MSPE': 1.4740491647160412},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.3179098444680373,
#   'R2': 0.7407267642257352,
#   'MSPE': 1.6134991905078142},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.32570230687658,
#   'R2': 0.7406219460809139,
#   'MSPE': 1.6638479567123483},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.3184104964137077,
#   'R2': 0.7405656686349475,
#   'MSPE': 1.5457717943089928},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.306726070245107,
#   'R2': 0.7394917809562366,
#   'MSPE': 1.4890070351762603},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.32578085809946056,
#   'R2': 0.7387106020021166,
#   'MSPE': 1.5925965381955556},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.2900302519400914,
#   'R2': 0.7386128693360737,
#   'MSPE': 1.3558030700442767},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.30703732371330256,
#   'R2': 0.7385951935504653,
#   'MSPE': 1.5384141470992354},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.2931299388408661,
#   'R2': 0.738517498327705,
#   'MSPE': 1.4415623295600668},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.2819469066957633,
#   'R2': 0.7382811798126898,
#   'MSPE': 1.2455763148538994},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.3050552725791931,
#   'R2': 0.7382295806167927,
#   'MSPE': 1.5237317143026927},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.30224890634417534,
#   'R2': 0.7373426440215207,
#   'MSPE': 1.447865774459911},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.2909860653181871,
#   'R2': 0.7366231239587042,
#   'MSPE': 1.3602257350629026},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.3113459294040998,
#   'R2': 0.736610386219532,
#   'MSPE': 1.50541365494707},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.31771987403432533,
#   'R2': 0.7365721477964355,
#   'MSPE': 1.753196823457726},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.3096777086456617,
#   'R2': 0.735410433723162,
#   'MSPE': 1.5146497239575092},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.29809957047303515,
#   'R2': 0.7346836962864306,
#   'MSPE': 1.4835317847742275},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.33046677584449446,
#   'R2': 0.7343112177610099,
#   'MSPE': 1.6137833524532994},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.3218226631482442,
#   'R2': 0.7338237526750068,
#   'MSPE': 1.7101223007634736},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.3174202928940455,
#   'R2': 0.7338203177544851,
#   'MSPE': 1.5124730607776933},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.3262254158655803,
#   'R2': 0.7338182129460368,
#   'MSPE': 1.5210190185844294},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.3019757941365242,
#   'R2': 0.7330431909430773,
#   'MSPE': 1.435192728866682},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.31164803554614384,
#   'R2': 0.7324485029478034,
#   'MSPE': 1.6303079930896107},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.3135146841406823,
#   'R2': 0.7321032925146033,
#   'MSPE': 1.5567602765172568},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.3399405946334203,
#   'R2': 0.7320954059019639,
#   'MSPE': 1.6951421548546564},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.32374111662308375,
#   'R2': 0.7315964199322768,
#   'MSPE': 1.5223442402320226},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.3039009963472684,
#   'R2': 0.731265807891269,
#   'MSPE': 1.4275465541603887},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.339585346231858,
#   'R2': 0.7310666186123533,
#   'MSPE': 1.670065804412871},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.30907107392946875,
#   'R2': 0.7306159394059576,
#   'MSPE': 1.4077338930031265},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.2844589531421661,
#   'R2': 0.7303690535787102,
#   'MSPE': 1.403850654629294},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.32186693797508875,
#   'R2': 0.7302868761066663,
#   'MSPE': 1.5192307918473626},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.2913438297808171,
#   'R2': 0.730020189066927,
#   'MSPE': 1.3863150598575371},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.3156060511867205,
#   'R2': 0.729655003968416,
#   'MSPE': 1.501683071537903},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.3361511247853438,
#   'R2': 0.7296370140973172,
#   'MSPE': 1.7322524684961096},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.2909766634305318,
#   'R2': 0.7285189087348153,
#   'MSPE': 1.3537219467789234},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.31438754114011924,
#   'R2': 0.7284515727414467,
#   'MSPE': 1.4692271754352584},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.30132128099600475,
#   'R2': 0.7283054121991104,
#   'MSPE': 1.3818066333881533},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.3107700382669767,
#   'R2': 0.7279943665068671,
#   'MSPE': 1.4943245330806634},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.3157940189043681,
#   'R2': 0.7279405774758979,
#   'MSPE': 1.5114993258200662},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.3255614325404167,
#   'R2': 0.7264920298680533,
#   'MSPE': 1.5627552415573536},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.3488908270994822,
#   'R2': 0.7245920625637896,
#   'MSPE': 1.735878710663228},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.32580290536085765,
#   'R2': 0.7244202986929046,
#   'MSPE': 1.6243572501616197},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.30655971070130666,
#   'R2': 0.7224974597048556,
#   'MSPE': 1.4165122987646044},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.3294544930259387,
#   'R2': 0.7223967310708777,
#   'MSPE': 1.521671483989316},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.301581592609485,
#   'R2': 0.7191805621646381,
#   'MSPE': 1.3893991297186175},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.30876171042521794,
#   'R2': 0.7191360595173596,
#   'MSPE': 1.4641079402556925},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.3068160697817802,
#   'R2': 0.7149214253010631,
#   'MSPE': 1.3815610691190068},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.3162519514560699,
#   'R2': 0.7147117179237705,
#   'MSPE': 1.6486027118081996},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.33911447674036027,
#   'R2': 0.7143458227897446,
#   'MSPE': 1.617351107562732},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.338270478695631,
#   'R2': 0.7142226549448337,
#   'MSPE': 1.6397832656711941},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.3257886258264383,
#   'R2': 0.7110558692143876,
#   'MSPE': 1.6458391319170143},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.3172490971783797,
#   'R2': 0.7105744335883376,
#   'MSPE': 1.4952277902494928},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.34230918884277345,
#   'R2': 0.7095533916790269,
#   'MSPE': 1.6483376025589127},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.305199383944273,
#   'R2': 0.7094027225148583,
#   'MSPE': 1.4207450421809247},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.3036412345866362,
#   'R2': 0.7073295063150192,
#   'MSPE': 1.3734716733428414},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.36161629706621173,
#   'R2': 0.7043259373793054,
#   'MSPE': 1.588793062990663},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.3464759801824887,
#   'R2': 0.7023066814270286,
#   'MSPE': 1.6602414858649777},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.33434134026368456,
#   'R2': 0.7002174105720755,
#   'MSPE': 1.562856284882685},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.3420684650540352,
#   'R2': 0.6983209265592293,
#   'MSPE': 1.8159470327123248},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.32139673282702763,
#   'R2': 0.6952797304401077,
#   'MSPE': 1.5943713181398134},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.3964436421791713,
#   'R2': 0.6898106069875948,
#   'MSPE': 1.9802270353197902},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.38167179351051644,
#   'R2': 0.689271616288041,
#   'MSPE': 1.7118185631592162},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.3475327879190445,
#   'R2': 0.689062685034764,
#   'MSPE': 1.725951230548548},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.3207131542265415,
#   'R2': 0.6858280997847683,
#   'MSPE': 1.6108115433216696},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.3428394183516502,
#   'R2': 0.6857758617319475,
#   'MSPE': 1.5714781204558381},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.3755549396077792,
#   'R2': 0.6857304480094539,
#   'MSPE': 1.890811685830204},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.3913320444524288,
#   'R2': 0.6848116828105384,
#   'MSPE': 1.735252153053127},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.40701107879479725,
#   'R2': 0.6816063849265316,
#   'MSPE': 1.9458640933112066},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.3790283938248952,
#   'R2': 0.6791856477821457,
#   'MSPE': 1.700506027919626},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.3821804374456406,
#   'R2': 0.6769095553001864,
#   'MSPE': 1.9145492100241512},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.3936870125432809,
#   'R2': 0.6742235584898957,
#   'MSPE': 1.7999012661966105},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.39025857448577883,
#   'R2': 0.6701660990931135,
#   'MSPE': 2.0210781026481075},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.4137391671538353,
#   'R2': 0.6644008390843253,
#   'MSPE': 2.0571454005748633},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.40740660081307095,
#   'R2': 0.6616086104425692,
#   'MSPE': 1.9149898747076293},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.35126411244273187,
#   'R2': 0.6599094264954389,
#   'MSPE': 1.601572631660736},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.42199152534206713,
#   'R2': 0.659227362470222,
#   'MSPE': 1.9873604967701017},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.40984787320097293,
#   'R2': 0.6590275914172754,
#   'MSPE': 2.0839897940179917},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.39669587711493176,
#   'R2': 0.6584855183730132,
#   'MSPE': 1.7429199287987718},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.4090263441205025,
#   'R2': 0.649583475308236,
#   'MSPE': 1.8661480445903957},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.4262605766455332,
#   'R2': 0.6492857088299023,
#   'MSPE': 1.9630374922181921},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.43456242779890697,
#   'R2': 0.6471823555277996,
#   'MSPE': 2.132036470798681},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.4580639272928238,
#   'R2': 0.6463213943823407,
#   'MSPE': 2.244615399495068},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.4387373785177867,
#   'R2': 0.6462632087122048,
#   'MSPE': 2.174942226318473},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.4050854469339053,
#   'R2': 0.6455568228297532,
#   'MSPE': 1.7388754814035363},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.42091026082634936,
#   'R2': 0.6454984438828945,
#   'MSPE': 2.248904811208974},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.4247353355089823,
#   'R2': 0.6438731771788577,
#   'MSPE': 1.8559166137129068},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.43853646218776704,
#   'R2': 0.6432799696997316,
#   'MSPE': 1.9698524494852983},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.4052308087547621,
#   'R2': 0.6431814903607909,
#   'MSPE': 2.0085343990399678},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.4573798194527626,
#   'R2': 0.6417705304831214,
#   'MSPE': 2.0679461169573994},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.42294648140668867,
#   'R2': 0.6368230805122973,
#   'MSPE': 1.9817832273177125},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.4669870937863986,
#   'R2': 0.6283533330965978,
#   'MSPE': 2.160619841418182},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.4577199588219325,
#   'R2': 0.6267610328956763,
#   'MSPE': 2.2015021764908473},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.46982141137123107,
#   'R2': 0.6241175683923789,
#   'MSPE': 2.097026105744369},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.47058441241582233,
#   'R2': 0.623729476800739,
#   'MSPE': 2.1686529370043615},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.39924181426564853,
#   'R2': 0.6215185580996,
#   'MSPE': 1.871907556137879},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.44927145838737487,
#   'R2': 0.6211452715191439,
#   'MSPE': 1.9362556644611888},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.45733098586400345,
#   'R2': 0.6209737347578032,
#   'MSPE': 2.145817239270216},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.4680981447299321,
#   'R2': 0.6135456160508824,
#   'MSPE': 2.191920078387766},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.4693078269561132,
#   'R2': 0.6127319650857052,
#   'MSPE': 2.0609021711755884},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.46856830765803653,
#   'R2': 0.6124403283249463,
#   'MSPE': 2.116515745568757},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.4881463920076688,
#   'R2': 0.6120196064298408,
#   'MSPE': 2.1939800449204863},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.49044708261887227,
#   'R2': 0.6112483737488814,
#   'MSPE': 2.2553056577277},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.47997005879879007,
#   'R2': 0.6091915643815485,
#   'MSPE': 2.4412595186232013},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.4741609325011572,
#   'R2': 0.609041771178805,
#   'MSPE': 2.056237105092015},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.4981608162323634,
#   'R2': 0.6088494544670615,
#   'MSPE': 2.5362458449760172},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.46249540597200384,
#   'R2': 0.6084430056225855,
#   'MSPE': 2.183877476443997},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.4654302150011064,
#   'R2': 0.6061080483357089,
#   'MSPE': 2.2223442394963717},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.4696594496568044,
#   'R2': 0.6003510195305075,
#   'MSPE': 2.0737936787984586},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.4484357153375943,
#   'R2': 0.5999541185816251,
#   'MSPE': 2.0347064390138847},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.5009004970391591,
#   'R2': 0.5997235533130001,
#   'MSPE': 2.383906312352705},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.49718992710113535,
#   'R2': 0.5992883667910032,
#   'MSPE': 2.321458625503712},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.4929511696100234,
#   'R2': 0.5923470077260566,
#   'MSPE': 2.094625401207142},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.47894795536994933,
#   'R2': 0.5900330999344627,
#   'MSPE': 2.1849286204410925},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.5275795911749205,
#   'R2': 0.5898078732088645,
#   'MSPE': 2.3756546224232276},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.5087670519948005,
#   'R2': 0.5866904249114289,
#   'MSPE': 2.1995255610708035},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.47301637530326834,
#   'R2': 0.5861308526436014,
#   'MSPE': 2.287342112624284},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.5099107809364797,
#   'R2': 0.5850428762935564,
#   'MSPE': 2.383384641560942},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.49260960817337035,
#   'R2': 0.5757742956150744,
#   'MSPE': 2.2746214343968667},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.45569897045691815,
#   'R2': 0.5708791728287508,
#   'MSPE': 2.086306002856505},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.4965823868910471,
#   'R2': 0.5674684111365924,
#   'MSPE': 2.2437920688529207},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.5421309143304824,
#   'R2': 0.5576411583989968,
#   'MSPE': 2.19191822844247},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.5177862495183945,
#   'R2': 0.5447295716037244,
#   'MSPE': 2.1102100229737433},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.5595552911361059,
#   'R2': 0.5335283545409533,
#   'MSPE': 2.1884556673467155},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.5811252653598785,
#   'R2': 0.5225904724387834,
#   'MSPE': 2.696721887761595},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.48901947736740115,
#   'R2': 0.5181861056124694,
#   'MSPE': 1.952419856262177},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.5597652663787207,
#   'R2': 0.5168827625982334,
#   'MSPE': 2.772944884638142},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.6295161023736001,
#   'R2': 0.5154377223218922,
#   'MSPE': 2.9057270069277346},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.5855660140514374,
#   'R2': 0.5130741371097534,
#   'MSPE': 2.6507362294377703},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.6112553442517916,
#   'R2': 0.504864061336489,
#   'MSPE': 2.6893515092781692},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.5988756070534389,
#   'R2': 0.49491550465845313,
#   'MSPE': 2.2196322441514993},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.6233192880948385,
#   'R2': 0.49337840499244867,
#   'MSPE': 2.9168577189322074},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.6541336248318355,
#   'R2': 0.48890211874728867,
#   'MSPE': 3.113813009677511},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.6579618304967881,
#   'R2': 0.48215786895522805,
#   'MSPE': 2.7552013865888414},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.5902757396300634,
#   'R2': 0.4680975365627832,
#   'MSPE': 2.6814222197528137},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.6454357286294301,
#   'R2': 0.4559505081445619,
#   'MSPE': 2.8219560729433786},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.6783444029589494,
#   'R2': 0.45460162686760164,
#   'MSPE': 3.1020253190695484},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.6802943219741187,
#   'R2': 0.45015518366974466,
#   'MSPE': 3.1480546860080776},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.6812298665444055,
#   'R2': 0.4441704679965808,
#   'MSPE': 3.2736201753670513},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.7099032054344814,
#   'R2': 0.44092670250802507,
#   'MSPE': 3.054600968166734},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.6366543908913931,
#   'R2': 0.4402697257809951,
#   'MSPE': 3.054164462732245},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.6560829321543376,
#   'R2': 0.4375196026745881,
#   'MSPE': 3.0343102163287123},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.6739076487720013,
#   'R2': 0.4361712765051526,
#   'MSPE': 3.043935703057231},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.7067976161837578,
#   'R2': 0.4356806323755812,
#   'MSPE': 3.2571776365541454},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.6888804654280345,
#   'R2': 0.42631525615287763,
#   'MSPE': 3.3205002448474517},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.716734528541565,
#   'R2': 0.42382196646139086,
#   'MSPE': 3.5718742487105453},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.7052330613136292,
#   'R2': 0.4200672400441345,
#   'MSPE': 3.1528860575171427},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.7100109438101451,
#   'R2': 0.41795219374493026,
#   'MSPE': 3.2639610206689498},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.7116963237524032,
#   'R2': 0.41626072638885814,
#   'MSPE': 3.2348299382085144},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.7316540032625198,
#   'R2': 0.4146101300233342,
#   'MSPE': 3.0786743997172876},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.6903640737136205,
#   'R2': 0.4108711828817178,
#   'MSPE': 3.197234385938506},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.7270329574743906,
#   'R2': 0.4054924469472268,
#   'MSPE': 3.069029330003141},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.7143402735392252,
#   'R2': 0.4045664483672781,
#   'MSPE': 3.2838487369243543},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.8018698086341223,
#   'R2': 0.39985268054886214,
#   'MSPE': 2.983895656323493},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.7198036223649978,
#   'R2': 0.3951639420694761,
#   'MSPE': 3.159189906272322},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.7321577429771423,
#   'R2': 0.37899834526148407,
#   'MSPE': 3.4462248121924475},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.74337490995725,
#   'R2': 0.3781786475254221,
#   'MSPE': 3.3200526542284265},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.744245939453443,
#   'R2': 0.37783515920006105,
#   'MSPE': 3.7014935024534212},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.795024515191714,
#   'R2': 0.37512444683669227,
#   'MSPE': 3.8875875992681643},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.7553568055232367,
#   'R2': 0.3747606209897963,
#   'MSPE': 3.6528808523834955},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.7609119981527328,
#   'R2': 0.37364844944431547,
#   'MSPE': 3.271357686437591},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.785671063264211,
#   'R2': 0.36766120838754845,
#   'MSPE': 3.6133409024338525},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.7804000724107027,
#   'R2': 0.36348338380981976,
#   'MSPE': 3.8970253395499896},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.802851163347562,
#   'R2': 0.36137380468100844,
#   'MSPE': 3.8489597783696774},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.7565789361794788,
#   'R2': 0.35370417585231584,
#   'MSPE': 3.38726157510672},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.837553956111272,
#   'R2': 0.3528842410811862,
#   'MSPE': 3.972851618597604},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.7766244073708852,
#   'R2': 0.352499664357543,
#   'MSPE': 3.2318039330644437},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.7633090337117513,
#   'R2': 0.3522384167228705,
#   'MSPE': 3.5990070075624514},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.8046819478273392,
#   'R2': 0.34763551720241426,
#   'MSPE': 3.771036384119229},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.7884099960327149,
#   'R2': 0.3406578970787604,
#   'MSPE': 3.5839888511808837},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.7929367984334628,
#   'R2': 0.33751683191543874,
#   'MSPE': 3.6450674492075583},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.8176035592953363,
#   'R2': 0.33700247477856954,
#   'MSPE': 3.5976458361579318},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.7593959838151932,
#   'R2': 0.33384219480610033,
#   'MSPE': 3.3163804363346463},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.8491518080234528,
#   'R2': 0.32455044463531196,
#   'MSPE': 4.170355060786912},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.8537915180126827,
#   'R2': 0.3194690102389506,
#   'MSPE': 4.065237345945354},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.8810886243979136,
#   'R2': 0.2750301108903451,
#   'MSPE': 4.057619753811094},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.8755255669355393,
#   'R2': 0.26933561553508273,
#   'MSPE': 4.030890702599226},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.9785157740116117,
#   'R2': 0.24463289385376838,
#   'MSPE': 4.546570850705558},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.8758482327063879,
#   'R2': 0.23702679976681934,
#   'MSPE': 4.030155866698484},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.9427325000365574,
#   'R2': 0.23675419182753438,
#   'MSPE': 4.0149702748867},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 1.070193841556708,
#   'R2': 0.12369233203256318,
#   'MSPE': 4.705663178153712},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 1.0503747021158536,
#   'R2': 0.08237050758990053,
#   'MSPE': 4.5848071389841},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 1.4293131480614345,
#   'R2': -0.08108060775247869,
#   'MSPE': 5.126514029548024},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 1.4261133939027786,
#   'R2': -0.23667380788148956,
#   'MSPE': 5.350006940501808},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 1.5571848889191944,
#   'R2': -0.42851338252561905,
#   'MSPE': 5.767024894329635},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 1.70338940123717,
#   'R2': -0.47291708225112883,
#   'MSPE': 6.1881377655222565}]

# %% [markdown]
# As we can see the best parameters is 2 hidden layers with 64 nodes and a learning rate of 1e-3, a momentum of 0.9, and a weight decay of 1e-4.

# %%
train_dataset = DataLoader(TensorDataset(torch.Tensor(x_train), torch.Tensor(y_train)), batch_size=64, shuffle=True)
test_dataset = DataLoader(TensorDataset(torch.Tensor(x_test), torch.Tensor(y_test)), batch_size=64, shuffle=True)
best_model = NeuralNetwork(len(x_train[0]), 2, 64)
train_loop(train_dataset, best_model, lr=1e-3, momentum=0.9, weight_decay=1e-4, early_stopping=25)
train_results = {
    "MSE": [],
    "R2": [],
    "MSPE": []
}
test_loop(test_dataset, best_model, train_results)
print(f"Train MSE: {train_results['MSE']}")
print(f"Train R2: {train_results['R2']}")
print(f"Train MSPE: {train_results['MSPE']}")
test_result = {
    "MSE": [],
    "R2": [],
    "MSPE": []
}
test_loop(test_dataset, best_model, test_result)
print(f"Test MSE: {test_result['MSE']}")
print(f"Test R2: {test_result['R2']}")
print(f"Test MSPE: {test_result['MSPE']}")
# Out:
# Train MSE: [0.24206174165010452]
# Train R2: [0.81868693801231]
# Train MSPE: [1.2185537690917652]
# Test MSE: [0.243272602558136]
# Test R2: [0.8257231067682708]
# Test MSPE: [1.2306270386195846]

# %% [markdown]
# Another option is 1 layer 64 nodes, a learning rate of 1e-4, a momentum of 0.99 and a weight decay of 1e-3

# %%
train_dataset = DataLoader(TensorDataset(torch.Tensor(x_train), torch.Tensor(y_train)), batch_size=64, shuffle=True)
test_dataset = DataLoader(TensorDataset(torch.Tensor(x_test), torch.Tensor(y_test)), batch_size=64, shuffle=True)
best_model = NeuralNetwork(len(x_train[0]), 1, 64)
train_loop(train_dataset, best_model, lr=1e-4, momentum=0.99, weight_decay=1e-3, early_stopping=25)
train_results = {
    "MSE": [],
    "R2": [],
    "MSPE": []
}
test_loop(test_dataset, best_model, train_results)
print(f"Train MSE: {train_results['MSE']}")
print(f"Train R2: {train_results['R2']}")
print(f"Train MSPE: {train_results['MSPE']}")
test_result = {
    "MSE": [],
    "R2": [],
    "MSPE": []
}
test_loop(test_dataset, best_model, test_result)
print(f"Test MSE: {test_result['MSE']}")
print(f"Test R2: {test_result['R2']}")
print(f"Test MSPE: {test_result['MSPE']}")
# Out:
# Train MSE: [0.23476113379001617]
# Train R2: [0.8295247541712]
# Train MSPE: [1.1758846799946494]
# Test MSE: [0.2355706493059794]
# Test R2: [0.830658863855672]
# Test MSPE: [1.1940753966983821]

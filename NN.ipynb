# %%
import numpy as np
import pandas as pd
import torch
from torch import nn
from torch.utils.data import DataLoader, TensorDataset
from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import mean_squared_error, r2_score
from utils import gather_data, mean_squared_percentage_error

# %% [markdown]
# # NN Model for regression
# The goal of this model is to build and try a few variances of basic neural networks to see if they can outperform the other regression models.

# %%
data, label = gather_data()
x_train, x_test, y_train, y_test = train_test_split(data, label, test_size=0.2)
y_train, y_test = np.reshape(y_train, (len(y_train), 1)), np.reshape(y_test, (len(y_test), 1))
kfold = KFold(n_splits=10, shuffle=True)
# Out:
# Index(['Log GDP per capita', 'Social support',
#        'Healthy life expectancy at birth', 'Freedom to make life choices',
#        'Generosity', 'Perceptions of corruption', 'Positive affect',
#        'Negative affect', 'Confidence in national government'],
#       dtype='object')

# %%
class NeuralNetwork(nn.Module):
    """
      Represents a Neural Network that can be constructed with a vartiety of hidden layers.
    """
    def __init__(self, input_size, num_hidden_layers, num_nodes_per_layer):
        """
          Initializes a neural network with the specified parameters

          Args:
            input_size: The size of the input feature vector
            num_hidden_layers: The number of hidden layers in the neural network
            num_nodes_per_layer: The number of nodes in each hidden layer
        """
        super().__init__()
        # Start with intialized first layer
        hidden_layers = [nn.Linear(input_size, num_nodes_per_layer)]
        for _ in range(num_hidden_layers):
            hidden_layers.append(nn.Linear(num_nodes_per_layer, num_nodes_per_layer))
            hidden_layers.append(nn.ReLU())
        self.layers = nn.Sequential(*hidden_layers, nn.Linear(num_nodes_per_layer, 1))

    def forward(self, x):
        """
          Feeds x forward through the neural network to get the prediction

          Args:
            x: The feature vector to get the prediction from
        """
        return self.layers(x)

# %%
loss_fn = nn.MSELoss()
# The following 2 functions were built with assistance from the torch documentation which has similar functions provided.
def train_loop(dataloader, model, lr=1e-5, num_epochs=200, momentum=0.9, weight_decay: float=None):
    """
      Runs the training loop for the model.

      Args:
        dataloader: the dataloader containing the training data
        model: the model to optimize
        lr: The learning rate for the model
        num_epochs: the number of times to repeat the trianing loop
    """
    optimizer = torch.optim.SGD(model.parameters(), lr=lr, momentum=momentum, weight_decay=weight_decay)
    for epoch in range(num_epochs):
        for batch, (X, y) in enumerate(dataloader):
            # Compute prediction and loss
            pred = model(X)
            loss = loss_fn(pred, y)

            # Backpropagation
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()


def test_loop(dataloader, model, result):
    """
      Runs the test loop for the model and outputs the result to the given dictionary

      Args:
        dataloader: The data for the model to be validated on
        model: The model to test
        result: The result dictionary to store the data in.
    """
    num_batches = len(dataloader)
    test_loss, test_r2, test_mspe = 0, 0, 0

    with torch.no_grad():
        for X, y in dataloader:
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            test_r2 += r2_score(y.numpy(), pred.numpy())
            test_mspe += mean_squared_percentage_error(y.numpy(), pred.numpy())

    result["MSE"].append(test_loss / num_batches)
    result["R2"].append(test_r2 / num_batches)
    result["MSPE"].append(test_mspe / num_batches)

# %%
results = []
for num_hidden_layers in range(1, 3):
    for num_nodes_per_layer in [8, 16, 32, 64]:
        for lr in [1e-5, 1e-4, 1e-3]:
            for momentum in [.9, .99]:
                for weight_decay in [1e-5, 1e-4, 1e-3, .01, .1, .5]:
                    result = {
                        "num_hidden_layers": num_hidden_layers,
                        "num_nodes_per_layer": num_nodes_per_layer,
                        "lr": lr,
                        "momentum": momentum,
                        "weight_decay": weight_decay,
                        "MSE": [],
                        "R2": [],
                        "MSPE": []
                    }
                    for train_index, val_index in kfold.split(x_train, y_train):
                        train_dataset = DataLoader(TensorDataset(torch.Tensor(x_train[train_index]), torch.Tensor(y_train[train_index])), batch_size=64, shuffle=True)
                        val_dataset= DataLoader(TensorDataset(torch.Tensor(x_train[val_index]), torch.Tensor(y_train[val_index])), batch_size=64, shuffle=True)
                        model = NeuralNetwork(len(x_train[0]), num_hidden_layers=num_hidden_layers, num_nodes_per_layer=num_nodes_per_layer)
                        train_loop(train_dataset, model, lr=lr, momentum=momentum, weight_decay=weight_decay)
                        test_loop(val_dataset, model, result)            
                    result["MSE"] = np.mean(result["MSE"])
                    result["R2"] = np.mean(result["R2"])
                    result["MSPE"] = np.mean(result["MSPE"])
                    results.append(result)

# %%
results
# Out:
# [{'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.799657600124677,
#   'R2': 0.35195948065992944,
#   'MSPE': 3.717631917785515},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.731444752216339,
#   'R2': 0.36962275136745115,
#   'MSPE': 3.2832924334915594},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.7985026687383653,
#   'R2': 0.3657095609433454,
#   'MSPE': 3.7992639589415056},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.834874893228213,
#   'R2': 0.33734324741039157,
#   'MSPE': 4.061007521143464},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.7979643791913986,
#   'R2': 0.36092843165321037,
#   'MSPE': 3.544346478701842},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.7994200060764949,
#   'R2': 0.36317078290219723,
#   'MSPE': 3.645495882239004},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.28502286349733674,
#   'R2': 0.7749844813233813,
#   'MSPE': 1.3827550069739423},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.4250790784756342,
#   'R2': 0.6532139506678599,
#   'MSPE': 2.1940008806760867},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.3117434139053027,
#   'R2': 0.7344550230384177,
#   'MSPE': 1.47856585526218},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.3023149069398642,
#   'R2': 0.7669110106413076,
#   'MSPE': 1.538510936397043},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.4480434621373813,
#   'R2': 0.6109681910797035,
#   'MSPE': 1.9761659312203073},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.7456709414720535,
#   'R2': 0.2566355901728984,
#   'MSPE': 2.93664596702038},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.28549681132038435,
#   'R2': 0.7663400899009077,
#   'MSPE': 1.3635253826758325},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.3027765606840451,
#   'R2': 0.7409961417852426,
#   'MSPE': 1.4575514575993322},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.29848538786172873,
#   'R2': 0.7613442534321583,
#   'MSPE': 1.5363186378634035},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.32145369897286097,
#   'R2': 0.7627597007291241,
#   'MSPE': 1.7227853947516643},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.32898550281922023,
#   'R2': 0.7134604979499425,
#   'MSPE': 1.6148586157295441},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.4705908089876175,
#   'R2': 0.6496656870299197,
#   'MSPE': 2.0967586421304274},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.27282808944582937,
#   'R2': 0.7677444666908577,
#   'MSPE': 1.3109506813414167},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.37398272429903345,
#   'R2': 0.7180507791196873,
#   'MSPE': 1.8409495960187279},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.2754231356084347,
#   'R2': 0.753238613349916,
#   'MSPE': 1.4197595584479095},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.2602493308484554,
#   'R2': 0.7929133963217039,
#   'MSPE': 1.3037600384253745},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.2903949258228143,
#   'R2': 0.7579398308563459,
#   'MSPE': 1.378628080710769},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.4311572194099426,
#   'R2': 0.6359343523058393,
#   'MSPE': 2.02206024655489},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.27776859452327096,
#   'R2': 0.7584492434343383,
#   'MSPE': 1.3419079704379493},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.26196660771965985,
#   'R2': 0.7889922393101099,
#   'MSPE': 1.2287132529485407},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.2594819441437721,
#   'R2': 0.7828930532318557,
#   'MSPE': 1.229615755887194},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.2595063142478466,
#   'R2': 0.7945813416544028,
#   'MSPE': 1.276474629735781},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.2893469471484423,
#   'R2': 0.7608961049855102,
#   'MSPE': 1.4319452370582808},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.45874808828035984,
#   'R2': 0.6395635710111991,
#   'MSPE': 2.04168706172795},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.296022700270017,
#   'R2': 0.7609767081506581,
#   'MSPE': 1.4466619267683438},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.38531139741341275,
#   'R2': 0.7030048479965946,
#   'MSPE': 1.8559707827264007},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.4000055799881618,
#   'R2': 0.6767503137155642,
#   'MSPE': 1.879137455852646},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.3018665621678035,
#   'R2': 0.7426690660535163,
#   'MSPE': 1.4555761727946572},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.32024055620034536,
#   'R2': 0.7462726170449305,
#   'MSPE': 1.488830805050604},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.45004051029682157,
#   'R2': 0.6302205598609402,
#   'MSPE': 2.1221821076904583},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.7588237921396892,
#   'R2': 0.3922096746228053,
#   'MSPE': 3.3533475149159484},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.8198743318518004,
#   'R2': 0.4160871625619514,
#   'MSPE': 3.9275342340797486},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.7748069018125534,
#   'R2': 0.39149447480428623,
#   'MSPE': 3.6107983746838683},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.7577393780152003,
#   'R2': 0.38083785879871773,
#   'MSPE': 3.769696874901501},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.823721069097519,
#   'R2': 0.35343199498840344,
#   'MSPE': 4.0277277078065605},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.7897635211547216,
#   'R2': 0.37357815937099803,
#   'MSPE': 3.37783802187804},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.29807895968357717,
#   'R2': 0.7753797580428341,
#   'MSPE': 1.6185301083205927},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.29003446549177164,
#   'R2': 0.7432972395430488,
#   'MSPE': 1.4272968095699041},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.29301765486598014,
#   'R2': 0.7639536773919721,
#   'MSPE': 1.4163451724582248},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.30340314358472825,
#   'R2': 0.7627399226763801,
#   'MSPE': 1.5231213956657386},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.32912650307019553,
#   'R2': 0.7614556795251858,
#   'MSPE': 1.8142933439406932},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.4647263740499814,
#   'R2': 0.5895171699546476,
#   'MSPE': 2.116318938576362},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.29910290986299515,
#   'R2': 0.7588472147238206,
#   'MSPE': 1.5090408703933158},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.26758162230253213,
#   'R2': 0.7837206897988658,
#   'MSPE': 1.272755952015745},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.28269588227073356,
#   'R2': 0.7651273047569798,
#   'MSPE': 1.351887843091831},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.2846295493344466,
#   'R2': 0.7538568883482091,
#   'MSPE': 1.389501015984952},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.32521299769481027,
#   'R2': 0.7225249982607047,
#   'MSPE': 1.5175721851751358},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.47152088880538934,
#   'R2': 0.6295151134579935,
#   'MSPE': 2.1024166451146202},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.2740340371926625,
#   'R2': 0.7905713973395502,
#   'MSPE': 1.392910582380313},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.26501514116923014,
#   'R2': 0.7806856070101187,
#   'MSPE': 1.2330778754043459},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.2506446448465188,
#   'R2': 0.7983765996065273,
#   'MSPE': 1.2304265363932108},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.2693892215689023,
#   'R2': 0.7817681852960481,
#   'MSPE': 1.4120417441984618},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.30319260209798815,
#   'R2': 0.7445021513289424,
#   'MSPE': 1.4839347759543944},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.44426874170700714,
#   'R2': 0.6422988670445852,
#   'MSPE': 1.9381446752584341},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.2713801657160123,
#   'R2': 0.7678303609553383,
#   'MSPE': 1.3092095997523177},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.2749744353195031,
#   'R2': 0.7758579886129205,
#   'MSPE': 1.4086662948300892},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.2778806644181411,
#   'R2': 0.7801420964119176,
#   'MSPE': 1.3708118116012726},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.2845170016090075,
#   'R2': 0.7632120016306171,
#   'MSPE': 1.4464108577713068},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.2769751712679863,
#   'R2': 0.7709054317007139,
#   'MSPE': 1.385451846219825},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.45706204921007154,
#   'R2': 0.6390824776624349,
#   'MSPE': 2.293834581670135},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.263533745209376,
#   'R2': 0.7795351082133672,
#   'MSPE': 1.2289734068091471},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.25988315542538964,
#   'R2': 0.744727258501246,
#   'MSPE': 1.2441724252350854},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.29483399515350656,
#   'R2': 0.7643813401809725,
#   'MSPE': 1.5065835151501525},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.3095828354358673,
#   'R2': 0.7536154173678062,
#   'MSPE': 1.586517643823166},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.3125371073683103,
#   'R2': 0.7464168248777988,
#   'MSPE': 1.5073832927854975},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.4284628530343374,
#   'R2': 0.6602075686551119,
#   'MSPE': 1.9733027788349475},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.7067190835873285,
#   'R2': 0.4475203102844315,
#   'MSPE': 3.26484136640875},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.7213774532079696,
#   'R2': 0.3963048809845563,
#   'MSPE': 3.2799030640962146},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.7518828709920247,
#   'R2': 0.44131521000515866,
#   'MSPE': 3.8883332672971065},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.7053125749031703,
#   'R2': 0.4516785799186345,
#   'MSPE': 3.279779487374154},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.7106104383865993,
#   'R2': 0.4460703683850051,
#   'MSPE': 3.616728818213397},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.7293190707763035,
#   'R2': 0.43556720588698716,
#   'MSPE': 3.1565291682879133},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.27991044223308564,
#   'R2': 0.7820418599306896,
#   'MSPE': 1.4070197290769129},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.28910935024420426,
#   'R2': 0.7699796700762043,
#   'MSPE': 1.428145904451458},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.2882610142230988,
#   'R2': 0.7774642111073204,
#   'MSPE': 1.3723877591617177},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.2805297742287318,
#   'R2': 0.7731779768089629,
#   'MSPE': 1.3489376115753795},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.29753111600875853,
#   'R2': 0.7514823069029432,
#   'MSPE': 1.507330619626575},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.42839206258455914,
#   'R2': 0.6302891692645708,
#   'MSPE': 1.9111430564086245},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.3016659771402677,
#   'R2': 0.7589050920285614,
#   'MSPE': 1.4357418427714195},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.300042470296224,
#   'R2': 0.762406664182919,
#   'MSPE': 1.4645918513732876},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.28239888648192085,
#   'R2': 0.7728365436703533,
#   'MSPE': 1.409796697529729},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.2733822951714198,
#   'R2': 0.7735240647720819,
#   'MSPE': 1.345546410014533},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.33138082375129063,
#   'R2': 0.7541582965956768,
#   'MSPE': 1.8183077789955966},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.49015434086322773,
#   'R2': 0.628840996575768,
#   'MSPE': 2.263260901143605},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.27065055295825,
#   'R2': 0.7833456641123868,
#   'MSPE': 1.3101160232767914},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.27619986434777577,
#   'R2': 0.7689213478277667,
#   'MSPE': 1.3354191753185458},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.25473053610573215,
#   'R2': 0.794440453405199,
#   'MSPE': 1.2939848989775087},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.2621939900020758,
#   'R2': 0.76943737008437,
#   'MSPE': 1.2265134247659586},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.2951213824252287,
#   'R2': 0.7686991050831955,
#   'MSPE': 1.4411842011178684},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.4301193316777547,
#   'R2': 0.644495101360657,
#   'MSPE': 1.9158042637123303},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.2772100791335106,
#   'R2': 0.7843049499601278,
#   'MSPE': 1.3679403310284168},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.28964495708545046,
#   'R2': 0.7638223533439736,
#   'MSPE': 1.3567366800976521},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.25155347883701323,
#   'R2': 0.7972170207097122,
#   'MSPE': 1.1931831303588818},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.3027466177940369,
#   'R2': 0.749902455222081,
#   'MSPE': 1.4833057983166942},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.30525121837854385,
#   'R2': 0.775999138819487,
#   'MSPE': 1.5956826402213085},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.45297691126664474,
#   'R2': 0.651383812180159,
#   'MSPE': 2.194176060288693},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.24595479071140286,
#   'R2': 0.8023366878708164,
#   'MSPE': 1.124330551053087},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.3809875200192133,
#   'R2': 0.6787108031939695,
#   'MSPE': 1.7442218522362487},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.26740745703379315,
#   'R2': 0.7897616043294586,
#   'MSPE': 1.3411325516386163},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.2671100810170174,
#   'R2': 0.7726626691785528,
#   'MSPE': 1.2856849691256729},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.2963208551208178,
#   'R2': 0.763174853987027,
#   'MSPE': 1.3810707592979223},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.4503666400909424,
#   'R2': 0.6473791957545906,
#   'MSPE': 2.1145938826969477},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.597658692797025,
#   'R2': 0.4382247373360504,
#   'MSPE': 2.839816124601797},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.649456025660038,
#   'R2': 0.4632893410125921,
#   'MSPE': 3.032410670673907},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.6823183645804722,
#   'R2': 0.455857616056372,
#   'MSPE': 3.247602889972805},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.6916021804014842,
#   'R2': 0.46370796858570174,
#   'MSPE': 3.1567465290050913},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.6567176813880603,
#   'R2': 0.4540764122905923,
#   'MSPE': 3.03206842392683},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.6827344059944153,
#   'R2': 0.4510049947987569,
#   'MSPE': 3.1275318931750578},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.2857664793729782,
#   'R2': 0.7258678640385405,
#   'MSPE': 1.3891917544727523},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.29356119756897286,
#   'R2': 0.7799717810050282,
#   'MSPE': 1.5331776501291026},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.2830239887038867,
#   'R2': 0.7647980570412128,
#   'MSPE': 1.4296707039642513},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.2831806192795435,
#   'R2': 0.775993652855824,
#   'MSPE': 1.3742164754769717},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.3060897794862588,
#   'R2': 0.7603088186666276,
#   'MSPE': 1.4700870570547955},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.4348634476463,
#   'R2': 0.6397951657224352,
#   'MSPE': 1.868411344052716},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.29410530974467597,
#   'R2': 0.7779909729054189,
#   'MSPE': 1.5332007248218011},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.2975043639540672,
#   'R2': 0.7649283584282733,
#   'MSPE': 1.4644881042962274},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.2729325282076994,
#   'R2': 0.7821852771037662,
#   'MSPE': 1.3162129462668388},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.3064796194434166,
#   'R2': 0.7391778687681062,
#   'MSPE': 1.4770341530969047},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.30845226980745793,
#   'R2': 0.7589915715301165,
#   'MSPE': 1.7582312801081426},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.4416759456197421,
#   'R2': 0.6345626346350294,
#   'MSPE': 2.034074834576159},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.2637303108970324,
#   'R2': 0.791051482224695,
#   'MSPE': 1.5107351833145426},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.25389389966924986,
#   'R2': 0.8053059077915761,
#   'MSPE': 1.3613589903377372},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.24179739902416864,
#   'R2': 0.7988074525832575,
#   'MSPE': 1.1475948895318342},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.2617567295829455,
#   'R2': 0.7902903156741765,
#   'MSPE': 1.3349809800980217},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.28367648099859555,
#   'R2': 0.7629121300759734,
#   'MSPE': 1.5235031390976572},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.43219280739625293,
#   'R2': 0.6194066393609239,
#   'MSPE': 2.010144862920196},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.2696192319194476,
#   'R2': 0.7707688345528572,
#   'MSPE': 1.3329143191433763},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.26237845346331595,
#   'R2': 0.7774877405319632,
#   'MSPE': 1.2781992433310456},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.27287237296501793,
#   'R2': 0.7617550651940388,
#   'MSPE': 1.3478364330725838},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.2655252975722154,
#   'R2': 0.779175331430638,
#   'MSPE': 1.3079666388644413},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.28770705113808315,
#   'R2': 0.7654073138855184,
#   'MSPE': 1.3914631188122761},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.4414255579312642,
#   'R2': 0.6482699640202266,
#   'MSPE': 1.9991742537328687},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.29080882569154104,
#   'R2': 0.7699677240790381,
#   'MSPE': 1.3771719779029037},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.2782337158918381,
#   'R2': 0.7823095477884776,
#   'MSPE': 1.3726427218867372},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.2671753533184528,
#   'R2': 0.7882687041456474,
#   'MSPE': 1.2889513946279432},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.289445306857427,
#   'R2': 0.7760421535568992,
#   'MSPE': 1.5191865632912578},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.31302792876958846,
#   'R2': 0.742102432646894,
#   'MSPE': 1.5424525109354894},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.5253416503469148,
#   'R2': 0.5887863580370272,
#   'MSPE': 2.253596870924788},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 1.4321367412805555,
#   'R2': -0.08477738604836094,
#   'MSPE': 5.2990526382369225},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 1.6100392798582714,
#   'R2': -0.7381374316517919,
#   'MSPE': 5.979180212386629},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.92901251912117,
#   'R2': 0.22735840193263696,
#   'MSPE': 4.275904610339138},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.9089627693096796,
#   'R2': 0.23169333514240836,
#   'MSPE': 4.367639568794255},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.9007911771535874,
#   'R2': 0.2615862562344704,
#   'MSPE': 4.0547895337445565},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 1.6239945193131764,
#   'R2': -0.40556285525984065,
#   'MSPE': 5.74983229220967},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.31554756437738735,
#   'R2': 0.7581768454779664,
#   'MSPE': 1.5912490759534066},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.32613306393225994,
#   'R2': 0.7434092327631092,
#   'MSPE': 1.7882989176708939},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.33969745884339014,
#   'R2': 0.7272324076120489,
#   'MSPE': 1.710096906983491},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.363151178508997,
#   'R2': 0.7119892557479321,
#   'MSPE': 1.8334532496190132},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.406668188671271,
#   'R2': 0.6858775941332735,
#   'MSPE': 2.0472818420202743},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.7116223757465681,
#   'R2': 0.41532799065081616,
#   'MSPE': 2.721169727638063},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.3715747019896905,
#   'R2': 0.6883619442120779,
#   'MSPE': 1.7462962705670209},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.2912033617496491,
#   'R2': 0.7686282533216582,
#   'MSPE': 1.4421901096956746},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.40485878239075346,
#   'R2': 0.6503403602819342,
#   'MSPE': 2.288221434097398},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.3844356859723727,
#   'R2': 0.6754092512317824,
#   'MSPE': 1.8865399572509105},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.32526632323861127,
#   'R2': 0.7262440448114293,
#   'MSPE': 1.6260370643188555},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.47508893708388006,
#   'R2': 0.642711353465008,
#   'MSPE': 2.2312704918699136},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.5840617015957832,
#   'R2': 0.5490259245176401,
#   'MSPE': 2.7698847438876677},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.6025374017655849,
#   'R2': 0.529785141868641,
#   'MSPE': 2.771993604055935},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.3744300251205762,
#   'R2': 0.6696588551565095,
#   'MSPE': 1.767327913054914},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.5909742047389348,
#   'R2': 0.5013481533004612,
#   'MSPE': 2.6784246138325245},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.39067422822117803,
#   'R2': 0.6841151482533165,
#   'MSPE': 1.9878891688028368},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.40926477760076524,
#   'R2': 0.6567590520310784,
#   'MSPE': 1.8144229204967766},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.2827557894090812,
#   'R2': 0.7560493239373798,
#   'MSPE': 1.4022249306053522},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.2404098773996035,
#   'R2': 0.8012343042894294,
#   'MSPE': 1.134895604207284},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.3777700061599414,
#   'R2': 0.7052857304251626,
#   'MSPE': 1.6226647478161436},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.28150139624873793,
#   'R2': 0.7593557642105955,
#   'MSPE': 1.327762081184321},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.38627403005957606,
#   'R2': 0.6940945961492588,
#   'MSPE': 1.9000020926122112},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.4589261998732884,
#   'R2': 0.6500684235108416,
#   'MSPE': 2.016017379972971},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.8003893246253332,
#   'R2': 0.3958722088380873,
#   'MSPE': 3.7321615540845827},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.7441457649072012,
#   'R2': 0.4387268411614995,
#   'MSPE': 3.4609729107093026},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.8249856323003769,
#   'R2': 0.36374314087276816,
#   'MSPE': 3.9023106974653077},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.38637675344944,
#   'R2': 0.6823239628255131,
#   'MSPE': 1.7773297391455583},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.3166745555897554,
#   'R2': 0.7486780565998096,
#   'MSPE': 1.6164247297465502},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.5021865497032801,
#   'R2': 0.5815959604694143,
#   'MSPE': 2.4639973655869865},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.8413724899291992,
#   'R2': 0.32313539855706674,
#   'MSPE': 4.061040838220806},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.8026615450779598,
#   'R2': 0.31735470813963185,
#   'MSPE': 3.8644608140292798},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.8437059362729389,
#   'R2': 0.3672927293855107,
#   'MSPE': 3.8948937774532366},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.8168476104736329,
#   'R2': 0.35013682449084693,
#   'MSPE': 3.700772511274225},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.908054401477178,
#   'R2': 0.29315135456246527,
#   'MSPE': 4.457280762644126},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.8828014552593231,
#   'R2': 0.25961087788744613,
#   'MSPE': 3.9508229642730166},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.2794936214884122,
#   'R2': 0.7217634744948433,
#   'MSPE': 1.3227818705931758},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.282745744784673,
#   'R2': 0.7729635300603197,
#   'MSPE': 1.3514231438889648},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.30709871699412666,
#   'R2': 0.7591623306231001,
#   'MSPE': 1.5241024418348315},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.29665093968311945,
#   'R2': 0.7340936546740113,
#   'MSPE': 1.3974195218296965},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.31792002320289614,
#   'R2': 0.745793976377909,
#   'MSPE': 1.648921597316259},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.4662171299258868,
#   'R2': 0.6395712337092079,
#   'MSPE': 2.1514571963273212},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.27155601407090824,
#   'R2': 0.780572698754054,
#   'MSPE': 1.3579931003841188},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.2889571641882261,
#   'R2': 0.7632074181028526,
#   'MSPE': 1.4568007089235266},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.2844847204784552,
#   'R2': 0.7611772784725934,
#   'MSPE': 1.4048441540393415},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.29685406287511185,
#   'R2': 0.7453840051019768,
#   'MSPE': 1.4480542442808397},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.3048142979542414,
#   'R2': 0.7618521832203669,
#   'MSPE': 1.5301205526397683},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.44637625217437743,
#   'R2': 0.6270922106433785,
#   'MSPE': 1.9776161642500543},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.2628722570836544,
#   'R2': 0.7990372234779104,
#   'MSPE': 1.2858133061290389},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.2579621774454911,
#   'R2': 0.7892542583847522,
#   'MSPE': 1.2500045869047895},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.24524316365520163,
#   'R2': 0.8055668565921076,
#   'MSPE': 1.235798517655995},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.24934231961766878,
#   'R2': 0.8038193457407863,
#   'MSPE': 1.2034694337747012},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.27268678322434425,
#   'R2': 0.765531272764185,
#   'MSPE': 1.2612571832582806},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.4415686304370562,
#   'R2': 0.6604402932987796,
#   'MSPE': 2.165168063113033},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.24960130328933397,
#   'R2': 0.8009442186013611,
#   'MSPE': 1.2201073328785674},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.2588117467860381,
#   'R2': 0.785354790201129,
#   'MSPE': 1.319009717930146},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.2688115251561006,
#   'R2': 0.794879585491372,
#   'MSPE': 1.3390204682005475},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.2767342823247115,
#   'R2': 0.789503008310801,
#   'MSPE': 1.3670171999532466},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.27524286756912864,
#   'R2': 0.7823243257976618,
#   'MSPE': 1.4616717302212208},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.44866751730442045,
#   'R2': 0.6413570758348793,
#   'MSPE': 1.990584611158931},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.7582832728823027,
#   'R2': 0.43272574938045094,
#   'MSPE': 3.661599911354257},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.5392169366280237,
#   'R2': 0.5351056357876377,
#   'MSPE': 2.2783516494162153},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.48980168998241425,
#   'R2': 0.6162194837312244,
#   'MSPE': 2.2201640327282326},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.38415802667538324,
#   'R2': 0.6954491214154902,
#   'MSPE': 1.9017782093336184},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.3377794983486334,
#   'R2': 0.7060714512745762,
#   'MSPE': 1.62920952134888},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.5148663739363352,
#   'R2': 0.6043587122074383,
#   'MSPE': 2.1768699332394386},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.7400863369305928,
#   'R2': 0.36534623260375126,
#   'MSPE': 3.397947091496352},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.7532866477966309,
#   'R2': 0.3620559395121279,
#   'MSPE': 3.821654886647005},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.7347439467906952,
#   'R2': 0.4179896734568853,
#   'MSPE': 3.302255980482306},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.7963020692269007,
#   'R2': 0.3821138190186051,
#   'MSPE': 3.7201893707793774},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.8167677313089371,
#   'R2': 0.37275316896495025,
#   'MSPE': 3.628872503724062},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.7991077899932861,
#   'R2': 0.38133123249171674,
#   'MSPE': 3.4637555058556373},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.3041602524618308,
#   'R2': 0.7508849704393616,
#   'MSPE': 1.5096706579053643},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.3102686847249667,
#   'R2': 0.7326758022338595,
#   'MSPE': 1.4979881654973284},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.2917321746548017,
#   'R2': 0.7751428070031798,
#   'MSPE': 1.4529626635420656},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.30435536106427513,
#   'R2': 0.7615687254208896,
#   'MSPE': 1.5467808192426509},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.3125571007529894,
#   'R2': 0.7355083754969973,
#   'MSPE': 1.5694651403229194},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.4578676601250967,
#   'R2': 0.6363446484912455,
#   'MSPE': 2.312441025531352},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.3069748232762019,
#   'R2': 0.7396011895437963,
#   'MSPE': 1.5388952302887584},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.27734999905029933,
#   'R2': 0.7657376326254138,
#   'MSPE': 1.3241857993933892},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.29174794803063075,
#   'R2': 0.7635219191267038,
#   'MSPE': 1.4281471570803208},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.2594859143098195,
#   'R2': 0.7811128165177479,
#   'MSPE': 1.2316726961859847},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.29884799271821977,
#   'R2': 0.7672498013436165,
#   'MSPE': 1.438353167884428},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.41267205874125157,
#   'R2': 0.6674315300182938,
#   'MSPE': 1.844256440779627},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.24592373023430505,
#   'R2': 0.7835359186056442,
#   'MSPE': 1.2364357357581306},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.26220664059122406,
#   'R2': 0.7780490843016016,
#   'MSPE': 1.260781326669861},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.26150365695357325,
#   'R2': 0.7721351322247765,
#   'MSPE': 1.4054120723346266},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.24360507925351457,
#   'R2': 0.7916911330100422,
#   'MSPE': 1.1703230074672688},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.285750196625789,
#   'R2': 0.7531526886310899,
#   'MSPE': 1.3706409492802742},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.46264517754316337,
#   'R2': 0.6464432876918137,
#   'MSPE': 2.1650719344427793},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.28110905687014265,
#   'R2': 0.7787857874910674,
#   'MSPE': 1.3926758320832793},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.26130985071261725,
#   'R2': 0.7866830450826708,
#   'MSPE': 1.4007923495250219},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.26052938699722283,
#   'R2': 0.7942117515097082,
#   'MSPE': 1.2963024609618716},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.26000726235409577,
#   'R2': 0.79365550869305,
#   'MSPE': 1.2355981966612315},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.2820359321931998,
#   'R2': 0.7726949204681958,
#   'MSPE': 1.552962259191907},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.41114200601975115,
#   'R2': 0.6619659545837948,
#   'MSPE': 2.0224800567622436},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.47286451011896136,
#   'R2': 0.6145001401819605,
#   'MSPE': 2.1125129473894235},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.25606470356384914,
#   'R2': 0.7805668686984107,
#   'MSPE': 1.2285431898716423},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.2709246243039766,
#   'R2': 0.7846382580118955,
#   'MSPE': 1.3262840902733832},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.2933815722664197,
#   'R2': 0.747455290720223,
#   'MSPE': 1.5645736220264523},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.3232345744967461,
#   'R2': 0.7336262529061267,
#   'MSPE': 1.5801594076170162},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.509281707306703,
#   'R2': 0.6188551082413813,
#   'MSPE': 2.369827693986772},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.6858494758605957,
#   'R2': 0.4587739062351829,
#   'MSPE': 3.4777187823195645},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.6538053343693416,
#   'R2': 0.4694974286184575,
#   'MSPE': 3.1333248241983283},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.7014575223128001,
#   'R2': 0.4433013406277391,
#   'MSPE': 3.164128945632414},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.6310153678059578,
#   'R2': 0.4888210065358779,
#   'MSPE': 3.051843547045883},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.6313829878966015,
#   'R2': 0.4684759164454723,
#   'MSPE': 3.1170337933181513},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.7099995225667952,
#   'R2': 0.4294669159654232,
#   'MSPE': 3.032244655181362},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.26985983873407043,
#   'R2': 0.7712878925776252,
#   'MSPE': 1.2874182846133757},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.2793601180116335,
#   'R2': 0.7665240706122665,
#   'MSPE': 1.330687926677667},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.30620518078406656,
#   'R2': 0.7515001633402438,
#   'MSPE': 1.562529788822914},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.2794594749808311,
#   'R2': 0.7710207148280568,
#   'MSPE': 1.3425280131173856},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.30313380410273866,
#   'R2': 0.7540976204085146,
#   'MSPE': 1.7415167590734935},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.4322373688220978,
#   'R2': 0.6392281566125736,
#   'MSPE': 1.973438321923216},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.2730562870701155,
#   'R2': 0.7703858553910004,
#   'MSPE': 1.3019384644605747},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.2901363134384155,
#   'R2': 0.7509405327848513,
#   'MSPE': 1.532963368750055},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.2912599618236224,
#   'R2': 0.7733081416736084,
#   'MSPE': 1.404899824316604},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.2802714124321938,
#   'R2': 0.7219487986632821,
#   'MSPE': 1.3036934613729967},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.295318204164505,
#   'R2': 0.7570110510455691,
#   'MSPE': 1.4950846734390866},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.4401061276594797,
#   'R2': 0.6464124219914226,
#   'MSPE': 1.967376135289669},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.2467856084307035,
#   'R2': 0.7986206648504259,
#   'MSPE': 1.2244813989452792},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.24271518141031265,
#   'R2': 0.799364937474935,
#   'MSPE': 1.2152017948377611},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.2713289012511571,
#   'R2': 0.7359271400017835,
#   'MSPE': 1.2805388367857145},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.24949195956190434,
#   'R2': 0.7984797005915408,
#   'MSPE': 1.1885108482657056},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.2954540277520815,
#   'R2': 0.758360549355068,
#   'MSPE': 1.4573314816060692},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.43170132239659625,
#   'R2': 0.6677030706810834,
#   'MSPE': 2.158540570073657},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.2356918546060721,
#   'R2': 0.8087246579994825,
#   'MSPE': 1.1024457791989501},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.2628365526596705,
#   'R2': 0.7941046845303515,
#   'MSPE': 1.2510084892350313},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.2442339204251766,
#   'R2': 0.7955760849715283,
#   'MSPE': 1.1281111574910507},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.27388175278902055,
#   'R2': 0.7899794734480692,
#   'MSPE': 1.4266821247233885},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.2840855787197748,
#   'R2': 0.7555150882518168,
#   'MSPE': 1.4891710276292127},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.4152277385195096,
#   'R2': 0.6548758742529796,
#   'MSPE': 1.9552308861918821},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.23920444659888748,
#   'R2': 0.7917996216679747,
#   'MSPE': 1.1408100749431838},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.35730211759607,
#   'R2': 0.6939170058423553,
#   'MSPE': 1.584587558831154},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.25074586371580765,
#   'R2': 0.7941837177674484,
#   'MSPE': 1.2287741669011534},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.30619512175520264,
#   'R2': 0.7310997809394583,
#   'MSPE': 1.4637798389344654},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.3117224626243114,
#   'R2': 0.7200390372731802,
#   'MSPE': 1.5294008007781073},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.4539195388555527,
#   'R2': 0.6425400837698135,
#   'MSPE': 2.0007981223552815}]

# %%
# Sort by lowest MSE
sorted(results, key=lambda x: x["MSE"])
# Out:
# [{'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.2356918546060721,
#   'R2': 0.8087246579994825,
#   'MSPE': 1.1024457791989501},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.23920444659888748,
#   'R2': 0.7917996216679747,
#   'MSPE': 1.1408100749431838},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.2404098773996035,
#   'R2': 0.8012343042894294,
#   'MSPE': 1.134895604207284},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.24179739902416864,
#   'R2': 0.7988074525832575,
#   'MSPE': 1.1475948895318342},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.24271518141031265,
#   'R2': 0.799364937474935,
#   'MSPE': 1.2152017948377611},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.24360507925351457,
#   'R2': 0.7916911330100422,
#   'MSPE': 1.1703230074672688},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.2442339204251766,
#   'R2': 0.7955760849715283,
#   'MSPE': 1.1281111574910507},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.24524316365520163,
#   'R2': 0.8055668565921076,
#   'MSPE': 1.235798517655995},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.24592373023430505,
#   'R2': 0.7835359186056442,
#   'MSPE': 1.2364357357581306},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.24595479071140286,
#   'R2': 0.8023366878708164,
#   'MSPE': 1.124330551053087},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.2467856084307035,
#   'R2': 0.7986206648504259,
#   'MSPE': 1.2244813989452792},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.24934231961766878,
#   'R2': 0.8038193457407863,
#   'MSPE': 1.2034694337747012},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.24949195956190434,
#   'R2': 0.7984797005915408,
#   'MSPE': 1.1885108482657056},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.24960130328933397,
#   'R2': 0.8009442186013611,
#   'MSPE': 1.2201073328785674},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.2506446448465188,
#   'R2': 0.7983765996065273,
#   'MSPE': 1.2304265363932108},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.25074586371580765,
#   'R2': 0.7941837177674484,
#   'MSPE': 1.2287741669011534},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.25155347883701323,
#   'R2': 0.7972170207097122,
#   'MSPE': 1.1931831303588818},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.25389389966924986,
#   'R2': 0.8053059077915761,
#   'MSPE': 1.3613589903377372},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.25473053610573215,
#   'R2': 0.794440453405199,
#   'MSPE': 1.2939848989775087},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.25606470356384914,
#   'R2': 0.7805668686984107,
#   'MSPE': 1.2285431898716423},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.2579621774454911,
#   'R2': 0.7892542583847522,
#   'MSPE': 1.2500045869047895},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.2588117467860381,
#   'R2': 0.785354790201129,
#   'MSPE': 1.319009717930146},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.2594819441437721,
#   'R2': 0.7828930532318557,
#   'MSPE': 1.229615755887194},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.2594859143098195,
#   'R2': 0.7811128165177479,
#   'MSPE': 1.2316726961859847},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.2595063142478466,
#   'R2': 0.7945813416544028,
#   'MSPE': 1.276474629735781},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.25988315542538964,
#   'R2': 0.744727258501246,
#   'MSPE': 1.2441724252350854},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.26000726235409577,
#   'R2': 0.79365550869305,
#   'MSPE': 1.2355981966612315},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.2602493308484554,
#   'R2': 0.7929133963217039,
#   'MSPE': 1.3037600384253745},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.26052938699722283,
#   'R2': 0.7942117515097082,
#   'MSPE': 1.2963024609618716},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.26130985071261725,
#   'R2': 0.7866830450826708,
#   'MSPE': 1.4007923495250219},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.26150365695357325,
#   'R2': 0.7721351322247765,
#   'MSPE': 1.4054120723346266},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.2617567295829455,
#   'R2': 0.7902903156741765,
#   'MSPE': 1.3349809800980217},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.26196660771965985,
#   'R2': 0.7889922393101099,
#   'MSPE': 1.2287132529485407},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.2621939900020758,
#   'R2': 0.76943737008437,
#   'MSPE': 1.2265134247659586},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.26220664059122406,
#   'R2': 0.7780490843016016,
#   'MSPE': 1.260781326669861},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.26237845346331595,
#   'R2': 0.7774877405319632,
#   'MSPE': 1.2781992433310456},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.2628365526596705,
#   'R2': 0.7941046845303515,
#   'MSPE': 1.2510084892350313},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.2628722570836544,
#   'R2': 0.7990372234779104,
#   'MSPE': 1.2858133061290389},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.263533745209376,
#   'R2': 0.7795351082133672,
#   'MSPE': 1.2289734068091471},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.2637303108970324,
#   'R2': 0.791051482224695,
#   'MSPE': 1.5107351833145426},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.26501514116923014,
#   'R2': 0.7806856070101187,
#   'MSPE': 1.2330778754043459},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.2655252975722154,
#   'R2': 0.779175331430638,
#   'MSPE': 1.3079666388644413},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.2671100810170174,
#   'R2': 0.7726626691785528,
#   'MSPE': 1.2856849691256729},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.2671753533184528,
#   'R2': 0.7882687041456474,
#   'MSPE': 1.2889513946279432},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.26740745703379315,
#   'R2': 0.7897616043294586,
#   'MSPE': 1.3411325516386163},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.26758162230253213,
#   'R2': 0.7837206897988658,
#   'MSPE': 1.272755952015745},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.2688115251561006,
#   'R2': 0.794879585491372,
#   'MSPE': 1.3390204682005475},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.2693892215689023,
#   'R2': 0.7817681852960481,
#   'MSPE': 1.4120417441984618},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.2696192319194476,
#   'R2': 0.7707688345528572,
#   'MSPE': 1.3329143191433763},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.26985983873407043,
#   'R2': 0.7712878925776252,
#   'MSPE': 1.2874182846133757},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.27065055295825,
#   'R2': 0.7833456641123868,
#   'MSPE': 1.3101160232767914},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.2709246243039766,
#   'R2': 0.7846382580118955,
#   'MSPE': 1.3262840902733832},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.2713289012511571,
#   'R2': 0.7359271400017835,
#   'MSPE': 1.2805388367857145},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.2713801657160123,
#   'R2': 0.7678303609553383,
#   'MSPE': 1.3092095997523177},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.27155601407090824,
#   'R2': 0.780572698754054,
#   'MSPE': 1.3579931003841188},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.27268678322434425,
#   'R2': 0.765531272764185,
#   'MSPE': 1.2612571832582806},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.27282808944582937,
#   'R2': 0.7677444666908577,
#   'MSPE': 1.3109506813414167},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.27287237296501793,
#   'R2': 0.7617550651940388,
#   'MSPE': 1.3478364330725838},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.2729325282076994,
#   'R2': 0.7821852771037662,
#   'MSPE': 1.3162129462668388},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.2730562870701155,
#   'R2': 0.7703858553910004,
#   'MSPE': 1.3019384644605747},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.2733822951714198,
#   'R2': 0.7735240647720819,
#   'MSPE': 1.345546410014533},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.27388175278902055,
#   'R2': 0.7899794734480692,
#   'MSPE': 1.4266821247233885},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.2740340371926625,
#   'R2': 0.7905713973395502,
#   'MSPE': 1.392910582380313},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.2749744353195031,
#   'R2': 0.7758579886129205,
#   'MSPE': 1.4086662948300892},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.27524286756912864,
#   'R2': 0.7823243257976618,
#   'MSPE': 1.4616717302212208},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.2754231356084347,
#   'R2': 0.753238613349916,
#   'MSPE': 1.4197595584479095},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.27619986434777577,
#   'R2': 0.7689213478277667,
#   'MSPE': 1.3354191753185458},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.2767342823247115,
#   'R2': 0.789503008310801,
#   'MSPE': 1.3670171999532466},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.2769751712679863,
#   'R2': 0.7709054317007139,
#   'MSPE': 1.385451846219825},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.2772100791335106,
#   'R2': 0.7843049499601278,
#   'MSPE': 1.3679403310284168},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.27734999905029933,
#   'R2': 0.7657376326254138,
#   'MSPE': 1.3241857993933892},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.27776859452327096,
#   'R2': 0.7584492434343383,
#   'MSPE': 1.3419079704379493},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.2778806644181411,
#   'R2': 0.7801420964119176,
#   'MSPE': 1.3708118116012726},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.2782337158918381,
#   'R2': 0.7823095477884776,
#   'MSPE': 1.3726427218867372},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.2793601180116335,
#   'R2': 0.7665240706122665,
#   'MSPE': 1.330687926677667},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.2794594749808311,
#   'R2': 0.7710207148280568,
#   'MSPE': 1.3425280131173856},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.2794936214884122,
#   'R2': 0.7217634744948433,
#   'MSPE': 1.3227818705931758},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.27991044223308564,
#   'R2': 0.7820418599306896,
#   'MSPE': 1.4070197290769129},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.2802714124321938,
#   'R2': 0.7219487986632821,
#   'MSPE': 1.3036934613729967},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.2805297742287318,
#   'R2': 0.7731779768089629,
#   'MSPE': 1.3489376115753795},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.28110905687014265,
#   'R2': 0.7787857874910674,
#   'MSPE': 1.3926758320832793},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.28150139624873793,
#   'R2': 0.7593557642105955,
#   'MSPE': 1.327762081184321},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.2820359321931998,
#   'R2': 0.7726949204681958,
#   'MSPE': 1.552962259191907},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.28239888648192085,
#   'R2': 0.7728365436703533,
#   'MSPE': 1.409796697529729},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.28269588227073356,
#   'R2': 0.7651273047569798,
#   'MSPE': 1.351887843091831},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.282745744784673,
#   'R2': 0.7729635300603197,
#   'MSPE': 1.3514231438889648},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.2827557894090812,
#   'R2': 0.7560493239373798,
#   'MSPE': 1.4022249306053522},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.2830239887038867,
#   'R2': 0.7647980570412128,
#   'MSPE': 1.4296707039642513},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.2831806192795435,
#   'R2': 0.775993652855824,
#   'MSPE': 1.3742164754769717},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.28367648099859555,
#   'R2': 0.7629121300759734,
#   'MSPE': 1.5235031390976572},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.2840855787197748,
#   'R2': 0.7555150882518168,
#   'MSPE': 1.4891710276292127},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.2844847204784552,
#   'R2': 0.7611772784725934,
#   'MSPE': 1.4048441540393415},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.2845170016090075,
#   'R2': 0.7632120016306171,
#   'MSPE': 1.4464108577713068},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.2846295493344466,
#   'R2': 0.7538568883482091,
#   'MSPE': 1.389501015984952},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.28502286349733674,
#   'R2': 0.7749844813233813,
#   'MSPE': 1.3827550069739423},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.28549681132038435,
#   'R2': 0.7663400899009077,
#   'MSPE': 1.3635253826758325},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.285750196625789,
#   'R2': 0.7531526886310899,
#   'MSPE': 1.3706409492802742},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.2857664793729782,
#   'R2': 0.7258678640385405,
#   'MSPE': 1.3891917544727523},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.28770705113808315,
#   'R2': 0.7654073138855184,
#   'MSPE': 1.3914631188122761},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.2882610142230988,
#   'R2': 0.7774642111073204,
#   'MSPE': 1.3723877591617177},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.2889571641882261,
#   'R2': 0.7632074181028526,
#   'MSPE': 1.4568007089235266},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.28910935024420426,
#   'R2': 0.7699796700762043,
#   'MSPE': 1.428145904451458},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.2893469471484423,
#   'R2': 0.7608961049855102,
#   'MSPE': 1.4319452370582808},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.289445306857427,
#   'R2': 0.7760421535568992,
#   'MSPE': 1.5191865632912578},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.28964495708545046,
#   'R2': 0.7638223533439736,
#   'MSPE': 1.3567366800976521},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.29003446549177164,
#   'R2': 0.7432972395430488,
#   'MSPE': 1.4272968095699041},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.2901363134384155,
#   'R2': 0.7509405327848513,
#   'MSPE': 1.532963368750055},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.2903949258228143,
#   'R2': 0.7579398308563459,
#   'MSPE': 1.378628080710769},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.29080882569154104,
#   'R2': 0.7699677240790381,
#   'MSPE': 1.3771719779029037},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.2912033617496491,
#   'R2': 0.7686282533216582,
#   'MSPE': 1.4421901096956746},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.2912599618236224,
#   'R2': 0.7733081416736084,
#   'MSPE': 1.404899824316604},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.2917321746548017,
#   'R2': 0.7751428070031798,
#   'MSPE': 1.4529626635420656},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.29174794803063075,
#   'R2': 0.7635219191267038,
#   'MSPE': 1.4281471570803208},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.29301765486598014,
#   'R2': 0.7639536773919721,
#   'MSPE': 1.4163451724582248},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.2933815722664197,
#   'R2': 0.747455290720223,
#   'MSPE': 1.5645736220264523},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.29356119756897286,
#   'R2': 0.7799717810050282,
#   'MSPE': 1.5331776501291026},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.29410530974467597,
#   'R2': 0.7779909729054189,
#   'MSPE': 1.5332007248218011},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.29483399515350656,
#   'R2': 0.7643813401809725,
#   'MSPE': 1.5065835151501525},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.2951213824252287,
#   'R2': 0.7686991050831955,
#   'MSPE': 1.4411842011178684},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.295318204164505,
#   'R2': 0.7570110510455691,
#   'MSPE': 1.4950846734390866},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.2954540277520815,
#   'R2': 0.758360549355068,
#   'MSPE': 1.4573314816060692},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.296022700270017,
#   'R2': 0.7609767081506581,
#   'MSPE': 1.4466619267683438},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.2963208551208178,
#   'R2': 0.763174853987027,
#   'MSPE': 1.3810707592979223},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.29665093968311945,
#   'R2': 0.7340936546740113,
#   'MSPE': 1.3974195218296965},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.29685406287511185,
#   'R2': 0.7453840051019768,
#   'MSPE': 1.4480542442808397},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.2975043639540672,
#   'R2': 0.7649283584282733,
#   'MSPE': 1.4644881042962274},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.29753111600875853,
#   'R2': 0.7514823069029432,
#   'MSPE': 1.507330619626575},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.29807895968357717,
#   'R2': 0.7753797580428341,
#   'MSPE': 1.6185301083205927},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.29848538786172873,
#   'R2': 0.7613442534321583,
#   'MSPE': 1.5363186378634035},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.29884799271821977,
#   'R2': 0.7672498013436165,
#   'MSPE': 1.438353167884428},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.29910290986299515,
#   'R2': 0.7588472147238206,
#   'MSPE': 1.5090408703933158},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.300042470296224,
#   'R2': 0.762406664182919,
#   'MSPE': 1.4645918513732876},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.3016659771402677,
#   'R2': 0.7589050920285614,
#   'MSPE': 1.4357418427714195},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.3018665621678035,
#   'R2': 0.7426690660535163,
#   'MSPE': 1.4555761727946572},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.3023149069398642,
#   'R2': 0.7669110106413076,
#   'MSPE': 1.538510936397043},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.3027466177940369,
#   'R2': 0.749902455222081,
#   'MSPE': 1.4833057983166942},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.3027765606840451,
#   'R2': 0.7409961417852426,
#   'MSPE': 1.4575514575993322},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.30313380410273866,
#   'R2': 0.7540976204085146,
#   'MSPE': 1.7415167590734935},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.30319260209798815,
#   'R2': 0.7445021513289424,
#   'MSPE': 1.4839347759543944},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.30340314358472825,
#   'R2': 0.7627399226763801,
#   'MSPE': 1.5231213956657386},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.3041602524618308,
#   'R2': 0.7508849704393616,
#   'MSPE': 1.5096706579053643},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.30435536106427513,
#   'R2': 0.7615687254208896,
#   'MSPE': 1.5467808192426509},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.3048142979542414,
#   'R2': 0.7618521832203669,
#   'MSPE': 1.5301205526397683},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.30525121837854385,
#   'R2': 0.775999138819487,
#   'MSPE': 1.5956826402213085},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.3060897794862588,
#   'R2': 0.7603088186666276,
#   'MSPE': 1.4700870570547955},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.30619512175520264,
#   'R2': 0.7310997809394583,
#   'MSPE': 1.4637798389344654},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.30620518078406656,
#   'R2': 0.7515001633402438,
#   'MSPE': 1.562529788822914},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.3064796194434166,
#   'R2': 0.7391778687681062,
#   'MSPE': 1.4770341530969047},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.3069748232762019,
#   'R2': 0.7396011895437963,
#   'MSPE': 1.5388952302887584},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.30709871699412666,
#   'R2': 0.7591623306231001,
#   'MSPE': 1.5241024418348315},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.30845226980745793,
#   'R2': 0.7589915715301165,
#   'MSPE': 1.7582312801081426},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.3095828354358673,
#   'R2': 0.7536154173678062,
#   'MSPE': 1.586517643823166},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.3102686847249667,
#   'R2': 0.7326758022338595,
#   'MSPE': 1.4979881654973284},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.3117224626243114,
#   'R2': 0.7200390372731802,
#   'MSPE': 1.5294008007781073},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.3117434139053027,
#   'R2': 0.7344550230384177,
#   'MSPE': 1.47856585526218},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.3125371073683103,
#   'R2': 0.7464168248777988,
#   'MSPE': 1.5073832927854975},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.3125571007529894,
#   'R2': 0.7355083754969973,
#   'MSPE': 1.5694651403229194},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.31302792876958846,
#   'R2': 0.742102432646894,
#   'MSPE': 1.5424525109354894},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.31554756437738735,
#   'R2': 0.7581768454779664,
#   'MSPE': 1.5912490759534066},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.3166745555897554,
#   'R2': 0.7486780565998096,
#   'MSPE': 1.6164247297465502},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.31792002320289614,
#   'R2': 0.745793976377909,
#   'MSPE': 1.648921597316259},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.32024055620034536,
#   'R2': 0.7462726170449305,
#   'MSPE': 1.488830805050604},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.32145369897286097,
#   'R2': 0.7627597007291241,
#   'MSPE': 1.7227853947516643},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.3232345744967461,
#   'R2': 0.7336262529061267,
#   'MSPE': 1.5801594076170162},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.32521299769481027,
#   'R2': 0.7225249982607047,
#   'MSPE': 1.5175721851751358},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.32526632323861127,
#   'R2': 0.7262440448114293,
#   'MSPE': 1.6260370643188555},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.32613306393225994,
#   'R2': 0.7434092327631092,
#   'MSPE': 1.7882989176708939},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.32898550281922023,
#   'R2': 0.7134604979499425,
#   'MSPE': 1.6148586157295441},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.32912650307019553,
#   'R2': 0.7614556795251858,
#   'MSPE': 1.8142933439406932},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.33138082375129063,
#   'R2': 0.7541582965956768,
#   'MSPE': 1.8183077789955966},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.3377794983486334,
#   'R2': 0.7060714512745762,
#   'MSPE': 1.62920952134888},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.33969745884339014,
#   'R2': 0.7272324076120489,
#   'MSPE': 1.710096906983491},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.35730211759607,
#   'R2': 0.6939170058423553,
#   'MSPE': 1.584587558831154},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.363151178508997,
#   'R2': 0.7119892557479321,
#   'MSPE': 1.8334532496190132},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.3715747019896905,
#   'R2': 0.6883619442120779,
#   'MSPE': 1.7462962705670209},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.37398272429903345,
#   'R2': 0.7180507791196873,
#   'MSPE': 1.8409495960187279},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.3744300251205762,
#   'R2': 0.6696588551565095,
#   'MSPE': 1.767327913054914},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.3777700061599414,
#   'R2': 0.7052857304251626,
#   'MSPE': 1.6226647478161436},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.3809875200192133,
#   'R2': 0.6787108031939695,
#   'MSPE': 1.7442218522362487},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.38415802667538324,
#   'R2': 0.6954491214154902,
#   'MSPE': 1.9017782093336184},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.3844356859723727,
#   'R2': 0.6754092512317824,
#   'MSPE': 1.8865399572509105},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.38531139741341275,
#   'R2': 0.7030048479965946,
#   'MSPE': 1.8559707827264007},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.38627403005957606,
#   'R2': 0.6940945961492588,
#   'MSPE': 1.9000020926122112},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.38637675344944,
#   'R2': 0.6823239628255131,
#   'MSPE': 1.7773297391455583},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.39067422822117803,
#   'R2': 0.6841151482533165,
#   'MSPE': 1.9878891688028368},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.4000055799881618,
#   'R2': 0.6767503137155642,
#   'MSPE': 1.879137455852646},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.40485878239075346,
#   'R2': 0.6503403602819342,
#   'MSPE': 2.288221434097398},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.406668188671271,
#   'R2': 0.6858775941332735,
#   'MSPE': 2.0472818420202743},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.40926477760076524,
#   'R2': 0.6567590520310784,
#   'MSPE': 1.8144229204967766},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.41114200601975115,
#   'R2': 0.6619659545837948,
#   'MSPE': 2.0224800567622436},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.41267205874125157,
#   'R2': 0.6674315300182938,
#   'MSPE': 1.844256440779627},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.4152277385195096,
#   'R2': 0.6548758742529796,
#   'MSPE': 1.9552308861918821},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.4250790784756342,
#   'R2': 0.6532139506678599,
#   'MSPE': 2.1940008806760867},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.42839206258455914,
#   'R2': 0.6302891692645708,
#   'MSPE': 1.9111430564086245},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.4284628530343374,
#   'R2': 0.6602075686551119,
#   'MSPE': 1.9733027788349475},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.4301193316777547,
#   'R2': 0.644495101360657,
#   'MSPE': 1.9158042637123303},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.4311572194099426,
#   'R2': 0.6359343523058393,
#   'MSPE': 2.02206024655489},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.43170132239659625,
#   'R2': 0.6677030706810834,
#   'MSPE': 2.158540570073657},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.43219280739625293,
#   'R2': 0.6194066393609239,
#   'MSPE': 2.010144862920196},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.4322373688220978,
#   'R2': 0.6392281566125736,
#   'MSPE': 1.973438321923216},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.4348634476463,
#   'R2': 0.6397951657224352,
#   'MSPE': 1.868411344052716},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.4401061276594797,
#   'R2': 0.6464124219914226,
#   'MSPE': 1.967376135289669},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.4414255579312642,
#   'R2': 0.6482699640202266,
#   'MSPE': 1.9991742537328687},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.4415686304370562,
#   'R2': 0.6604402932987796,
#   'MSPE': 2.165168063113033},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.4416759456197421,
#   'R2': 0.6345626346350294,
#   'MSPE': 2.034074834576159},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.44426874170700714,
#   'R2': 0.6422988670445852,
#   'MSPE': 1.9381446752584341},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.44637625217437743,
#   'R2': 0.6270922106433785,
#   'MSPE': 1.9776161642500543},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.4480434621373813,
#   'R2': 0.6109681910797035,
#   'MSPE': 1.9761659312203073},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.44866751730442045,
#   'R2': 0.6413570758348793,
#   'MSPE': 1.990584611158931},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.45004051029682157,
#   'R2': 0.6302205598609402,
#   'MSPE': 2.1221821076904583},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.4503666400909424,
#   'R2': 0.6473791957545906,
#   'MSPE': 2.1145938826969477},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.45297691126664474,
#   'R2': 0.651383812180159,
#   'MSPE': 2.194176060288693},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.4539195388555527,
#   'R2': 0.6425400837698135,
#   'MSPE': 2.0007981223552815},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.45706204921007154,
#   'R2': 0.6390824776624349,
#   'MSPE': 2.293834581670135},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.4578676601250967,
#   'R2': 0.6363446484912455,
#   'MSPE': 2.312441025531352},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.45874808828035984,
#   'R2': 0.6395635710111991,
#   'MSPE': 2.04168706172795},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.4589261998732884,
#   'R2': 0.6500684235108416,
#   'MSPE': 2.016017379972971},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.46264517754316337,
#   'R2': 0.6464432876918137,
#   'MSPE': 2.1650719344427793},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.4647263740499814,
#   'R2': 0.5895171699546476,
#   'MSPE': 2.116318938576362},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.4662171299258868,
#   'R2': 0.6395712337092079,
#   'MSPE': 2.1514571963273212},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.4705908089876175,
#   'R2': 0.6496656870299197,
#   'MSPE': 2.0967586421304274},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.47152088880538934,
#   'R2': 0.6295151134579935,
#   'MSPE': 2.1024166451146202},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.47286451011896136,
#   'R2': 0.6145001401819605,
#   'MSPE': 2.1125129473894235},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.47508893708388006,
#   'R2': 0.642711353465008,
#   'MSPE': 2.2312704918699136},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.48980168998241425,
#   'R2': 0.6162194837312244,
#   'MSPE': 2.2201640327282326},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.49015434086322773,
#   'R2': 0.628840996575768,
#   'MSPE': 2.263260901143605},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.5021865497032801,
#   'R2': 0.5815959604694143,
#   'MSPE': 2.4639973655869865},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.509281707306703,
#   'R2': 0.6188551082413813,
#   'MSPE': 2.369827693986772},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.5148663739363352,
#   'R2': 0.6043587122074383,
#   'MSPE': 2.1768699332394386},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.5253416503469148,
#   'R2': 0.5887863580370272,
#   'MSPE': 2.253596870924788},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.5392169366280237,
#   'R2': 0.5351056357876377,
#   'MSPE': 2.2783516494162153},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.5840617015957832,
#   'R2': 0.5490259245176401,
#   'MSPE': 2.7698847438876677},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.5909742047389348,
#   'R2': 0.5013481533004612,
#   'MSPE': 2.6784246138325245},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.597658692797025,
#   'R2': 0.4382247373360504,
#   'MSPE': 2.839816124601797},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.6025374017655849,
#   'R2': 0.529785141868641,
#   'MSPE': 2.771993604055935},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.6310153678059578,
#   'R2': 0.4888210065358779,
#   'MSPE': 3.051843547045883},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.6313829878966015,
#   'R2': 0.4684759164454723,
#   'MSPE': 3.1170337933181513},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.649456025660038,
#   'R2': 0.4632893410125921,
#   'MSPE': 3.032410670673907},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.6538053343693416,
#   'R2': 0.4694974286184575,
#   'MSPE': 3.1333248241983283},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.6567176813880603,
#   'R2': 0.4540764122905923,
#   'MSPE': 3.03206842392683},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.6823183645804722,
#   'R2': 0.455857616056372,
#   'MSPE': 3.247602889972805},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.6827344059944153,
#   'R2': 0.4510049947987569,
#   'MSPE': 3.1275318931750578},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.6858494758605957,
#   'R2': 0.4587739062351829,
#   'MSPE': 3.4777187823195645},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.6916021804014842,
#   'R2': 0.46370796858570174,
#   'MSPE': 3.1567465290050913},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.7014575223128001,
#   'R2': 0.4433013406277391,
#   'MSPE': 3.164128945632414},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.7053125749031703,
#   'R2': 0.4516785799186345,
#   'MSPE': 3.279779487374154},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.7067190835873285,
#   'R2': 0.4475203102844315,
#   'MSPE': 3.26484136640875},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.7099995225667952,
#   'R2': 0.4294669159654232,
#   'MSPE': 3.032244655181362},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.7106104383865993,
#   'R2': 0.4460703683850051,
#   'MSPE': 3.616728818213397},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.7116223757465681,
#   'R2': 0.41532799065081616,
#   'MSPE': 2.721169727638063},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.7213774532079696,
#   'R2': 0.3963048809845563,
#   'MSPE': 3.2799030640962146},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.7293190707763035,
#   'R2': 0.43556720588698716,
#   'MSPE': 3.1565291682879133},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.731444752216339,
#   'R2': 0.36962275136745115,
#   'MSPE': 3.2832924334915594},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.7347439467906952,
#   'R2': 0.4179896734568853,
#   'MSPE': 3.302255980482306},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.7400863369305928,
#   'R2': 0.36534623260375126,
#   'MSPE': 3.397947091496352},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.7441457649072012,
#   'R2': 0.4387268411614995,
#   'MSPE': 3.4609729107093026},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.7456709414720535,
#   'R2': 0.2566355901728984,
#   'MSPE': 2.93664596702038},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.7518828709920247,
#   'R2': 0.44131521000515866,
#   'MSPE': 3.8883332672971065},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.7532866477966309,
#   'R2': 0.3620559395121279,
#   'MSPE': 3.821654886647005},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.7577393780152003,
#   'R2': 0.38083785879871773,
#   'MSPE': 3.769696874901501},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.7582832728823027,
#   'R2': 0.43272574938045094,
#   'MSPE': 3.661599911354257},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.7588237921396892,
#   'R2': 0.3922096746228053,
#   'MSPE': 3.3533475149159484},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.7748069018125534,
#   'R2': 0.39149447480428623,
#   'MSPE': 3.6107983746838683},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.7897635211547216,
#   'R2': 0.37357815937099803,
#   'MSPE': 3.37783802187804},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.7963020692269007,
#   'R2': 0.3821138190186051,
#   'MSPE': 3.7201893707793774},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.7979643791913986,
#   'R2': 0.36092843165321037,
#   'MSPE': 3.544346478701842},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.7985026687383653,
#   'R2': 0.3657095609433454,
#   'MSPE': 3.7992639589415056},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.7991077899932861,
#   'R2': 0.38133123249171674,
#   'MSPE': 3.4637555058556373},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.7994200060764949,
#   'R2': 0.36317078290219723,
#   'MSPE': 3.645495882239004},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.799657600124677,
#   'R2': 0.35195948065992944,
#   'MSPE': 3.717631917785515},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.8003893246253332,
#   'R2': 0.3958722088380873,
#   'MSPE': 3.7321615540845827},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.8026615450779598,
#   'R2': 0.31735470813963185,
#   'MSPE': 3.8644608140292798},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.8167677313089371,
#   'R2': 0.37275316896495025,
#   'MSPE': 3.628872503724062},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.8168476104736329,
#   'R2': 0.35013682449084693,
#   'MSPE': 3.700772511274225},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.8198743318518004,
#   'R2': 0.4160871625619514,
#   'MSPE': 3.9275342340797486},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.823721069097519,
#   'R2': 0.35343199498840344,
#   'MSPE': 4.0277277078065605},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.8249856323003769,
#   'R2': 0.36374314087276816,
#   'MSPE': 3.9023106974653077},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.834874893228213,
#   'R2': 0.33734324741039157,
#   'MSPE': 4.061007521143464},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.8413724899291992,
#   'R2': 0.32313539855706674,
#   'MSPE': 4.061040838220806},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.8437059362729389,
#   'R2': 0.3672927293855107,
#   'MSPE': 3.8948937774532366},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.8828014552593231,
#   'R2': 0.25961087788744613,
#   'MSPE': 3.9508229642730166},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.9007911771535874,
#   'R2': 0.2615862562344704,
#   'MSPE': 4.0547895337445565},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.908054401477178,
#   'R2': 0.29315135456246527,
#   'MSPE': 4.457280762644126},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.9089627693096796,
#   'R2': 0.23169333514240836,
#   'MSPE': 4.367639568794255},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.92901251912117,
#   'R2': 0.22735840193263696,
#   'MSPE': 4.275904610339138},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 1.4321367412805555,
#   'R2': -0.08477738604836094,
#   'MSPE': 5.2990526382369225},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 1.6100392798582714,
#   'R2': -0.7381374316517919,
#   'MSPE': 5.979180212386629},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 1.6239945193131764,
#   'R2': -0.40556285525984065,
#   'MSPE': 5.74983229220967}]

# %%
# Sort by highest R2
sorted(results, key=lambda x: x["R2"], reverse=True)
# Out:
# [{'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.2356918546060721,
#   'R2': 0.8087246579994825,
#   'MSPE': 1.1024457791989501},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.24524316365520163,
#   'R2': 0.8055668565921076,
#   'MSPE': 1.235798517655995},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.25389389966924986,
#   'R2': 0.8053059077915761,
#   'MSPE': 1.3613589903377372},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.24934231961766878,
#   'R2': 0.8038193457407863,
#   'MSPE': 1.2034694337747012},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.24595479071140286,
#   'R2': 0.8023366878708164,
#   'MSPE': 1.124330551053087},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.2404098773996035,
#   'R2': 0.8012343042894294,
#   'MSPE': 1.134895604207284},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.24960130328933397,
#   'R2': 0.8009442186013611,
#   'MSPE': 1.2201073328785674},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.24271518141031265,
#   'R2': 0.799364937474935,
#   'MSPE': 1.2152017948377611},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.2628722570836544,
#   'R2': 0.7990372234779104,
#   'MSPE': 1.2858133061290389},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.24179739902416864,
#   'R2': 0.7988074525832575,
#   'MSPE': 1.1475948895318342},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.2467856084307035,
#   'R2': 0.7986206648504259,
#   'MSPE': 1.2244813989452792},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.24949195956190434,
#   'R2': 0.7984797005915408,
#   'MSPE': 1.1885108482657056},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.2506446448465188,
#   'R2': 0.7983765996065273,
#   'MSPE': 1.2304265363932108},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.25155347883701323,
#   'R2': 0.7972170207097122,
#   'MSPE': 1.1931831303588818},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.2442339204251766,
#   'R2': 0.7955760849715283,
#   'MSPE': 1.1281111574910507},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.2688115251561006,
#   'R2': 0.794879585491372,
#   'MSPE': 1.3390204682005475},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.2595063142478466,
#   'R2': 0.7945813416544028,
#   'MSPE': 1.276474629735781},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.25473053610573215,
#   'R2': 0.794440453405199,
#   'MSPE': 1.2939848989775087},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.26052938699722283,
#   'R2': 0.7942117515097082,
#   'MSPE': 1.2963024609618716},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.25074586371580765,
#   'R2': 0.7941837177674484,
#   'MSPE': 1.2287741669011534},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.2628365526596705,
#   'R2': 0.7941046845303515,
#   'MSPE': 1.2510084892350313},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.26000726235409577,
#   'R2': 0.79365550869305,
#   'MSPE': 1.2355981966612315},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.2602493308484554,
#   'R2': 0.7929133963217039,
#   'MSPE': 1.3037600384253745},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.23920444659888748,
#   'R2': 0.7917996216679747,
#   'MSPE': 1.1408100749431838},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.24360507925351457,
#   'R2': 0.7916911330100422,
#   'MSPE': 1.1703230074672688},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.2637303108970324,
#   'R2': 0.791051482224695,
#   'MSPE': 1.5107351833145426},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.2740340371926625,
#   'R2': 0.7905713973395502,
#   'MSPE': 1.392910582380313},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.2617567295829455,
#   'R2': 0.7902903156741765,
#   'MSPE': 1.3349809800980217},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.27388175278902055,
#   'R2': 0.7899794734480692,
#   'MSPE': 1.4266821247233885},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.26740745703379315,
#   'R2': 0.7897616043294586,
#   'MSPE': 1.3411325516386163},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.2767342823247115,
#   'R2': 0.789503008310801,
#   'MSPE': 1.3670171999532466},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.2579621774454911,
#   'R2': 0.7892542583847522,
#   'MSPE': 1.2500045869047895},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.26196660771965985,
#   'R2': 0.7889922393101099,
#   'MSPE': 1.2287132529485407},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.2671753533184528,
#   'R2': 0.7882687041456474,
#   'MSPE': 1.2889513946279432},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.26130985071261725,
#   'R2': 0.7866830450826708,
#   'MSPE': 1.4007923495250219},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.2588117467860381,
#   'R2': 0.785354790201129,
#   'MSPE': 1.319009717930146},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.2709246243039766,
#   'R2': 0.7846382580118955,
#   'MSPE': 1.3262840902733832},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.2772100791335106,
#   'R2': 0.7843049499601278,
#   'MSPE': 1.3679403310284168},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.26758162230253213,
#   'R2': 0.7837206897988658,
#   'MSPE': 1.272755952015745},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.24592373023430505,
#   'R2': 0.7835359186056442,
#   'MSPE': 1.2364357357581306},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.27065055295825,
#   'R2': 0.7833456641123868,
#   'MSPE': 1.3101160232767914},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.2594819441437721,
#   'R2': 0.7828930532318557,
#   'MSPE': 1.229615755887194},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.27524286756912864,
#   'R2': 0.7823243257976618,
#   'MSPE': 1.4616717302212208},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.2782337158918381,
#   'R2': 0.7823095477884776,
#   'MSPE': 1.3726427218867372},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.2729325282076994,
#   'R2': 0.7821852771037662,
#   'MSPE': 1.3162129462668388},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.27991044223308564,
#   'R2': 0.7820418599306896,
#   'MSPE': 1.4070197290769129},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.2693892215689023,
#   'R2': 0.7817681852960481,
#   'MSPE': 1.4120417441984618},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.2594859143098195,
#   'R2': 0.7811128165177479,
#   'MSPE': 1.2316726961859847},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.26501514116923014,
#   'R2': 0.7806856070101187,
#   'MSPE': 1.2330778754043459},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.27155601407090824,
#   'R2': 0.780572698754054,
#   'MSPE': 1.3579931003841188},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.25606470356384914,
#   'R2': 0.7805668686984107,
#   'MSPE': 1.2285431898716423},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.2778806644181411,
#   'R2': 0.7801420964119176,
#   'MSPE': 1.3708118116012726},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.29356119756897286,
#   'R2': 0.7799717810050282,
#   'MSPE': 1.5331776501291026},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.263533745209376,
#   'R2': 0.7795351082133672,
#   'MSPE': 1.2289734068091471},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.2655252975722154,
#   'R2': 0.779175331430638,
#   'MSPE': 1.3079666388644413},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.28110905687014265,
#   'R2': 0.7787857874910674,
#   'MSPE': 1.3926758320832793},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.26220664059122406,
#   'R2': 0.7780490843016016,
#   'MSPE': 1.260781326669861},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.29410530974467597,
#   'R2': 0.7779909729054189,
#   'MSPE': 1.5332007248218011},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.26237845346331595,
#   'R2': 0.7774877405319632,
#   'MSPE': 1.2781992433310456},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.2882610142230988,
#   'R2': 0.7774642111073204,
#   'MSPE': 1.3723877591617177},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.289445306857427,
#   'R2': 0.7760421535568992,
#   'MSPE': 1.5191865632912578},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.30525121837854385,
#   'R2': 0.775999138819487,
#   'MSPE': 1.5956826402213085},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.2831806192795435,
#   'R2': 0.775993652855824,
#   'MSPE': 1.3742164754769717},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.2749744353195031,
#   'R2': 0.7758579886129205,
#   'MSPE': 1.4086662948300892},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.29807895968357717,
#   'R2': 0.7753797580428341,
#   'MSPE': 1.6185301083205927},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.2917321746548017,
#   'R2': 0.7751428070031798,
#   'MSPE': 1.4529626635420656},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.28502286349733674,
#   'R2': 0.7749844813233813,
#   'MSPE': 1.3827550069739423},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.2733822951714198,
#   'R2': 0.7735240647720819,
#   'MSPE': 1.345546410014533},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.2912599618236224,
#   'R2': 0.7733081416736084,
#   'MSPE': 1.404899824316604},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.2805297742287318,
#   'R2': 0.7731779768089629,
#   'MSPE': 1.3489376115753795},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.282745744784673,
#   'R2': 0.7729635300603197,
#   'MSPE': 1.3514231438889648},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.28239888648192085,
#   'R2': 0.7728365436703533,
#   'MSPE': 1.409796697529729},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.2820359321931998,
#   'R2': 0.7726949204681958,
#   'MSPE': 1.552962259191907},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.2671100810170174,
#   'R2': 0.7726626691785528,
#   'MSPE': 1.2856849691256729},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.26150365695357325,
#   'R2': 0.7721351322247765,
#   'MSPE': 1.4054120723346266},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.26985983873407043,
#   'R2': 0.7712878925776252,
#   'MSPE': 1.2874182846133757},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.2794594749808311,
#   'R2': 0.7710207148280568,
#   'MSPE': 1.3425280131173856},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.2769751712679863,
#   'R2': 0.7709054317007139,
#   'MSPE': 1.385451846219825},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.2696192319194476,
#   'R2': 0.7707688345528572,
#   'MSPE': 1.3329143191433763},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.2730562870701155,
#   'R2': 0.7703858553910004,
#   'MSPE': 1.3019384644605747},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.28910935024420426,
#   'R2': 0.7699796700762043,
#   'MSPE': 1.428145904451458},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.29080882569154104,
#   'R2': 0.7699677240790381,
#   'MSPE': 1.3771719779029037},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.2621939900020758,
#   'R2': 0.76943737008437,
#   'MSPE': 1.2265134247659586},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.27619986434777577,
#   'R2': 0.7689213478277667,
#   'MSPE': 1.3354191753185458},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.2951213824252287,
#   'R2': 0.7686991050831955,
#   'MSPE': 1.4411842011178684},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.2912033617496491,
#   'R2': 0.7686282533216582,
#   'MSPE': 1.4421901096956746},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.2713801657160123,
#   'R2': 0.7678303609553383,
#   'MSPE': 1.3092095997523177},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.27282808944582937,
#   'R2': 0.7677444666908577,
#   'MSPE': 1.3109506813414167},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.29884799271821977,
#   'R2': 0.7672498013436165,
#   'MSPE': 1.438353167884428},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.3023149069398642,
#   'R2': 0.7669110106413076,
#   'MSPE': 1.538510936397043},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.2793601180116335,
#   'R2': 0.7665240706122665,
#   'MSPE': 1.330687926677667},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.28549681132038435,
#   'R2': 0.7663400899009077,
#   'MSPE': 1.3635253826758325},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.27734999905029933,
#   'R2': 0.7657376326254138,
#   'MSPE': 1.3241857993933892},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.27268678322434425,
#   'R2': 0.765531272764185,
#   'MSPE': 1.2612571832582806},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.28770705113808315,
#   'R2': 0.7654073138855184,
#   'MSPE': 1.3914631188122761},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.28269588227073356,
#   'R2': 0.7651273047569798,
#   'MSPE': 1.351887843091831},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.2975043639540672,
#   'R2': 0.7649283584282733,
#   'MSPE': 1.4644881042962274},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.2830239887038867,
#   'R2': 0.7647980570412128,
#   'MSPE': 1.4296707039642513},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.29483399515350656,
#   'R2': 0.7643813401809725,
#   'MSPE': 1.5065835151501525},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.29301765486598014,
#   'R2': 0.7639536773919721,
#   'MSPE': 1.4163451724582248},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.28964495708545046,
#   'R2': 0.7638223533439736,
#   'MSPE': 1.3567366800976521},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.29174794803063075,
#   'R2': 0.7635219191267038,
#   'MSPE': 1.4281471570803208},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.2845170016090075,
#   'R2': 0.7632120016306171,
#   'MSPE': 1.4464108577713068},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.2889571641882261,
#   'R2': 0.7632074181028526,
#   'MSPE': 1.4568007089235266},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.2963208551208178,
#   'R2': 0.763174853987027,
#   'MSPE': 1.3810707592979223},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.28367648099859555,
#   'R2': 0.7629121300759734,
#   'MSPE': 1.5235031390976572},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.32145369897286097,
#   'R2': 0.7627597007291241,
#   'MSPE': 1.7227853947516643},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.30340314358472825,
#   'R2': 0.7627399226763801,
#   'MSPE': 1.5231213956657386},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.300042470296224,
#   'R2': 0.762406664182919,
#   'MSPE': 1.4645918513732876},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.3048142979542414,
#   'R2': 0.7618521832203669,
#   'MSPE': 1.5301205526397683},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.27287237296501793,
#   'R2': 0.7617550651940388,
#   'MSPE': 1.3478364330725838},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.30435536106427513,
#   'R2': 0.7615687254208896,
#   'MSPE': 1.5467808192426509},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.32912650307019553,
#   'R2': 0.7614556795251858,
#   'MSPE': 1.8142933439406932},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.29848538786172873,
#   'R2': 0.7613442534321583,
#   'MSPE': 1.5363186378634035},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.2844847204784552,
#   'R2': 0.7611772784725934,
#   'MSPE': 1.4048441540393415},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.296022700270017,
#   'R2': 0.7609767081506581,
#   'MSPE': 1.4466619267683438},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.2893469471484423,
#   'R2': 0.7608961049855102,
#   'MSPE': 1.4319452370582808},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.3060897794862588,
#   'R2': 0.7603088186666276,
#   'MSPE': 1.4700870570547955},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.28150139624873793,
#   'R2': 0.7593557642105955,
#   'MSPE': 1.327762081184321},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.30709871699412666,
#   'R2': 0.7591623306231001,
#   'MSPE': 1.5241024418348315},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.30845226980745793,
#   'R2': 0.7589915715301165,
#   'MSPE': 1.7582312801081426},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.3016659771402677,
#   'R2': 0.7589050920285614,
#   'MSPE': 1.4357418427714195},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.29910290986299515,
#   'R2': 0.7588472147238206,
#   'MSPE': 1.5090408703933158},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.27776859452327096,
#   'R2': 0.7584492434343383,
#   'MSPE': 1.3419079704379493},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.2954540277520815,
#   'R2': 0.758360549355068,
#   'MSPE': 1.4573314816060692},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.31554756437738735,
#   'R2': 0.7581768454779664,
#   'MSPE': 1.5912490759534066},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.2903949258228143,
#   'R2': 0.7579398308563459,
#   'MSPE': 1.378628080710769},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.295318204164505,
#   'R2': 0.7570110510455691,
#   'MSPE': 1.4950846734390866},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.2827557894090812,
#   'R2': 0.7560493239373798,
#   'MSPE': 1.4022249306053522},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.2840855787197748,
#   'R2': 0.7555150882518168,
#   'MSPE': 1.4891710276292127},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.33138082375129063,
#   'R2': 0.7541582965956768,
#   'MSPE': 1.8183077789955966},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.30313380410273866,
#   'R2': 0.7540976204085146,
#   'MSPE': 1.7415167590734935},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.2846295493344466,
#   'R2': 0.7538568883482091,
#   'MSPE': 1.389501015984952},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.3095828354358673,
#   'R2': 0.7536154173678062,
#   'MSPE': 1.586517643823166},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.2754231356084347,
#   'R2': 0.753238613349916,
#   'MSPE': 1.4197595584479095},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.285750196625789,
#   'R2': 0.7531526886310899,
#   'MSPE': 1.3706409492802742},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.30620518078406656,
#   'R2': 0.7515001633402438,
#   'MSPE': 1.562529788822914},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.29753111600875853,
#   'R2': 0.7514823069029432,
#   'MSPE': 1.507330619626575},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.2901363134384155,
#   'R2': 0.7509405327848513,
#   'MSPE': 1.532963368750055},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.3041602524618308,
#   'R2': 0.7508849704393616,
#   'MSPE': 1.5096706579053643},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.3027466177940369,
#   'R2': 0.749902455222081,
#   'MSPE': 1.4833057983166942},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.3166745555897554,
#   'R2': 0.7486780565998096,
#   'MSPE': 1.6164247297465502},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.2933815722664197,
#   'R2': 0.747455290720223,
#   'MSPE': 1.5645736220264523},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.3125371073683103,
#   'R2': 0.7464168248777988,
#   'MSPE': 1.5073832927854975},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.32024055620034536,
#   'R2': 0.7462726170449305,
#   'MSPE': 1.488830805050604},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.31792002320289614,
#   'R2': 0.745793976377909,
#   'MSPE': 1.648921597316259},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.29685406287511185,
#   'R2': 0.7453840051019768,
#   'MSPE': 1.4480542442808397},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.25988315542538964,
#   'R2': 0.744727258501246,
#   'MSPE': 1.2441724252350854},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.30319260209798815,
#   'R2': 0.7445021513289424,
#   'MSPE': 1.4839347759543944},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.32613306393225994,
#   'R2': 0.7434092327631092,
#   'MSPE': 1.7882989176708939},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.29003446549177164,
#   'R2': 0.7432972395430488,
#   'MSPE': 1.4272968095699041},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.3018665621678035,
#   'R2': 0.7426690660535163,
#   'MSPE': 1.4555761727946572},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.31302792876958846,
#   'R2': 0.742102432646894,
#   'MSPE': 1.5424525109354894},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.3027765606840451,
#   'R2': 0.7409961417852426,
#   'MSPE': 1.4575514575993322},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.3069748232762019,
#   'R2': 0.7396011895437963,
#   'MSPE': 1.5388952302887584},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.3064796194434166,
#   'R2': 0.7391778687681062,
#   'MSPE': 1.4770341530969047},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.2713289012511571,
#   'R2': 0.7359271400017835,
#   'MSPE': 1.2805388367857145},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.3125571007529894,
#   'R2': 0.7355083754969973,
#   'MSPE': 1.5694651403229194},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.3117434139053027,
#   'R2': 0.7344550230384177,
#   'MSPE': 1.47856585526218},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.29665093968311945,
#   'R2': 0.7340936546740113,
#   'MSPE': 1.3974195218296965},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.3232345744967461,
#   'R2': 0.7336262529061267,
#   'MSPE': 1.5801594076170162},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.3102686847249667,
#   'R2': 0.7326758022338595,
#   'MSPE': 1.4979881654973284},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.30619512175520264,
#   'R2': 0.7310997809394583,
#   'MSPE': 1.4637798389344654},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.33969745884339014,
#   'R2': 0.7272324076120489,
#   'MSPE': 1.710096906983491},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.32526632323861127,
#   'R2': 0.7262440448114293,
#   'MSPE': 1.6260370643188555},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.2857664793729782,
#   'R2': 0.7258678640385405,
#   'MSPE': 1.3891917544727523},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.32521299769481027,
#   'R2': 0.7225249982607047,
#   'MSPE': 1.5175721851751358},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.2802714124321938,
#   'R2': 0.7219487986632821,
#   'MSPE': 1.3036934613729967},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.2794936214884122,
#   'R2': 0.7217634744948433,
#   'MSPE': 1.3227818705931758},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.3117224626243114,
#   'R2': 0.7200390372731802,
#   'MSPE': 1.5294008007781073},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.37398272429903345,
#   'R2': 0.7180507791196873,
#   'MSPE': 1.8409495960187279},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.32898550281922023,
#   'R2': 0.7134604979499425,
#   'MSPE': 1.6148586157295441},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.363151178508997,
#   'R2': 0.7119892557479321,
#   'MSPE': 1.8334532496190132},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.3377794983486334,
#   'R2': 0.7060714512745762,
#   'MSPE': 1.62920952134888},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.3777700061599414,
#   'R2': 0.7052857304251626,
#   'MSPE': 1.6226647478161436},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.38531139741341275,
#   'R2': 0.7030048479965946,
#   'MSPE': 1.8559707827264007},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.38415802667538324,
#   'R2': 0.6954491214154902,
#   'MSPE': 1.9017782093336184},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.38627403005957606,
#   'R2': 0.6940945961492588,
#   'MSPE': 1.9000020926122112},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.35730211759607,
#   'R2': 0.6939170058423553,
#   'MSPE': 1.584587558831154},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.3715747019896905,
#   'R2': 0.6883619442120779,
#   'MSPE': 1.7462962705670209},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.406668188671271,
#   'R2': 0.6858775941332735,
#   'MSPE': 2.0472818420202743},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.39067422822117803,
#   'R2': 0.6841151482533165,
#   'MSPE': 1.9878891688028368},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.38637675344944,
#   'R2': 0.6823239628255131,
#   'MSPE': 1.7773297391455583},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.3809875200192133,
#   'R2': 0.6787108031939695,
#   'MSPE': 1.7442218522362487},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.4000055799881618,
#   'R2': 0.6767503137155642,
#   'MSPE': 1.879137455852646},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.3844356859723727,
#   'R2': 0.6754092512317824,
#   'MSPE': 1.8865399572509105},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.3744300251205762,
#   'R2': 0.6696588551565095,
#   'MSPE': 1.767327913054914},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.43170132239659625,
#   'R2': 0.6677030706810834,
#   'MSPE': 2.158540570073657},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.41267205874125157,
#   'R2': 0.6674315300182938,
#   'MSPE': 1.844256440779627},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.41114200601975115,
#   'R2': 0.6619659545837948,
#   'MSPE': 2.0224800567622436},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.4415686304370562,
#   'R2': 0.6604402932987796,
#   'MSPE': 2.165168063113033},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.4284628530343374,
#   'R2': 0.6602075686551119,
#   'MSPE': 1.9733027788349475},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.40926477760076524,
#   'R2': 0.6567590520310784,
#   'MSPE': 1.8144229204967766},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.4152277385195096,
#   'R2': 0.6548758742529796,
#   'MSPE': 1.9552308861918821},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.4250790784756342,
#   'R2': 0.6532139506678599,
#   'MSPE': 2.1940008806760867},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.45297691126664474,
#   'R2': 0.651383812180159,
#   'MSPE': 2.194176060288693},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.40485878239075346,
#   'R2': 0.6503403602819342,
#   'MSPE': 2.288221434097398},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.4589261998732884,
#   'R2': 0.6500684235108416,
#   'MSPE': 2.016017379972971},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.4705908089876175,
#   'R2': 0.6496656870299197,
#   'MSPE': 2.0967586421304274},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.4414255579312642,
#   'R2': 0.6482699640202266,
#   'MSPE': 1.9991742537328687},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.4503666400909424,
#   'R2': 0.6473791957545906,
#   'MSPE': 2.1145938826969477},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.46264517754316337,
#   'R2': 0.6464432876918137,
#   'MSPE': 2.1650719344427793},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.4401061276594797,
#   'R2': 0.6464124219914226,
#   'MSPE': 1.967376135289669},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.4301193316777547,
#   'R2': 0.644495101360657,
#   'MSPE': 1.9158042637123303},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.47508893708388006,
#   'R2': 0.642711353465008,
#   'MSPE': 2.2312704918699136},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.4539195388555527,
#   'R2': 0.6425400837698135,
#   'MSPE': 2.0007981223552815},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.44426874170700714,
#   'R2': 0.6422988670445852,
#   'MSPE': 1.9381446752584341},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.44866751730442045,
#   'R2': 0.6413570758348793,
#   'MSPE': 1.990584611158931},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.4348634476463,
#   'R2': 0.6397951657224352,
#   'MSPE': 1.868411344052716},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.4662171299258868,
#   'R2': 0.6395712337092079,
#   'MSPE': 2.1514571963273212},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.45874808828035984,
#   'R2': 0.6395635710111991,
#   'MSPE': 2.04168706172795},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.4322373688220978,
#   'R2': 0.6392281566125736,
#   'MSPE': 1.973438321923216},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.45706204921007154,
#   'R2': 0.6390824776624349,
#   'MSPE': 2.293834581670135},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.4578676601250967,
#   'R2': 0.6363446484912455,
#   'MSPE': 2.312441025531352},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.4311572194099426,
#   'R2': 0.6359343523058393,
#   'MSPE': 2.02206024655489},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.4416759456197421,
#   'R2': 0.6345626346350294,
#   'MSPE': 2.034074834576159},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.42839206258455914,
#   'R2': 0.6302891692645708,
#   'MSPE': 1.9111430564086245},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.45004051029682157,
#   'R2': 0.6302205598609402,
#   'MSPE': 2.1221821076904583},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.47152088880538934,
#   'R2': 0.6295151134579935,
#   'MSPE': 2.1024166451146202},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.49015434086322773,
#   'R2': 0.628840996575768,
#   'MSPE': 2.263260901143605},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.44637625217437743,
#   'R2': 0.6270922106433785,
#   'MSPE': 1.9776161642500543},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.43219280739625293,
#   'R2': 0.6194066393609239,
#   'MSPE': 2.010144862920196},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.509281707306703,
#   'R2': 0.6188551082413813,
#   'MSPE': 2.369827693986772},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.48980168998241425,
#   'R2': 0.6162194837312244,
#   'MSPE': 2.2201640327282326},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.47286451011896136,
#   'R2': 0.6145001401819605,
#   'MSPE': 2.1125129473894235},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.4480434621373813,
#   'R2': 0.6109681910797035,
#   'MSPE': 1.9761659312203073},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.5148663739363352,
#   'R2': 0.6043587122074383,
#   'MSPE': 2.1768699332394386},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.4647263740499814,
#   'R2': 0.5895171699546476,
#   'MSPE': 2.116318938576362},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.5253416503469148,
#   'R2': 0.5887863580370272,
#   'MSPE': 2.253596870924788},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.5021865497032801,
#   'R2': 0.5815959604694143,
#   'MSPE': 2.4639973655869865},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.5840617015957832,
#   'R2': 0.5490259245176401,
#   'MSPE': 2.7698847438876677},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.5392169366280237,
#   'R2': 0.5351056357876377,
#   'MSPE': 2.2783516494162153},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.6025374017655849,
#   'R2': 0.529785141868641,
#   'MSPE': 2.771993604055935},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.5909742047389348,
#   'R2': 0.5013481533004612,
#   'MSPE': 2.6784246138325245},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.6310153678059578,
#   'R2': 0.4888210065358779,
#   'MSPE': 3.051843547045883},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.6538053343693416,
#   'R2': 0.4694974286184575,
#   'MSPE': 3.1333248241983283},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.6313829878966015,
#   'R2': 0.4684759164454723,
#   'MSPE': 3.1170337933181513},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.6916021804014842,
#   'R2': 0.46370796858570174,
#   'MSPE': 3.1567465290050913},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.649456025660038,
#   'R2': 0.4632893410125921,
#   'MSPE': 3.032410670673907},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.6858494758605957,
#   'R2': 0.4587739062351829,
#   'MSPE': 3.4777187823195645},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.6823183645804722,
#   'R2': 0.455857616056372,
#   'MSPE': 3.247602889972805},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.6567176813880603,
#   'R2': 0.4540764122905923,
#   'MSPE': 3.03206842392683},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.7053125749031703,
#   'R2': 0.4516785799186345,
#   'MSPE': 3.279779487374154},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.6827344059944153,
#   'R2': 0.4510049947987569,
#   'MSPE': 3.1275318931750578},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.7067190835873285,
#   'R2': 0.4475203102844315,
#   'MSPE': 3.26484136640875},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.7106104383865993,
#   'R2': 0.4460703683850051,
#   'MSPE': 3.616728818213397},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.7014575223128001,
#   'R2': 0.4433013406277391,
#   'MSPE': 3.164128945632414},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.7518828709920247,
#   'R2': 0.44131521000515866,
#   'MSPE': 3.8883332672971065},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.7441457649072012,
#   'R2': 0.4387268411614995,
#   'MSPE': 3.4609729107093026},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.597658692797025,
#   'R2': 0.4382247373360504,
#   'MSPE': 2.839816124601797},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.7293190707763035,
#   'R2': 0.43556720588698716,
#   'MSPE': 3.1565291682879133},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.7582832728823027,
#   'R2': 0.43272574938045094,
#   'MSPE': 3.661599911354257},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.7099995225667952,
#   'R2': 0.4294669159654232,
#   'MSPE': 3.032244655181362},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.7347439467906952,
#   'R2': 0.4179896734568853,
#   'MSPE': 3.302255980482306},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.8198743318518004,
#   'R2': 0.4160871625619514,
#   'MSPE': 3.9275342340797486},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.7116223757465681,
#   'R2': 0.41532799065081616,
#   'MSPE': 2.721169727638063},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.7213774532079696,
#   'R2': 0.3963048809845563,
#   'MSPE': 3.2799030640962146},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.8003893246253332,
#   'R2': 0.3958722088380873,
#   'MSPE': 3.7321615540845827},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.7588237921396892,
#   'R2': 0.3922096746228053,
#   'MSPE': 3.3533475149159484},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.7748069018125534,
#   'R2': 0.39149447480428623,
#   'MSPE': 3.6107983746838683},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.7963020692269007,
#   'R2': 0.3821138190186051,
#   'MSPE': 3.7201893707793774},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.7991077899932861,
#   'R2': 0.38133123249171674,
#   'MSPE': 3.4637555058556373},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.7577393780152003,
#   'R2': 0.38083785879871773,
#   'MSPE': 3.769696874901501},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.7897635211547216,
#   'R2': 0.37357815937099803,
#   'MSPE': 3.37783802187804},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.8167677313089371,
#   'R2': 0.37275316896495025,
#   'MSPE': 3.628872503724062},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.731444752216339,
#   'R2': 0.36962275136745115,
#   'MSPE': 3.2832924334915594},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.8437059362729389,
#   'R2': 0.3672927293855107,
#   'MSPE': 3.8948937774532366},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.7985026687383653,
#   'R2': 0.3657095609433454,
#   'MSPE': 3.7992639589415056},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.7400863369305928,
#   'R2': 0.36534623260375126,
#   'MSPE': 3.397947091496352},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.8249856323003769,
#   'R2': 0.36374314087276816,
#   'MSPE': 3.9023106974653077},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.7994200060764949,
#   'R2': 0.36317078290219723,
#   'MSPE': 3.645495882239004},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.7532866477966309,
#   'R2': 0.3620559395121279,
#   'MSPE': 3.821654886647005},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.7979643791913986,
#   'R2': 0.36092843165321037,
#   'MSPE': 3.544346478701842},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.823721069097519,
#   'R2': 0.35343199498840344,
#   'MSPE': 4.0277277078065605},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.799657600124677,
#   'R2': 0.35195948065992944,
#   'MSPE': 3.717631917785515},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.8168476104736329,
#   'R2': 0.35013682449084693,
#   'MSPE': 3.700772511274225},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.834874893228213,
#   'R2': 0.33734324741039157,
#   'MSPE': 4.061007521143464},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.8413724899291992,
#   'R2': 0.32313539855706674,
#   'MSPE': 4.061040838220806},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.8026615450779598,
#   'R2': 0.31735470813963185,
#   'MSPE': 3.8644608140292798},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.908054401477178,
#   'R2': 0.29315135456246527,
#   'MSPE': 4.457280762644126},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.9007911771535874,
#   'R2': 0.2615862562344704,
#   'MSPE': 4.0547895337445565},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.8828014552593231,
#   'R2': 0.25961087788744613,
#   'MSPE': 3.9508229642730166},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.7456709414720535,
#   'R2': 0.2566355901728984,
#   'MSPE': 2.93664596702038},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.9089627693096796,
#   'R2': 0.23169333514240836,
#   'MSPE': 4.367639568794255},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.92901251912117,
#   'R2': 0.22735840193263696,
#   'MSPE': 4.275904610339138},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 1.4321367412805555,
#   'R2': -0.08477738604836094,
#   'MSPE': 5.2990526382369225},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 1.6239945193131764,
#   'R2': -0.40556285525984065,
#   'MSPE': 5.74983229220967},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 1.6100392798582714,
#   'R2': -0.7381374316517919,
#   'MSPE': 5.979180212386629}]

# %% [markdown]
# As we can see the best parameters is 2 hidden layers with 64 nodes and a learning rate of 1e-3, a momentum of 0.9, and a weight decay of 1e-5.

# %%
train_dataset = DataLoader(TensorDataset(torch.Tensor(x_train), torch.Tensor(y_train)), batch_size=64, shuffle=True)
test_dataset = DataLoader(TensorDataset(torch.Tensor(x_test), torch.Tensor(y_test)), batch_size=64, shuffle=True)
best_model = NeuralNetwork(len(x_train[0]), 2, 64)
train_loop(train_dataset, best_model, lr=1e-3, momentum=0.9, weight_decay=1e-5)
result = {
    "MSE": [],
    "R2": [],
    "MSPE": []
}
test_loop(test_dataset, best_model, result)
print(f"MSE: {result['MSE']}")
print(f"R2: {result['R2']}")
print(f"MSPE: {result['MSPE']}")
# Out:
# MSE: [0.28993074347575504]
# R2: [0.7654101324580855]
# MSPE: [1.340149575844407]

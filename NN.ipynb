# %%
import numpy as np
import pandas as pd
import torch
from torch import nn
from torch.utils.data import DataLoader, TensorDataset
from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import mean_squared_error, r2_score
from utils import gather_data, mean_squared_percentage_error

# %% [markdown]
# # NN Model for regression
# The goal of this model is to build and try a few variances of basic neural networks to see if they can outperform the other regression models.

# %%
data, label = gather_data()
x_train, x_test, y_train, y_test = train_test_split(data, label, test_size=0.2)
y_train, y_test = np.reshape(y_train, (len(y_train), 1)), np.reshape(y_test, (len(y_test), 1))
kfold = KFold(n_splits=10, shuffle=True)
# Out:
# Index(['Log GDP per capita', 'Social support',
#        'Healthy life expectancy at birth', 'Freedom to make life choices',
#        'Generosity', 'Perceptions of corruption', 'Positive affect',
#        'Negative affect', 'Confidence in national government'],
#       dtype='object')

# %%
class NeuralNetwork(nn.Module):
    """
      Represents a Neural Network that can be constructed with a vartiety of hidden layers.
    """
    def __init__(self, input_size, num_hidden_layers, num_nodes_per_layer):
        """
          Initializes a neural network with the specified parameters

          Args:
            input_size: The size of the input feature vector
            num_hidden_layers: The number of hidden layers in the neural network
            num_nodes_per_layer: The number of nodes in each hidden layer
        """
        super().__init__()
        # Start with intialized first layer
        hidden_layers = [nn.Linear(input_size, num_nodes_per_layer)]
        for _ in range(num_hidden_layers):
            hidden_layers.append(nn.Linear(num_nodes_per_layer, num_nodes_per_layer))
            hidden_layers.append(nn.ReLU())
        self.layers = nn.Sequential(*hidden_layers, nn.Linear(num_nodes_per_layer, 1))

    def forward(self, x):
        """
          Feeds x forward through the neural network to get the prediction

          Args:
            x: The feature vector to get the prediction from
        """
        return self.layers(x)

# %%
# The following 2 functions were built with assistance from the torch documentation which has similar functions provided.
def train_loop(dataloader, model, lr=1e-5, num_epochs=200, momentum=0.9, weight_decay: float=None, loss_fn=nn.MSELoss(), early_stopping: int=None):
    """
      Runs the training loop for the model.

      Args:
        dataloader: the dataloader containing the training data
        model: the model to optimize
        lr: The learning rate for the model
        num_epochs: the number of times to repeat the training loop
        momentum: The momentum for SGD
        weight_decay: The amount of weight decay for SGD
        loss_fn: the loss function to optimize
        early_stopping: how many rounds of having a loss that doesn't improve before stopping
    """
    model_dict = {}
    best_model = {}
    best_loss = np.inf
    kept_for = 1
    optimizer = torch.optim.SGD(model.parameters(), lr=lr, momentum=momentum, weight_decay=weight_decay)
    for epoch in range(num_epochs):
        total_loss = 0
        for batch, (X, y) in enumerate(dataloader):
            # Compute prediction and loss
            pred = model(X)
            loss = loss_fn(pred, y)
            total_loss += loss.item()

            # Store model dict for early stopping
            if early_stopping:
                model_dict = model.state_dict()

            # Backpropagation
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
        
        total_loss /= len(dataloader)

        if early_stopping:
            # Determine if we should stop early
            if best_loss < total_loss:
                kept_for += 1
                if kept_for >= early_stopping:
                    model.load_state_dict(best_model)
                    return 
            else:
                best_model = model_dict
                best_loss = total_loss
                kept_for = 1


def test_loop(dataloader, model, result):
    """
      Runs the test loop for the model and outputs the result to the given dictionary

      Args:
        dataloader: The data for the model to be validated on
        model: The model to test
        result: The result dictionary to store the data in.
    """
    num_batches = len(dataloader)
    test_loss, test_r2, test_mspe = 0, 0, 0
    loss_fn = nn.MSELoss()

    with torch.no_grad():
        for X, y in dataloader:
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            test_r2 += r2_score(y.numpy(), pred.numpy())
            test_mspe += mean_squared_percentage_error(y.numpy(), pred.numpy())

    result["MSE"].append(test_loss / num_batches)
    result["R2"].append(test_r2 / num_batches)
    result["MSPE"].append(test_mspe / num_batches)

# %%
results = []
for num_hidden_layers in range(1, 3):
    for num_nodes_per_layer in [8, 16, 32, 64]:
        for lr in [1e-5, 1e-4, 1e-3]:
            for momentum in [.9, .99]:
                for weight_decay in [1e-5, 1e-4, 1e-3, .01, .1, .5]:
                    result = {
                        "num_hidden_layers": num_hidden_layers,
                        "num_nodes_per_layer": num_nodes_per_layer,
                        "lr": lr,
                        "momentum": momentum,
                        "weight_decay": weight_decay,
                        "MSE": [],
                        "R2": [],
                        "MSPE": []
                    }
                    for train_index, val_index in kfold.split(x_train, y_train):
                        train_dataset = DataLoader(TensorDataset(torch.Tensor(x_train[train_index]), torch.Tensor(y_train[train_index])), batch_size=64, shuffle=True)
                        val_dataset= DataLoader(TensorDataset(torch.Tensor(x_train[val_index]), torch.Tensor(y_train[val_index])), batch_size=64, shuffle=True)
                        model = NeuralNetwork(len(x_train[0]), num_hidden_layers=num_hidden_layers, num_nodes_per_layer=num_nodes_per_layer)
                        train_loop(train_dataset, model, lr=lr, momentum=momentum, weight_decay=weight_decay, early_stopping=25)
                        test_loop(val_dataset, model, result)            
                    result["MSE"] = np.mean(result["MSE"])
                    result["R2"] = np.mean(result["R2"])
                    result["MSPE"] = np.mean(result["MSPE"])
                    results.append(result)

# %%
results
# Out:
# [{'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 1.506544715166092,
#   'R2': -0.10082205577140044,
#   'MSPE': 5.32199385321953},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.8004551142454147,
#   'R2': 0.3515958457261288,
#   'MSPE': 3.6913879522395256},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.7843132515748342,
#   'R2': 0.3523899988355199,
#   'MSPE': 3.682336323527676},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.7858529672026634,
#   'R2': 0.39562178340429,
#   'MSPE': 3.868272131064324},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.830386303861936,
#   'R2': 0.3321341329537864,
#   'MSPE': 3.6741405386816366},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.8153032312790552,
#   'R2': 0.31767458212283356,
#   'MSPE': 3.787856078847791},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.3206242973605792,
#   'R2': 0.7545500233426206,
#   'MSPE': 1.6261686967930409},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.3136638234059016,
#   'R2': 0.7523000881303923,
#   'MSPE': 1.6044871845856459},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.3035367858906587,
#   'R2': 0.7286099819957063,
#   'MSPE': 1.4814751216144573},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.31453597396612165,
#   'R2': 0.7406534830881384,
#   'MSPE': 1.6366276361349257},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.38229506313800815,
#   'R2': 0.6956772915120579,
#   'MSPE': 1.9582877737103086},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.4728386849164964,
#   'R2': 0.6221379463713701,
#   'MSPE': 2.0952331374465216},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.29360869725545247,
#   'R2': 0.7753791328722558,
#   'MSPE': 1.5359072245168266},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.41630413209398587,
#   'R2': 0.6809858211756525,
#   'MSPE': 2.1784477110839253},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.3195435002446175,
#   'R2': 0.7568453643650536,
#   'MSPE': 1.609098750702811},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.2987378301719824,
#   'R2': 0.7559491801452526,
#   'MSPE': 1.4678750391296966},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.3202543750405312,
#   'R2': 0.7424915599114166,
#   'MSPE': 1.6548579113764894},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.4980149259169897,
#   'R2': 0.6355585146768656,
#   'MSPE': 2.388833888213743},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.2672379565735658,
#   'R2': 0.778699390996352,
#   'MSPE': 1.3083298265407184},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.2778002008795738,
#   'R2': 0.7762567653753158,
#   'MSPE': 1.3695618525768318},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.26404761523008347,
#   'R2': 0.7818992399126978,
#   'MSPE': 1.364856681391371},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.2878108754754066,
#   'R2': 0.765582152133086,
#   'MSPE': 1.3916635643126383},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.28637608240048085,
#   'R2': 0.7512313890522896,
#   'MSPE': 1.39249954767751},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.4489732826749483,
#   'R2': 0.6366865550007855,
#   'MSPE': 2.1277595091272485},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.29277817259232203,
#   'R2': 0.7627554524284939,
#   'MSPE': 1.5927258735014633},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.28814086988568305,
#   'R2': 0.7690466414412275,
#   'MSPE': 1.5722906610204113},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.28604132135709126,
#   'R2': 0.765503209578876,
#   'MSPE': 1.4674147827118034},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.2846101835370064,
#   'R2': 0.7683571067203563,
#   'MSPE': 1.36052269784903},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.3047900329033533,
#   'R2': 0.7467129602537972,
#   'MSPE': 1.5771344828071319},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.5078878919283549,
#   'R2': 0.6040183637035368,
#   'MSPE': 2.5514000737945537},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.321014674504598,
#   'R2': 0.7456101977420622,
#   'MSPE': 1.6203906500918996},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.38438661222656567,
#   'R2': 0.6846179464630735,
#   'MSPE': 1.8850492781046964},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.2914689478774865,
#   'R2': 0.7620582199007215,
#   'MSPE': 1.3997397097674282},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.5127624243497848,
#   'R2': 0.5617461839857089,
#   'MSPE': 2.4871655212094383},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.3153584149976571,
#   'R2': 0.7410090646301631,
#   'MSPE': 1.461837456815622},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.49242142736911776,
#   'R2': 0.6120496491662999,
#   'MSPE': 2.18935599400088},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.8135547637939453,
#   'R2': 0.37250109728594555,
#   'MSPE': 3.7365031296932933},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.7762346367041271,
#   'R2': 0.36884236481885585,
#   'MSPE': 3.570074255418296},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.7743170713384947,
#   'R2': 0.400650070050433,
#   'MSPE': 4.075710462650868},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.7627199977636338,
#   'R2': 0.4147614432634409,
#   'MSPE': 3.6834925174186326},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.7039451628923417,
#   'R2': 0.4455353120926235,
#   'MSPE': 3.059706519160307},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.785241142908732,
#   'R2': 0.3772908899367525,
#   'MSPE': 3.230452584384969},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.2937079711506764,
#   'R2': 0.7502973516264915,
#   'MSPE': 1.4417338437127944},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.2755730715890725,
#   'R2': 0.763798237373679,
#   'MSPE': 1.2974860356424494},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.29514638384183256,
#   'R2': 0.7618858899974417,
#   'MSPE': 1.550538633771316},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.3189514741301536,
#   'R2': 0.743052885022202,
#   'MSPE': 1.4678334179475452},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.3106372738877933,
#   'R2': 0.7320359085608047,
#   'MSPE': 1.5711490189976465},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.45921894808610286,
#   'R2': 0.6084636472823416,
#   'MSPE': 1.9988431639480169},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.2893712192773819,
#   'R2': 0.759356571941343,
#   'MSPE': 1.4015905534133617},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.2865105298658212,
#   'R2': 0.7474559175395591,
#   'MSPE': 1.3868872233845218},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.27600551918148997,
#   'R2': 0.7809085683986139,
#   'MSPE': 1.3173585891196824},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.30061825960874555,
#   'R2': 0.7479110638325492,
#   'MSPE': 1.4580749786186096},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.3202662100394567,
#   'R2': 0.7423879047408872,
#   'MSPE': 1.62213203323196},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.4578500109414259,
#   'R2': 0.6266185102170521,
#   'MSPE': 2.0760968494031466},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.28490638385216394,
#   'R2': 0.7708176811721467,
#   'MSPE': 1.4472056818523944},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.2504825517535209,
#   'R2': 0.7952506301122343,
#   'MSPE': 1.206150301732123},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.25640386467178666,
#   'R2': 0.7757419338883176,
#   'MSPE': 1.2707865692562226},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.26814555525779726,
#   'R2': 0.7808469074582074,
#   'MSPE': 1.3260637059092821},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.2978977270424366,
#   'R2': 0.7584774809126426,
#   'MSPE': 1.6410472080337275},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.45142421176036207,
#   'R2': 0.6169310431575629,
#   'MSPE': 2.046297925966557},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.27923559447129565,
#   'R2': 0.7392826427027336,
#   'MSPE': 1.3405330699746207},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.288419525573651,
#   'R2': 0.7564140126746414,
#   'MSPE': 1.433776351246945},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.2936827279627323,
#   'R2': 0.7710668143576246,
#   'MSPE': 1.4349732341978583},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.2787899581094583,
#   'R2': 0.7652185373510966,
#   'MSPE': 1.373124175300502},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.30383237401644386,
#   'R2': 0.7600242357804567,
#   'MSPE': 1.7085493885620378},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.443372110525767,
#   'R2': 0.6225338647654794,
#   'MSPE': 2.019651011008807},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.28008868992328645,
#   'R2': 0.7567704958251074,
#   'MSPE': 1.277712414774931},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.37294943332672126,
#   'R2': 0.7031164621794563,
#   'MSPE': 1.7771590027882893},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.2930757403373718,
#   'R2': 0.7449594723501618,
#   'MSPE': 1.3888022923522225},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.31575774649779,
#   'R2': 0.7544439566434458,
#   'MSPE': 1.6679118737352616},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.3177334249019622,
#   'R2': 0.7270205587142797,
#   'MSPE': 1.5889299361768998},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.5318806529045106,
#   'R2': 0.5951668123701207,
#   'MSPE': 2.1290774043235507},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.8043655316034952,
#   'R2': 0.39369300601591556,
#   'MSPE': 3.5911405447757603},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.7912521759668987,
#   'R2': 0.3987547973098255,
#   'MSPE': 3.8021648953659364},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.6448573340972266,
#   'R2': 0.47532429128796094,
#   'MSPE': 3.0808565489044692},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.6796710560719171,
#   'R2': 0.4321203916826092,
#   'MSPE': 3.0928523857334644},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.6766906380653381,
#   'R2': 0.43542941607329694,
#   'MSPE': 3.108137726520348},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.6797706047693889,
#   'R2': 0.4391412213102142,
#   'MSPE': 3.0185279180530946},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.29860365688800816,
#   'R2': 0.7672951745047873,
#   'MSPE': 1.5047976340759885},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.2692669846117497,
#   'R2': 0.7783094636610576,
#   'MSPE': 1.3665850605872092},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.2684418837229411,
#   'R2': 0.7738426322876591,
#   'MSPE': 1.2938432939200089},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.29277506222327554,
#   'R2': 0.7707401079484164,
#   'MSPE': 1.4627700024331458},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.31675138572851813,
#   'R2': 0.7322345358383279,
#   'MSPE': 1.5654259413066836},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.4832891722520193,
#   'R2': 0.6151800548355093,
#   'MSPE': 2.1462118004759154},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.29529480487108234,
#   'R2': 0.7624175558950813,
#   'MSPE': 1.5349674767654653},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.2713685671488444,
#   'R2': 0.7792464382989459,
#   'MSPE': 1.448241156064952},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.29395142793655393,
#   'R2': 0.7808537609042603,
#   'MSPE': 1.66243876189445},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.2914559232691924,
#   'R2': 0.7437333371394086,
#   'MSPE': 1.4563850496867388},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.31107618163029355,
#   'R2': 0.7437553592960513,
#   'MSPE': 1.5268151017112863},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.44941769788662594,
#   'R2': 0.6337630937818353,
#   'MSPE': 2.114677515558221},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.24820603281259537,
#   'R2': 0.7946429363376633,
#   'MSPE': 1.2117934468757325},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.26556308666865036,
#   'R2': 0.7512792841742826,
#   'MSPE': 1.2975246207130076},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.2837430673340956,
#   'R2': 0.7298520144675407,
#   'MSPE': 1.3777715279579614},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.2715056074162325,
#   'R2': 0.7885167398392003,
#   'MSPE': 1.3960589623699584},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.2970374797781309,
#   'R2': 0.7174318301200776,
#   'MSPE': 1.4640123149229571},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.43256742904583617,
#   'R2': 0.6440051482672753,
#   'MSPE': 2.133879980937851},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.2684639061490695,
#   'R2': 0.7815574137336729,
#   'MSPE': 1.286024117484839},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.27343606576323515,
#   'R2': 0.7645505198175131,
#   'MSPE': 1.3419397704472595},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.3106424957513809,
#   'R2': 0.7422776671326765,
#   'MSPE': 1.5483767942835889},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.2819360961516698,
#   'R2': 0.7565420725295212,
#   'MSPE': 1.359235578583497},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.283065868417422,
#   'R2': 0.7849633702886999,
#   'MSPE': 1.4274293713911312},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.45643368661403655,
#   'R2': 0.6488799122215074,
#   'MSPE': 2.1297562660442457},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.30814845214287445,
#   'R2': 0.7697355223529675,
#   'MSPE': 1.4862354731450629},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.29951120068629583,
#   'R2': 0.7555782744732056,
#   'MSPE': 1.4340754328389662},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.2908687810103099,
#   'R2': 0.752842974906627,
#   'MSPE': 1.4982934242039168},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.28907000174125036,
#   'R2': 0.7578524795071544,
#   'MSPE': 1.3625957819661407},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.3172505170106888,
#   'R2': 0.7199474295179091,
#   'MSPE': 1.4672964955256744},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.526440279185772,
#   'R2': 0.5852753992694286,
#   'MSPE': 2.4151616563286744},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.6383176694313685,
#   'R2': 0.505667344858195,
#   'MSPE': 3.1396172223894885},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.6401743710041046,
#   'R2': 0.48419828011086474,
#   'MSPE': 3.0866959273363603},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.5979713569084804,
#   'R2': 0.516090689869696,
#   'MSPE': 2.7788161311411494},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.6045774946610133,
#   'R2': 0.4643595558258887,
#   'MSPE': 3.1740501451522416},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.651260131597519,
#   'R2': 0.4832859523297851,
#   'MSPE': 3.1233442544636096},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.7300204289456209,
#   'R2': 0.438777989315515,
#   'MSPE': 3.1923190348151356},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.2835865408182144,
#   'R2': 0.7661886523172186,
#   'MSPE': 1.3807601139250427},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.2829428342481454,
#   'R2': 0.773626652796654,
#   'MSPE': 1.399961584576904},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.2760750040411949,
#   'R2': 0.7819766125425588,
#   'MSPE': 1.3425658778710798},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.29353318785627686,
#   'R2': 0.7636806643568586,
#   'MSPE': 1.572286139778567},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.3206505589187146,
#   'R2': 0.7451301331230085,
#   'MSPE': 1.6596511202027102},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.468572657306989,
#   'R2': 0.6247446808654114,
#   'MSPE': 2.1694410694857136},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.2890004500746727,
#   'R2': 0.7604960627718628,
#   'MSPE': 1.4635801634215047},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.27610114961862564,
#   'R2': 0.7623192328515903,
#   'MSPE': 1.3683640424425554},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.2969648055732251,
#   'R2': 0.7654118409289845,
#   'MSPE': 1.4308055643594324},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.2746464210251967,
#   'R2': 0.7817941607283398,
#   'MSPE': 1.3641747489872604},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.2840479739010334,
#   'R2': 0.7663135012933614,
#   'MSPE': 1.4165968331273153},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.46411734869082777,
#   'R2': 0.6368887945893874,
#   'MSPE': 2.187437328105472},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.26580502539873124,
#   'R2': 0.7760498266188522,
#   'MSPE': 1.3219306033311615},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.2619648344814778,
#   'R2': 0.7843790810872612,
#   'MSPE': 1.3074695234271616},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.2912631432215373,
#   'R2': 0.7821541754769801,
#   'MSPE': 1.5366863150318915},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.2850198050340017,
#   'R2': 0.7725464772458441,
#   'MSPE': 1.5456403662083729},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.2867122049132983,
#   'R2': 0.7699715394346364,
#   'MSPE': 1.3742968251909873},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.43714419802029925,
#   'R2': 0.6552247960441504,
#   'MSPE': 1.9979132073131776},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.27064840123057365,
#   'R2': 0.7779962886762833,
#   'MSPE': 1.365590351586691},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.2915977622071902,
#   'R2': 0.7490953169687096,
#   'MSPE': 1.3747853252359412},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.2801724411547184,
#   'R2': 0.7626356244974395,
#   'MSPE': 1.3839802607856313},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.2722464258472125,
#   'R2': 0.7677928667261211,
#   'MSPE': 1.3661071144025585},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.302132863799731,
#   'R2': 0.7636335780516408,
#   'MSPE': 1.6713425502971266},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.4640102614959082,
#   'R2': 0.6162557592670126,
#   'MSPE': 2.185931319013388},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.27860219155748683,
#   'R2': 0.767233809057781,
#   'MSPE': 1.3661883669820698},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.2722931355237961,
#   'R2': 0.7801318002291853,
#   'MSPE': 1.2759570804697393},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.33910959089795745,
#   'R2': 0.7276130888522625,
#   'MSPE': 1.5939964497029178},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.3053477759162585,
#   'R2': 0.7378616490137431,
#   'MSPE': 1.5254842445743502},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.2974096218744914,
#   'R2': 0.7495229046069095,
#   'MSPE': 1.3897107919734535},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.47914071083068854,
#   'R2': 0.6163197692001285,
#   'MSPE': 2.024127125100355},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.9351383745670319,
#   'R2': 0.22772972443267858,
#   'MSPE': 4.246546307371721},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 1.5909140398104988,
#   'R2': -0.2957832406634227,
#   'MSPE': 5.727947088090157},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.9288565476735433,
#   'R2': 0.2661623061043307,
#   'MSPE': 4.407254293410465},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 1.7476111729939778,
#   'R2': -0.42795251114875177,
#   'MSPE': 6.7951512468433135},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 1.6786820769309998,
#   'R2': -0.4668385707717097,
#   'MSPE': 6.1665751435088385},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 1.751923614740372,
#   'R2': -0.49006174760724086,
#   'MSPE': 6.138147420127585},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.4010453852514426,
#   'R2': 0.6802297392609937,
#   'MSPE': 2.0154067151474226},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.35458887318770094,
#   'R2': 0.6841471285441323,
#   'MSPE': 1.85707270167768},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.4078705189128716,
#   'R2': 0.6686675038622452,
#   'MSPE': 2.0592679588989626},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.428153125445048,
#   'R2': 0.6566980793503404,
#   'MSPE': 2.1158195389528767},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.36586884309848144,
#   'R2': 0.703205470176714,
#   'MSPE': 1.795030233233866},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.48887809664011,
#   'R2': 0.6153755075839517,
#   'MSPE': 2.3327977989207613},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.29729838619629545,
#   'R2': 0.7495880461315579,
#   'MSPE': 1.4483803800881057},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.3037461832165718,
#   'R2': 0.7566256646229078,
#   'MSPE': 1.4979052930280115},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.30500322282314296,
#   'R2': 0.737834143830148,
#   'MSPE': 1.4865725917854544},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.2850965842604637,
#   'R2': 0.7762911274046448,
#   'MSPE': 1.4456993178699653},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.3012295328080654,
#   'R2': 0.7390471070925588,
#   'MSPE': 1.5111902956333423},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.48400702476501467,
#   'R2': 0.6232394105932938,
#   'MSPE': 2.461388073485307},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.28175161356727274,
#   'R2': 0.7725682161115864,
#   'MSPE': 1.4384798930882654},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.5152450223763784,
#   'R2': 0.5928702965382141,
#   'MSPE': 2.5138863963498315},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.3815117531766494,
#   'R2': 0.7056015708560457,
#   'MSPE': 1.8373866914536314},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.27633951008319857,
#   'R2': 0.7806837594934624,
#   'MSPE': 1.3712058264780977},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.5170574267705281,
#   'R2': 0.5552597278131688,
#   'MSPE': 2.1458304705888485},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.7685425678888957,
#   'R2': 0.40809469578358054,
#   'MSPE': 3.183243681648464},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.2730664283037186,
#   'R2': 0.7746640199690653,
#   'MSPE': 1.3352220137650617},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.28197768976291016,
#   'R2': 0.7781452709490457,
#   'MSPE': 1.5621088092412911},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.28220873996615414,
#   'R2': 0.7572790418957276,
#   'MSPE': 1.346515368039936},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.46786429112156236,
#   'R2': 0.6181647715314024,
#   'MSPE': 2.1655029155351597},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.2750574566423893,
#   'R2': 0.7681176445021138,
#   'MSPE': 1.361995210325477},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.43546711653470993,
#   'R2': 0.6439794303840654,
#   'MSPE': 2.025867583079621},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.7885004848241806,
#   'R2': 0.3798449268173054,
#   'MSPE': 3.8299546059634957},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.7815490424633026,
#   'R2': 0.3228537893713919,
#   'MSPE': 3.508979133377322},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 1.2316417346398034,
#   'R2': 0.04612934681488044,
#   'MSPE': 5.794474756947219},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.7147583141922952,
#   'R2': 0.40541643013972334,
#   'MSPE': 3.113880180330439},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.3463412001729012,
#   'R2': 0.7009360949925025,
#   'MSPE': 1.6284322678440748},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.46076300640900925,
#   'R2': 0.6060875221374366,
#   'MSPE': 2.113668727453309},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.8267142375310261,
#   'R2': 0.29021872398232135,
#   'MSPE': 3.8419193637115177},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.8802626033624014,
#   'R2': 0.3184082672783092,
#   'MSPE': 4.360958721977894},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.8465916951497394,
#   'R2': 0.36314810038551004,
#   'MSPE': 4.401083561507138},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.8319656898578007,
#   'R2': 0.3600353232710037,
#   'MSPE': 3.9115263467108967},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.8723186453183492,
#   'R2': 0.28947881969586914,
#   'MSPE': 4.106247493752627},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.860820072889328,
#   'R2': 0.31895236682879047,
#   'MSPE': 3.8404637046459342},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.3037688732147217,
#   'R2': 0.7603428312221929,
#   'MSPE': 1.463024804998904},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.3062986969947815,
#   'R2': 0.749753128957149,
#   'MSPE': 1.4917306189020778},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.32278906007607777,
#   'R2': 0.7279181244019066,
#   'MSPE': 1.7309987427422193},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.32312036057313287,
#   'R2': 0.7555811075377707,
#   'MSPE': 1.6914863280500427},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.3053191641966502,
#   'R2': 0.768635714999381,
#   'MSPE': 1.6261795585542316},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.46742291996876395,
#   'R2': 0.6323990909994209,
#   'MSPE': 2.1872074115607476},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.2710120027263959,
#   'R2': 0.7780096791790215,
#   'MSPE': 1.3105710352197137},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.2963984730343024,
#   'R2': 0.7493935790856396,
#   'MSPE': 1.42603439180124},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.2786549044152101,
#   'R2': 0.7601028218913455,
#   'MSPE': 1.3875951481550328},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.277553778141737,
#   'R2': 0.7833218229516627,
#   'MSPE': 1.4213845273009453},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.279539313664039,
#   'R2': 0.7706971414871142,
#   'MSPE': 1.4070910061098107},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.46083315064509706,
#   'R2': 0.6007494329158665,
#   'MSPE': 2.2952719620720607},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.27937046686808265,
#   'R2': 0.7853880219344729,
#   'MSPE': 1.4388835730708458},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.25267310552299027,
#   'R2': 0.7882869147580953,
#   'MSPE': 1.1877650669258502},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.2827803713579973,
#   'R2': 0.7600460061581286,
#   'MSPE': 1.393715464180768},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.2750836918751398,
#   'R2': 0.776272040532389,
#   'MSPE': 1.4563348075619553},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.40533652057250336,
#   'R2': 0.6844460458823823,
#   'MSPE': 1.9565731698101518},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.4907850493987402,
#   'R2': 0.5913712262289431,
#   'MSPE': 2.224238884512975},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.27980912874142333,
#   'R2': 0.76239909350443,
#   'MSPE': 1.3231155494547855},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.2884929259618123,
#   'R2': 0.7545548707225108,
#   'MSPE': 1.4279249539090828},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.25826961224277817,
#   'R2': 0.7791177245030748,
#   'MSPE': 1.1914636914364318},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.2713683652381102,
#   'R2': 0.7539927601395157,
#   'MSPE': 1.3159100400904813},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.29104727307955425,
#   'R2': 0.7384679435667726,
#   'MSPE': 1.4001681923753384},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.4427178492148717,
#   'R2': 0.6422271711411668,
#   'MSPE': 2.2254691411261307},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.6376119780043761,
#   'R2': 0.4603702729522248,
#   'MSPE': 2.869903241105453},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.9076090534528095,
#   'R2': 0.24994153548766831,
#   'MSPE': 3.938371169973503},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.7069946885108948,
#   'R2': 0.3879827206636672,
#   'MSPE': 3.7025027731997953},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.4392399311065674,
#   'R2': 0.6055821843266961,
#   'MSPE': 2.0592128434641794},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.35625372330347693,
#   'R2': 0.7108924190995397,
#   'MSPE': 1.851512197536802},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.49506877958774564,
#   'R2': 0.5687346445540331,
#   'MSPE': 2.0675078666571416},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.7295434584220251,
#   'R2': 0.3718111406441908,
#   'MSPE': 3.370985601925187},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.7702844272057214,
#   'R2': 0.3461947569902436,
#   'MSPE': 3.727453425338472},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.7752914746602377,
#   'R2': 0.38287378121696225,
#   'MSPE': 3.5340964049100876},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.7754119038581848,
#   'R2': 0.36991984137007344,
#   'MSPE': 3.8934521401545625},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.8257550845543543,
#   'R2': 0.39262769238721307,
#   'MSPE': 4.082884302908423},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.8051259701450666,
#   'R2': 0.3563482518215214,
#   'MSPE': 3.9154331762381274},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.28797180553277335,
#   'R2': 0.7670148825059518,
#   'MSPE': 1.4377880009888397},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.29666791260242464,
#   'R2': 0.7646982734319366,
#   'MSPE': 1.5084383419404426},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.2909582957625389,
#   'R2': 0.760260157533478,
#   'MSPE': 1.4006999506135327},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.29358025491237644,
#   'R2': 0.7501915347979031,
#   'MSPE': 1.4110493895155611},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.32603381127119063,
#   'R2': 0.7370850620063132,
#   'MSPE': 1.9132216035792922},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.4649044170975685,
#   'R2': 0.6435287559255186,
#   'MSPE': 2.1119563244847637},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.30568955739339193,
#   'R2': 0.7327523717776779,
#   'MSPE': 1.5012866480633469},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.3011747196316719,
#   'R2': 0.7395883869406623,
#   'MSPE': 1.4963764432968216},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.27430406380444766,
#   'R2': 0.7806502497190972,
#   'MSPE': 1.3738459771536669},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.27382038806875547,
#   'R2': 0.7848412364214282,
#   'MSPE': 1.3235596833148537},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.29879030336936313,
#   'R2': 0.7509965777912467,
#   'MSPE': 1.449550294571302},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.4364707047740618,
#   'R2': 0.6321400487432777,
#   'MSPE': 2.0187845218437492},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.2641682179023822,
#   'R2': 0.7876295682765496,
#   'MSPE': 1.2501864505442555},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.29251247371236483,
#   'R2': 0.7632991148739463,
#   'MSPE': 1.441565676394737},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.2658121262987455,
#   'R2': 0.7838451044723937,
#   'MSPE': 1.347918263777639},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.2561137355864048,
#   'R2': 0.7564829938331542,
#   'MSPE': 1.2896378468157665},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.2845151456693808,
#   'R2': 0.7752259939147584,
#   'MSPE': 1.4267512543522047},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.5393525933225949,
#   'R2': 0.588273055687581,
#   'MSPE': 2.52368594143502},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.2573148580888907,
#   'R2': 0.7947204879721369,
#   'MSPE': 1.2185531493389246},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.27645349701245625,
#   'R2': 0.7289343859270875,
#   'MSPE': 1.3115778667946354},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.26151562357942265,
#   'R2': 0.747768486141144,
#   'MSPE': 1.2609759899270203},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.277348413442572,
#   'R2': 0.7664768744911894,
#   'MSPE': 1.330432373785762},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.2928163637717565,
#   'R2': 0.7581493952416982,
#   'MSPE': 1.41646425813587},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.46613832811514533,
#   'R2': 0.6348694196110137,
#   'MSPE': 2.2201653726097907},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.3105003786583741,
#   'R2': 0.737528578697346,
#   'MSPE': 1.530913157774267},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.2888811275362968,
#   'R2': 0.7567889459047556,
#   'MSPE': 1.3820537125146148},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.4011709238092105,
#   'R2': 0.6833440851324164,
#   'MSPE': 1.7822972543518802},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.27191315963864326,
#   'R2': 0.7701227534037768,
#   'MSPE': 1.2668940336960883},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.3154096702734629,
#   'R2': 0.7521454144716062,
#   'MSPE': 1.5708796504057112},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.45682914753754933,
#   'R2': 0.6495368460993468,
#   'MSPE': 2.340615076022317},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.7239603579044342,
#   'R2': 0.4382065643703739,
#   'MSPE': 3.337574480948123},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.6901666929324468,
#   'R2': 0.43037934200042993,
#   'MSPE': 3.288248475603383},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.6404296492536863,
#   'R2': 0.4767817666831136,
#   'MSPE': 3.0997125657670423},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.7193225463231405,
#   'R2': 0.4489534675911518,
#   'MSPE': 3.3027543851898775},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.6461367865403493,
#   'R2': 0.46525027098437227,
#   'MSPE': 3.0153131291194994},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.7222910275061926,
#   'R2': 0.4259761041341438,
#   'MSPE': 3.250613996966018},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.28737024043997134,
#   'R2': 0.7681873636790036,
#   'MSPE': 1.4122756460512225},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.2810325903818011,
#   'R2': 0.7781756536865003,
#   'MSPE': 1.3385959842590371},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.2962344547112783,
#   'R2': 0.7430575153534272,
#   'MSPE': 1.4443237850950523},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.28230525404214857,
#   'R2': 0.7587048190371414,
#   'MSPE': 1.5515529560960002},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.30296070600549385,
#   'R2': 0.7652036100060455,
#   'MSPE': 1.554564862897751},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.44471856355667116,
#   'R2': 0.652613187123098,
#   'MSPE': 2.044342642254901},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.25962650825579964,
#   'R2': 0.7744233891199915,
#   'MSPE': 1.2210708278974498},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.30370789567629497,
#   'R2': 0.7699681081313863,
#   'MSPE': 1.5511515878630104},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.29342511619130773,
#   'R2': 0.7656479355101702,
#   'MSPE': 1.3291713258609026},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.2621487148106098,
#   'R2': 0.7862976830406048,
#   'MSPE': 1.2440426942111564},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.2961175824205081,
#   'R2': 0.7596333203443646,
#   'MSPE': 1.4857896682194842},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.4493006855249405,
#   'R2': 0.6477508100421371,
#   'MSPE': 2.2145549017898363},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.2602107857664426,
#   'R2': 0.7859999397713402,
#   'MSPE': 1.2893872487010678},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.27097111468513807,
#   'R2': 0.784803379866696,
#   'MSPE': 1.4388455594466492},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.2666072790821393,
#   'R2': 0.7557642687151521,
#   'MSPE': 1.3101674367984137},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.2600494258105755,
#   'R2': 0.7926445707599233,
#   'MSPE': 1.2121827240958056},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.3051061319808165,
#   'R2': 0.7358284036691389,
#   'MSPE': 1.5061433421391428},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.4506145780285199,
#   'R2': 0.6418092491049185,
#   'MSPE': 2.1686837699903982},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.24924166748921076,
#   'R2': 0.7983637068863594,
#   'MSPE': 1.2033620677568544},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.2613672281304995,
#   'R2': 0.7931898025307588,
#   'MSPE': 1.2167842200759686},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.2604059144854546,
#   'R2': 0.782802910572781,
#   'MSPE': 1.2683086205424383},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.2798059890667598,
#   'R2': 0.7551536714318017,
#   'MSPE': 1.2945814620741087},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.2871459866563479,
#   'R2': 0.7643932999803623,
#   'MSPE': 1.4036468289453876},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.42563255280256274,
#   'R2': 0.6664003966199096,
#   'MSPE': 2.0208422205589636},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.27993307262659073,
#   'R2': 0.7631970316585599,
#   'MSPE': 1.2779794665373334},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.28835901543498044,
#   'R2': 0.7711596252581019,
#   'MSPE': 1.4603510827315274},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.3549044010539849,
#   'R2': 0.7027054883421857,
#   'MSPE': 1.5984759276563472},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.2920766000946363,
#   'R2': 0.7688100600024018,
#   'MSPE': 1.345603729814592},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.33210827733079595,
#   'R2': 0.7216691658018396,
#   'MSPE': 1.4725423089670713},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.47921750545501707,
#   'R2': 0.6005685868736349,
#   'MSPE': 2.389166499629165}]

# %%
import json
with open("nn_results.json", "wt") as f:
    json.dump(results, f)

# %%
# Sort by lowest MSE
sorted(results, key=lambda x: x["MSE"])
# Out:
# [{'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.24820603281259537,
#   'R2': 0.7946429363376633,
#   'MSPE': 1.2117934468757325},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.24924166748921076,
#   'R2': 0.7983637068863594,
#   'MSPE': 1.2033620677568544},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.2504825517535209,
#   'R2': 0.7952506301122343,
#   'MSPE': 1.206150301732123},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.25267310552299027,
#   'R2': 0.7882869147580953,
#   'MSPE': 1.1877650669258502},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.2561137355864048,
#   'R2': 0.7564829938331542,
#   'MSPE': 1.2896378468157665},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.25640386467178666,
#   'R2': 0.7757419338883176,
#   'MSPE': 1.2707865692562226},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.2573148580888907,
#   'R2': 0.7947204879721369,
#   'MSPE': 1.2185531493389246},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.25826961224277817,
#   'R2': 0.7791177245030748,
#   'MSPE': 1.1914636914364318},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.25962650825579964,
#   'R2': 0.7744233891199915,
#   'MSPE': 1.2210708278974498},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.2600494258105755,
#   'R2': 0.7926445707599233,
#   'MSPE': 1.2121827240958056},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.2602107857664426,
#   'R2': 0.7859999397713402,
#   'MSPE': 1.2893872487010678},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.2604059144854546,
#   'R2': 0.782802910572781,
#   'MSPE': 1.2683086205424383},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.2613672281304995,
#   'R2': 0.7931898025307588,
#   'MSPE': 1.2167842200759686},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.26151562357942265,
#   'R2': 0.747768486141144,
#   'MSPE': 1.2609759899270203},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.2619648344814778,
#   'R2': 0.7843790810872612,
#   'MSPE': 1.3074695234271616},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.2621487148106098,
#   'R2': 0.7862976830406048,
#   'MSPE': 1.2440426942111564},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.26404761523008347,
#   'R2': 0.7818992399126978,
#   'MSPE': 1.364856681391371},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.2641682179023822,
#   'R2': 0.7876295682765496,
#   'MSPE': 1.2501864505442555},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.26556308666865036,
#   'R2': 0.7512792841742826,
#   'MSPE': 1.2975246207130076},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.26580502539873124,
#   'R2': 0.7760498266188522,
#   'MSPE': 1.3219306033311615},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.2658121262987455,
#   'R2': 0.7838451044723937,
#   'MSPE': 1.347918263777639},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.2666072790821393,
#   'R2': 0.7557642687151521,
#   'MSPE': 1.3101674367984137},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.2672379565735658,
#   'R2': 0.778699390996352,
#   'MSPE': 1.3083298265407184},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.26814555525779726,
#   'R2': 0.7808469074582074,
#   'MSPE': 1.3260637059092821},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.2684418837229411,
#   'R2': 0.7738426322876591,
#   'MSPE': 1.2938432939200089},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.2684639061490695,
#   'R2': 0.7815574137336729,
#   'MSPE': 1.286024117484839},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.2692669846117497,
#   'R2': 0.7783094636610576,
#   'MSPE': 1.3665850605872092},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.27064840123057365,
#   'R2': 0.7779962886762833,
#   'MSPE': 1.365590351586691},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.27097111468513807,
#   'R2': 0.784803379866696,
#   'MSPE': 1.4388455594466492},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.2710120027263959,
#   'R2': 0.7780096791790215,
#   'MSPE': 1.3105710352197137},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.2713683652381102,
#   'R2': 0.7539927601395157,
#   'MSPE': 1.3159100400904813},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.2713685671488444,
#   'R2': 0.7792464382989459,
#   'MSPE': 1.448241156064952},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.2715056074162325,
#   'R2': 0.7885167398392003,
#   'MSPE': 1.3960589623699584},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.27191315963864326,
#   'R2': 0.7701227534037768,
#   'MSPE': 1.2668940336960883},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.2722464258472125,
#   'R2': 0.7677928667261211,
#   'MSPE': 1.3661071144025585},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.2722931355237961,
#   'R2': 0.7801318002291853,
#   'MSPE': 1.2759570804697393},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.2730664283037186,
#   'R2': 0.7746640199690653,
#   'MSPE': 1.3352220137650617},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.27343606576323515,
#   'R2': 0.7645505198175131,
#   'MSPE': 1.3419397704472595},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.27382038806875547,
#   'R2': 0.7848412364214282,
#   'MSPE': 1.3235596833148537},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.27430406380444766,
#   'R2': 0.7806502497190972,
#   'MSPE': 1.3738459771536669},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.2746464210251967,
#   'R2': 0.7817941607283398,
#   'MSPE': 1.3641747489872604},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.2750574566423893,
#   'R2': 0.7681176445021138,
#   'MSPE': 1.361995210325477},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.2750836918751398,
#   'R2': 0.776272040532389,
#   'MSPE': 1.4563348075619553},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.2755730715890725,
#   'R2': 0.763798237373679,
#   'MSPE': 1.2974860356424494},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.27600551918148997,
#   'R2': 0.7809085683986139,
#   'MSPE': 1.3173585891196824},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.2760750040411949,
#   'R2': 0.7819766125425588,
#   'MSPE': 1.3425658778710798},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.27610114961862564,
#   'R2': 0.7623192328515903,
#   'MSPE': 1.3683640424425554},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.27633951008319857,
#   'R2': 0.7806837594934624,
#   'MSPE': 1.3712058264780977},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.27645349701245625,
#   'R2': 0.7289343859270875,
#   'MSPE': 1.3115778667946354},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.277348413442572,
#   'R2': 0.7664768744911894,
#   'MSPE': 1.330432373785762},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.277553778141737,
#   'R2': 0.7833218229516627,
#   'MSPE': 1.4213845273009453},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.2778002008795738,
#   'R2': 0.7762567653753158,
#   'MSPE': 1.3695618525768318},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.27860219155748683,
#   'R2': 0.767233809057781,
#   'MSPE': 1.3661883669820698},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.2786549044152101,
#   'R2': 0.7601028218913455,
#   'MSPE': 1.3875951481550328},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.2787899581094583,
#   'R2': 0.7652185373510966,
#   'MSPE': 1.373124175300502},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.27923559447129565,
#   'R2': 0.7392826427027336,
#   'MSPE': 1.3405330699746207},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.27937046686808265,
#   'R2': 0.7853880219344729,
#   'MSPE': 1.4388835730708458},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.279539313664039,
#   'R2': 0.7706971414871142,
#   'MSPE': 1.4070910061098107},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.2798059890667598,
#   'R2': 0.7551536714318017,
#   'MSPE': 1.2945814620741087},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.27980912874142333,
#   'R2': 0.76239909350443,
#   'MSPE': 1.3231155494547855},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.27993307262659073,
#   'R2': 0.7631970316585599,
#   'MSPE': 1.2779794665373334},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.28008868992328645,
#   'R2': 0.7567704958251074,
#   'MSPE': 1.277712414774931},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.2801724411547184,
#   'R2': 0.7626356244974395,
#   'MSPE': 1.3839802607856313},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.2810325903818011,
#   'R2': 0.7781756536865003,
#   'MSPE': 1.3385959842590371},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.28175161356727274,
#   'R2': 0.7725682161115864,
#   'MSPE': 1.4384798930882654},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.2819360961516698,
#   'R2': 0.7565420725295212,
#   'MSPE': 1.359235578583497},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.28197768976291016,
#   'R2': 0.7781452709490457,
#   'MSPE': 1.5621088092412911},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.28220873996615414,
#   'R2': 0.7572790418957276,
#   'MSPE': 1.346515368039936},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.28230525404214857,
#   'R2': 0.7587048190371414,
#   'MSPE': 1.5515529560960002},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.2827803713579973,
#   'R2': 0.7600460061581286,
#   'MSPE': 1.393715464180768},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.2829428342481454,
#   'R2': 0.773626652796654,
#   'MSPE': 1.399961584576904},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.283065868417422,
#   'R2': 0.7849633702886999,
#   'MSPE': 1.4274293713911312},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.2835865408182144,
#   'R2': 0.7661886523172186,
#   'MSPE': 1.3807601139250427},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.2837430673340956,
#   'R2': 0.7298520144675407,
#   'MSPE': 1.3777715279579614},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.2840479739010334,
#   'R2': 0.7663135012933614,
#   'MSPE': 1.4165968331273153},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.2845151456693808,
#   'R2': 0.7752259939147584,
#   'MSPE': 1.4267512543522047},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.2846101835370064,
#   'R2': 0.7683571067203563,
#   'MSPE': 1.36052269784903},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.28490638385216394,
#   'R2': 0.7708176811721467,
#   'MSPE': 1.4472056818523944},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.2850198050340017,
#   'R2': 0.7725464772458441,
#   'MSPE': 1.5456403662083729},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.2850965842604637,
#   'R2': 0.7762911274046448,
#   'MSPE': 1.4456993178699653},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.28604132135709126,
#   'R2': 0.765503209578876,
#   'MSPE': 1.4674147827118034},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.28637608240048085,
#   'R2': 0.7512313890522896,
#   'MSPE': 1.39249954767751},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.2865105298658212,
#   'R2': 0.7474559175395591,
#   'MSPE': 1.3868872233845218},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.2867122049132983,
#   'R2': 0.7699715394346364,
#   'MSPE': 1.3742968251909873},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.2871459866563479,
#   'R2': 0.7643932999803623,
#   'MSPE': 1.4036468289453876},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.28737024043997134,
#   'R2': 0.7681873636790036,
#   'MSPE': 1.4122756460512225},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.2878108754754066,
#   'R2': 0.765582152133086,
#   'MSPE': 1.3916635643126383},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.28797180553277335,
#   'R2': 0.7670148825059518,
#   'MSPE': 1.4377880009888397},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.28814086988568305,
#   'R2': 0.7690466414412275,
#   'MSPE': 1.5722906610204113},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.28835901543498044,
#   'R2': 0.7711596252581019,
#   'MSPE': 1.4603510827315274},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.288419525573651,
#   'R2': 0.7564140126746414,
#   'MSPE': 1.433776351246945},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.2884929259618123,
#   'R2': 0.7545548707225108,
#   'MSPE': 1.4279249539090828},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.2888811275362968,
#   'R2': 0.7567889459047556,
#   'MSPE': 1.3820537125146148},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.2890004500746727,
#   'R2': 0.7604960627718628,
#   'MSPE': 1.4635801634215047},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.28907000174125036,
#   'R2': 0.7578524795071544,
#   'MSPE': 1.3625957819661407},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.2893712192773819,
#   'R2': 0.759356571941343,
#   'MSPE': 1.4015905534133617},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.2908687810103099,
#   'R2': 0.752842974906627,
#   'MSPE': 1.4982934242039168},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.2909582957625389,
#   'R2': 0.760260157533478,
#   'MSPE': 1.4006999506135327},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.29104727307955425,
#   'R2': 0.7384679435667726,
#   'MSPE': 1.4001681923753384},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.2912631432215373,
#   'R2': 0.7821541754769801,
#   'MSPE': 1.5366863150318915},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.2914559232691924,
#   'R2': 0.7437333371394086,
#   'MSPE': 1.4563850496867388},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.2914689478774865,
#   'R2': 0.7620582199007215,
#   'MSPE': 1.3997397097674282},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.2915977622071902,
#   'R2': 0.7490953169687096,
#   'MSPE': 1.3747853252359412},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.2920766000946363,
#   'R2': 0.7688100600024018,
#   'MSPE': 1.345603729814592},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.29251247371236483,
#   'R2': 0.7632991148739463,
#   'MSPE': 1.441565676394737},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.29277506222327554,
#   'R2': 0.7707401079484164,
#   'MSPE': 1.4627700024331458},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.29277817259232203,
#   'R2': 0.7627554524284939,
#   'MSPE': 1.5927258735014633},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.2928163637717565,
#   'R2': 0.7581493952416982,
#   'MSPE': 1.41646425813587},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.2930757403373718,
#   'R2': 0.7449594723501618,
#   'MSPE': 1.3888022923522225},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.29342511619130773,
#   'R2': 0.7656479355101702,
#   'MSPE': 1.3291713258609026},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.29353318785627686,
#   'R2': 0.7636806643568586,
#   'MSPE': 1.572286139778567},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.29358025491237644,
#   'R2': 0.7501915347979031,
#   'MSPE': 1.4110493895155611},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.29360869725545247,
#   'R2': 0.7753791328722558,
#   'MSPE': 1.5359072245168266},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.2936827279627323,
#   'R2': 0.7710668143576246,
#   'MSPE': 1.4349732341978583},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.2937079711506764,
#   'R2': 0.7502973516264915,
#   'MSPE': 1.4417338437127944},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.29395142793655393,
#   'R2': 0.7808537609042603,
#   'MSPE': 1.66243876189445},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.29514638384183256,
#   'R2': 0.7618858899974417,
#   'MSPE': 1.550538633771316},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.29529480487108234,
#   'R2': 0.7624175558950813,
#   'MSPE': 1.5349674767654653},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.2961175824205081,
#   'R2': 0.7596333203443646,
#   'MSPE': 1.4857896682194842},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.2962344547112783,
#   'R2': 0.7430575153534272,
#   'MSPE': 1.4443237850950523},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.2963984730343024,
#   'R2': 0.7493935790856396,
#   'MSPE': 1.42603439180124},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.29666791260242464,
#   'R2': 0.7646982734319366,
#   'MSPE': 1.5084383419404426},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.2969648055732251,
#   'R2': 0.7654118409289845,
#   'MSPE': 1.4308055643594324},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.2970374797781309,
#   'R2': 0.7174318301200776,
#   'MSPE': 1.4640123149229571},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.29729838619629545,
#   'R2': 0.7495880461315579,
#   'MSPE': 1.4483803800881057},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.2974096218744914,
#   'R2': 0.7495229046069095,
#   'MSPE': 1.3897107919734535},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.2978977270424366,
#   'R2': 0.7584774809126426,
#   'MSPE': 1.6410472080337275},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.29860365688800816,
#   'R2': 0.7672951745047873,
#   'MSPE': 1.5047976340759885},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.2987378301719824,
#   'R2': 0.7559491801452526,
#   'MSPE': 1.4678750391296966},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.29879030336936313,
#   'R2': 0.7509965777912467,
#   'MSPE': 1.449550294571302},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.29951120068629583,
#   'R2': 0.7555782744732056,
#   'MSPE': 1.4340754328389662},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.30061825960874555,
#   'R2': 0.7479110638325492,
#   'MSPE': 1.4580749786186096},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.3011747196316719,
#   'R2': 0.7395883869406623,
#   'MSPE': 1.4963764432968216},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.3012295328080654,
#   'R2': 0.7390471070925588,
#   'MSPE': 1.5111902956333423},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.302132863799731,
#   'R2': 0.7636335780516408,
#   'MSPE': 1.6713425502971266},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.30296070600549385,
#   'R2': 0.7652036100060455,
#   'MSPE': 1.554564862897751},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.3035367858906587,
#   'R2': 0.7286099819957063,
#   'MSPE': 1.4814751216144573},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.30370789567629497,
#   'R2': 0.7699681081313863,
#   'MSPE': 1.5511515878630104},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.3037461832165718,
#   'R2': 0.7566256646229078,
#   'MSPE': 1.4979052930280115},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.3037688732147217,
#   'R2': 0.7603428312221929,
#   'MSPE': 1.463024804998904},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.30383237401644386,
#   'R2': 0.7600242357804567,
#   'MSPE': 1.7085493885620378},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.3047900329033533,
#   'R2': 0.7467129602537972,
#   'MSPE': 1.5771344828071319},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.30500322282314296,
#   'R2': 0.737834143830148,
#   'MSPE': 1.4865725917854544},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.3051061319808165,
#   'R2': 0.7358284036691389,
#   'MSPE': 1.5061433421391428},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.3053191641966502,
#   'R2': 0.768635714999381,
#   'MSPE': 1.6261795585542316},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.3053477759162585,
#   'R2': 0.7378616490137431,
#   'MSPE': 1.5254842445743502},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.30568955739339193,
#   'R2': 0.7327523717776779,
#   'MSPE': 1.5012866480633469},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.3062986969947815,
#   'R2': 0.749753128957149,
#   'MSPE': 1.4917306189020778},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.30814845214287445,
#   'R2': 0.7697355223529675,
#   'MSPE': 1.4862354731450629},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.3105003786583741,
#   'R2': 0.737528578697346,
#   'MSPE': 1.530913157774267},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.3106372738877933,
#   'R2': 0.7320359085608047,
#   'MSPE': 1.5711490189976465},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.3106424957513809,
#   'R2': 0.7422776671326765,
#   'MSPE': 1.5483767942835889},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.31107618163029355,
#   'R2': 0.7437553592960513,
#   'MSPE': 1.5268151017112863},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.3136638234059016,
#   'R2': 0.7523000881303923,
#   'MSPE': 1.6044871845856459},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.31453597396612165,
#   'R2': 0.7406534830881384,
#   'MSPE': 1.6366276361349257},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.3153584149976571,
#   'R2': 0.7410090646301631,
#   'MSPE': 1.461837456815622},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.3154096702734629,
#   'R2': 0.7521454144716062,
#   'MSPE': 1.5708796504057112},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.31575774649779,
#   'R2': 0.7544439566434458,
#   'MSPE': 1.6679118737352616},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.31675138572851813,
#   'R2': 0.7322345358383279,
#   'MSPE': 1.5654259413066836},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.3172505170106888,
#   'R2': 0.7199474295179091,
#   'MSPE': 1.4672964955256744},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.3177334249019622,
#   'R2': 0.7270205587142797,
#   'MSPE': 1.5889299361768998},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.3189514741301536,
#   'R2': 0.743052885022202,
#   'MSPE': 1.4678334179475452},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.3195435002446175,
#   'R2': 0.7568453643650536,
#   'MSPE': 1.609098750702811},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.3202543750405312,
#   'R2': 0.7424915599114166,
#   'MSPE': 1.6548579113764894},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.3202662100394567,
#   'R2': 0.7423879047408872,
#   'MSPE': 1.62213203323196},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.3206242973605792,
#   'R2': 0.7545500233426206,
#   'MSPE': 1.6261686967930409},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.3206505589187146,
#   'R2': 0.7451301331230085,
#   'MSPE': 1.6596511202027102},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.321014674504598,
#   'R2': 0.7456101977420622,
#   'MSPE': 1.6203906500918996},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.32278906007607777,
#   'R2': 0.7279181244019066,
#   'MSPE': 1.7309987427422193},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.32312036057313287,
#   'R2': 0.7555811075377707,
#   'MSPE': 1.6914863280500427},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.32603381127119063,
#   'R2': 0.7370850620063132,
#   'MSPE': 1.9132216035792922},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.33210827733079595,
#   'R2': 0.7216691658018396,
#   'MSPE': 1.4725423089670713},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.33910959089795745,
#   'R2': 0.7276130888522625,
#   'MSPE': 1.5939964497029178},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.3463412001729012,
#   'R2': 0.7009360949925025,
#   'MSPE': 1.6284322678440748},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.35458887318770094,
#   'R2': 0.6841471285441323,
#   'MSPE': 1.85707270167768},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.3549044010539849,
#   'R2': 0.7027054883421857,
#   'MSPE': 1.5984759276563472},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.35625372330347693,
#   'R2': 0.7108924190995397,
#   'MSPE': 1.851512197536802},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.36586884309848144,
#   'R2': 0.703205470176714,
#   'MSPE': 1.795030233233866},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.37294943332672126,
#   'R2': 0.7031164621794563,
#   'MSPE': 1.7771590027882893},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.3815117531766494,
#   'R2': 0.7056015708560457,
#   'MSPE': 1.8373866914536314},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.38229506313800815,
#   'R2': 0.6956772915120579,
#   'MSPE': 1.9582877737103086},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.38438661222656567,
#   'R2': 0.6846179464630735,
#   'MSPE': 1.8850492781046964},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.4010453852514426,
#   'R2': 0.6802297392609937,
#   'MSPE': 2.0154067151474226},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.4011709238092105,
#   'R2': 0.6833440851324164,
#   'MSPE': 1.7822972543518802},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.40533652057250336,
#   'R2': 0.6844460458823823,
#   'MSPE': 1.9565731698101518},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.4078705189128716,
#   'R2': 0.6686675038622452,
#   'MSPE': 2.0592679588989626},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.41630413209398587,
#   'R2': 0.6809858211756525,
#   'MSPE': 2.1784477110839253},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.42563255280256274,
#   'R2': 0.6664003966199096,
#   'MSPE': 2.0208422205589636},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.428153125445048,
#   'R2': 0.6566980793503404,
#   'MSPE': 2.1158195389528767},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.43256742904583617,
#   'R2': 0.6440051482672753,
#   'MSPE': 2.133879980937851},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.43546711653470993,
#   'R2': 0.6439794303840654,
#   'MSPE': 2.025867583079621},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.4364707047740618,
#   'R2': 0.6321400487432777,
#   'MSPE': 2.0187845218437492},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.43714419802029925,
#   'R2': 0.6552247960441504,
#   'MSPE': 1.9979132073131776},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.4392399311065674,
#   'R2': 0.6055821843266961,
#   'MSPE': 2.0592128434641794},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.4427178492148717,
#   'R2': 0.6422271711411668,
#   'MSPE': 2.2254691411261307},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.443372110525767,
#   'R2': 0.6225338647654794,
#   'MSPE': 2.019651011008807},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.44471856355667116,
#   'R2': 0.652613187123098,
#   'MSPE': 2.044342642254901},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.4489732826749483,
#   'R2': 0.6366865550007855,
#   'MSPE': 2.1277595091272485},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.4493006855249405,
#   'R2': 0.6477508100421371,
#   'MSPE': 2.2145549017898363},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.44941769788662594,
#   'R2': 0.6337630937818353,
#   'MSPE': 2.114677515558221},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.4506145780285199,
#   'R2': 0.6418092491049185,
#   'MSPE': 2.1686837699903982},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.45142421176036207,
#   'R2': 0.6169310431575629,
#   'MSPE': 2.046297925966557},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.45643368661403655,
#   'R2': 0.6488799122215074,
#   'MSPE': 2.1297562660442457},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.45682914753754933,
#   'R2': 0.6495368460993468,
#   'MSPE': 2.340615076022317},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.4578500109414259,
#   'R2': 0.6266185102170521,
#   'MSPE': 2.0760968494031466},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.45921894808610286,
#   'R2': 0.6084636472823416,
#   'MSPE': 1.9988431639480169},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.46076300640900925,
#   'R2': 0.6060875221374366,
#   'MSPE': 2.113668727453309},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.46083315064509706,
#   'R2': 0.6007494329158665,
#   'MSPE': 2.2952719620720607},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.4640102614959082,
#   'R2': 0.6162557592670126,
#   'MSPE': 2.185931319013388},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.46411734869082777,
#   'R2': 0.6368887945893874,
#   'MSPE': 2.187437328105472},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.4649044170975685,
#   'R2': 0.6435287559255186,
#   'MSPE': 2.1119563244847637},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.46613832811514533,
#   'R2': 0.6348694196110137,
#   'MSPE': 2.2201653726097907},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.46742291996876395,
#   'R2': 0.6323990909994209,
#   'MSPE': 2.1872074115607476},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.46786429112156236,
#   'R2': 0.6181647715314024,
#   'MSPE': 2.1655029155351597},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.468572657306989,
#   'R2': 0.6247446808654114,
#   'MSPE': 2.1694410694857136},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.4728386849164964,
#   'R2': 0.6221379463713701,
#   'MSPE': 2.0952331374465216},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.47914071083068854,
#   'R2': 0.6163197692001285,
#   'MSPE': 2.024127125100355},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.47921750545501707,
#   'R2': 0.6005685868736349,
#   'MSPE': 2.389166499629165},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.4832891722520193,
#   'R2': 0.6151800548355093,
#   'MSPE': 2.1462118004759154},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.48400702476501467,
#   'R2': 0.6232394105932938,
#   'MSPE': 2.461388073485307},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.48887809664011,
#   'R2': 0.6153755075839517,
#   'MSPE': 2.3327977989207613},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.4907850493987402,
#   'R2': 0.5913712262289431,
#   'MSPE': 2.224238884512975},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.49242142736911776,
#   'R2': 0.6120496491662999,
#   'MSPE': 2.18935599400088},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.49506877958774564,
#   'R2': 0.5687346445540331,
#   'MSPE': 2.0675078666571416},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.4980149259169897,
#   'R2': 0.6355585146768656,
#   'MSPE': 2.388833888213743},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.5078878919283549,
#   'R2': 0.6040183637035368,
#   'MSPE': 2.5514000737945537},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.5127624243497848,
#   'R2': 0.5617461839857089,
#   'MSPE': 2.4871655212094383},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.5152450223763784,
#   'R2': 0.5928702965382141,
#   'MSPE': 2.5138863963498315},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.5170574267705281,
#   'R2': 0.5552597278131688,
#   'MSPE': 2.1458304705888485},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.526440279185772,
#   'R2': 0.5852753992694286,
#   'MSPE': 2.4151616563286744},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.5318806529045106,
#   'R2': 0.5951668123701207,
#   'MSPE': 2.1290774043235507},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.5393525933225949,
#   'R2': 0.588273055687581,
#   'MSPE': 2.52368594143502},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.5979713569084804,
#   'R2': 0.516090689869696,
#   'MSPE': 2.7788161311411494},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.6045774946610133,
#   'R2': 0.4643595558258887,
#   'MSPE': 3.1740501451522416},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.6376119780043761,
#   'R2': 0.4603702729522248,
#   'MSPE': 2.869903241105453},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.6383176694313685,
#   'R2': 0.505667344858195,
#   'MSPE': 3.1396172223894885},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.6401743710041046,
#   'R2': 0.48419828011086474,
#   'MSPE': 3.0866959273363603},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.6404296492536863,
#   'R2': 0.4767817666831136,
#   'MSPE': 3.0997125657670423},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.6448573340972266,
#   'R2': 0.47532429128796094,
#   'MSPE': 3.0808565489044692},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.6461367865403493,
#   'R2': 0.46525027098437227,
#   'MSPE': 3.0153131291194994},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.651260131597519,
#   'R2': 0.4832859523297851,
#   'MSPE': 3.1233442544636096},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.6766906380653381,
#   'R2': 0.43542941607329694,
#   'MSPE': 3.108137726520348},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.6796710560719171,
#   'R2': 0.4321203916826092,
#   'MSPE': 3.0928523857334644},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.6797706047693889,
#   'R2': 0.4391412213102142,
#   'MSPE': 3.0185279180530946},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.6901666929324468,
#   'R2': 0.43037934200042993,
#   'MSPE': 3.288248475603383},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.7039451628923417,
#   'R2': 0.4455353120926235,
#   'MSPE': 3.059706519160307},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.7069946885108948,
#   'R2': 0.3879827206636672,
#   'MSPE': 3.7025027731997953},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.7147583141922952,
#   'R2': 0.40541643013972334,
#   'MSPE': 3.113880180330439},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.7193225463231405,
#   'R2': 0.4489534675911518,
#   'MSPE': 3.3027543851898775},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.7222910275061926,
#   'R2': 0.4259761041341438,
#   'MSPE': 3.250613996966018},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.7239603579044342,
#   'R2': 0.4382065643703739,
#   'MSPE': 3.337574480948123},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.7295434584220251,
#   'R2': 0.3718111406441908,
#   'MSPE': 3.370985601925187},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.7300204289456209,
#   'R2': 0.438777989315515,
#   'MSPE': 3.1923190348151356},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.7627199977636338,
#   'R2': 0.4147614432634409,
#   'MSPE': 3.6834925174186326},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.7685425678888957,
#   'R2': 0.40809469578358054,
#   'MSPE': 3.183243681648464},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.7702844272057214,
#   'R2': 0.3461947569902436,
#   'MSPE': 3.727453425338472},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.7743170713384947,
#   'R2': 0.400650070050433,
#   'MSPE': 4.075710462650868},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.7752914746602377,
#   'R2': 0.38287378121696225,
#   'MSPE': 3.5340964049100876},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.7754119038581848,
#   'R2': 0.36991984137007344,
#   'MSPE': 3.8934521401545625},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.7762346367041271,
#   'R2': 0.36884236481885585,
#   'MSPE': 3.570074255418296},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.7815490424633026,
#   'R2': 0.3228537893713919,
#   'MSPE': 3.508979133377322},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.7843132515748342,
#   'R2': 0.3523899988355199,
#   'MSPE': 3.682336323527676},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.785241142908732,
#   'R2': 0.3772908899367525,
#   'MSPE': 3.230452584384969},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.7858529672026634,
#   'R2': 0.39562178340429,
#   'MSPE': 3.868272131064324},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.7885004848241806,
#   'R2': 0.3798449268173054,
#   'MSPE': 3.8299546059634957},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.7912521759668987,
#   'R2': 0.3987547973098255,
#   'MSPE': 3.8021648953659364},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.8004551142454147,
#   'R2': 0.3515958457261288,
#   'MSPE': 3.6913879522395256},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.8043655316034952,
#   'R2': 0.39369300601591556,
#   'MSPE': 3.5911405447757603},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.8051259701450666,
#   'R2': 0.3563482518215214,
#   'MSPE': 3.9154331762381274},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.8135547637939453,
#   'R2': 0.37250109728594555,
#   'MSPE': 3.7365031296932933},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.8153032312790552,
#   'R2': 0.31767458212283356,
#   'MSPE': 3.787856078847791},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.8257550845543543,
#   'R2': 0.39262769238721307,
#   'MSPE': 4.082884302908423},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.8267142375310261,
#   'R2': 0.29021872398232135,
#   'MSPE': 3.8419193637115177},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.830386303861936,
#   'R2': 0.3321341329537864,
#   'MSPE': 3.6741405386816366},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.8319656898578007,
#   'R2': 0.3600353232710037,
#   'MSPE': 3.9115263467108967},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.8465916951497394,
#   'R2': 0.36314810038551004,
#   'MSPE': 4.401083561507138},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.860820072889328,
#   'R2': 0.31895236682879047,
#   'MSPE': 3.8404637046459342},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.8723186453183492,
#   'R2': 0.28947881969586914,
#   'MSPE': 4.106247493752627},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.8802626033624014,
#   'R2': 0.3184082672783092,
#   'MSPE': 4.360958721977894},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.9076090534528095,
#   'R2': 0.24994153548766831,
#   'MSPE': 3.938371169973503},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.9288565476735433,
#   'R2': 0.2661623061043307,
#   'MSPE': 4.407254293410465},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.9351383745670319,
#   'R2': 0.22772972443267858,
#   'MSPE': 4.246546307371721},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 1.2316417346398034,
#   'R2': 0.04612934681488044,
#   'MSPE': 5.794474756947219},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 1.506544715166092,
#   'R2': -0.10082205577140044,
#   'MSPE': 5.32199385321953},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 1.5909140398104988,
#   'R2': -0.2957832406634227,
#   'MSPE': 5.727947088090157},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 1.6786820769309998,
#   'R2': -0.4668385707717097,
#   'MSPE': 6.1665751435088385},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 1.7476111729939778,
#   'R2': -0.42795251114875177,
#   'MSPE': 6.7951512468433135},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 1.751923614740372,
#   'R2': -0.49006174760724086,
#   'MSPE': 6.138147420127585}]

# %%
# Sort by highest R2
sorted(results, key=lambda x: x["R2"], reverse=True)
# Out:
# [{'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.24924166748921076,
#   'R2': 0.7983637068863594,
#   'MSPE': 1.2033620677568544},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.2504825517535209,
#   'R2': 0.7952506301122343,
#   'MSPE': 1.206150301732123},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.2573148580888907,
#   'R2': 0.7947204879721369,
#   'MSPE': 1.2185531493389246},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.24820603281259537,
#   'R2': 0.7946429363376633,
#   'MSPE': 1.2117934468757325},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.2613672281304995,
#   'R2': 0.7931898025307588,
#   'MSPE': 1.2167842200759686},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.2600494258105755,
#   'R2': 0.7926445707599233,
#   'MSPE': 1.2121827240958056},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.2715056074162325,
#   'R2': 0.7885167398392003,
#   'MSPE': 1.3960589623699584},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.25267310552299027,
#   'R2': 0.7882869147580953,
#   'MSPE': 1.1877650669258502},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.2641682179023822,
#   'R2': 0.7876295682765496,
#   'MSPE': 1.2501864505442555},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.2621487148106098,
#   'R2': 0.7862976830406048,
#   'MSPE': 1.2440426942111564},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.2602107857664426,
#   'R2': 0.7859999397713402,
#   'MSPE': 1.2893872487010678},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.27937046686808265,
#   'R2': 0.7853880219344729,
#   'MSPE': 1.4388835730708458},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.283065868417422,
#   'R2': 0.7849633702886999,
#   'MSPE': 1.4274293713911312},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.27382038806875547,
#   'R2': 0.7848412364214282,
#   'MSPE': 1.3235596833148537},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.27097111468513807,
#   'R2': 0.784803379866696,
#   'MSPE': 1.4388455594466492},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.2619648344814778,
#   'R2': 0.7843790810872612,
#   'MSPE': 1.3074695234271616},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.2658121262987455,
#   'R2': 0.7838451044723937,
#   'MSPE': 1.347918263777639},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.277553778141737,
#   'R2': 0.7833218229516627,
#   'MSPE': 1.4213845273009453},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.2604059144854546,
#   'R2': 0.782802910572781,
#   'MSPE': 1.2683086205424383},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.2912631432215373,
#   'R2': 0.7821541754769801,
#   'MSPE': 1.5366863150318915},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.2760750040411949,
#   'R2': 0.7819766125425588,
#   'MSPE': 1.3425658778710798},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.26404761523008347,
#   'R2': 0.7818992399126978,
#   'MSPE': 1.364856681391371},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.2746464210251967,
#   'R2': 0.7817941607283398,
#   'MSPE': 1.3641747489872604},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.2684639061490695,
#   'R2': 0.7815574137336729,
#   'MSPE': 1.286024117484839},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.27600551918148997,
#   'R2': 0.7809085683986139,
#   'MSPE': 1.3173585891196824},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.29395142793655393,
#   'R2': 0.7808537609042603,
#   'MSPE': 1.66243876189445},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.26814555525779726,
#   'R2': 0.7808469074582074,
#   'MSPE': 1.3260637059092821},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.27633951008319857,
#   'R2': 0.7806837594934624,
#   'MSPE': 1.3712058264780977},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.27430406380444766,
#   'R2': 0.7806502497190972,
#   'MSPE': 1.3738459771536669},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.2722931355237961,
#   'R2': 0.7801318002291853,
#   'MSPE': 1.2759570804697393},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.2713685671488444,
#   'R2': 0.7792464382989459,
#   'MSPE': 1.448241156064952},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.25826961224277817,
#   'R2': 0.7791177245030748,
#   'MSPE': 1.1914636914364318},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.2672379565735658,
#   'R2': 0.778699390996352,
#   'MSPE': 1.3083298265407184},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.2692669846117497,
#   'R2': 0.7783094636610576,
#   'MSPE': 1.3665850605872092},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.2810325903818011,
#   'R2': 0.7781756536865003,
#   'MSPE': 1.3385959842590371},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.28197768976291016,
#   'R2': 0.7781452709490457,
#   'MSPE': 1.5621088092412911},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.2710120027263959,
#   'R2': 0.7780096791790215,
#   'MSPE': 1.3105710352197137},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.27064840123057365,
#   'R2': 0.7779962886762833,
#   'MSPE': 1.365590351586691},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.2850965842604637,
#   'R2': 0.7762911274046448,
#   'MSPE': 1.4456993178699653},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.2750836918751398,
#   'R2': 0.776272040532389,
#   'MSPE': 1.4563348075619553},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.2778002008795738,
#   'R2': 0.7762567653753158,
#   'MSPE': 1.3695618525768318},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.26580502539873124,
#   'R2': 0.7760498266188522,
#   'MSPE': 1.3219306033311615},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.25640386467178666,
#   'R2': 0.7757419338883176,
#   'MSPE': 1.2707865692562226},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.29360869725545247,
#   'R2': 0.7753791328722558,
#   'MSPE': 1.5359072245168266},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.2845151456693808,
#   'R2': 0.7752259939147584,
#   'MSPE': 1.4267512543522047},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.2730664283037186,
#   'R2': 0.7746640199690653,
#   'MSPE': 1.3352220137650617},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.25962650825579964,
#   'R2': 0.7744233891199915,
#   'MSPE': 1.2210708278974498},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.2684418837229411,
#   'R2': 0.7738426322876591,
#   'MSPE': 1.2938432939200089},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.2829428342481454,
#   'R2': 0.773626652796654,
#   'MSPE': 1.399961584576904},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.28175161356727274,
#   'R2': 0.7725682161115864,
#   'MSPE': 1.4384798930882654},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.2850198050340017,
#   'R2': 0.7725464772458441,
#   'MSPE': 1.5456403662083729},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.28835901543498044,
#   'R2': 0.7711596252581019,
#   'MSPE': 1.4603510827315274},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.2936827279627323,
#   'R2': 0.7710668143576246,
#   'MSPE': 1.4349732341978583},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.28490638385216394,
#   'R2': 0.7708176811721467,
#   'MSPE': 1.4472056818523944},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.29277506222327554,
#   'R2': 0.7707401079484164,
#   'MSPE': 1.4627700024331458},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.279539313664039,
#   'R2': 0.7706971414871142,
#   'MSPE': 1.4070910061098107},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.27191315963864326,
#   'R2': 0.7701227534037768,
#   'MSPE': 1.2668940336960883},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.2867122049132983,
#   'R2': 0.7699715394346364,
#   'MSPE': 1.3742968251909873},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.30370789567629497,
#   'R2': 0.7699681081313863,
#   'MSPE': 1.5511515878630104},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.30814845214287445,
#   'R2': 0.7697355223529675,
#   'MSPE': 1.4862354731450629},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.28814086988568305,
#   'R2': 0.7690466414412275,
#   'MSPE': 1.5722906610204113},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.2920766000946363,
#   'R2': 0.7688100600024018,
#   'MSPE': 1.345603729814592},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.3053191641966502,
#   'R2': 0.768635714999381,
#   'MSPE': 1.6261795585542316},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.2846101835370064,
#   'R2': 0.7683571067203563,
#   'MSPE': 1.36052269784903},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.28737024043997134,
#   'R2': 0.7681873636790036,
#   'MSPE': 1.4122756460512225},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.2750574566423893,
#   'R2': 0.7681176445021138,
#   'MSPE': 1.361995210325477},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.2722464258472125,
#   'R2': 0.7677928667261211,
#   'MSPE': 1.3661071144025585},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.29860365688800816,
#   'R2': 0.7672951745047873,
#   'MSPE': 1.5047976340759885},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.27860219155748683,
#   'R2': 0.767233809057781,
#   'MSPE': 1.3661883669820698},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.28797180553277335,
#   'R2': 0.7670148825059518,
#   'MSPE': 1.4377880009888397},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.277348413442572,
#   'R2': 0.7664768744911894,
#   'MSPE': 1.330432373785762},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.2840479739010334,
#   'R2': 0.7663135012933614,
#   'MSPE': 1.4165968331273153},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.2835865408182144,
#   'R2': 0.7661886523172186,
#   'MSPE': 1.3807601139250427},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.29342511619130773,
#   'R2': 0.7656479355101702,
#   'MSPE': 1.3291713258609026},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.2878108754754066,
#   'R2': 0.765582152133086,
#   'MSPE': 1.3916635643126383},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.28604132135709126,
#   'R2': 0.765503209578876,
#   'MSPE': 1.4674147827118034},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.2969648055732251,
#   'R2': 0.7654118409289845,
#   'MSPE': 1.4308055643594324},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.2787899581094583,
#   'R2': 0.7652185373510966,
#   'MSPE': 1.373124175300502},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.30296070600549385,
#   'R2': 0.7652036100060455,
#   'MSPE': 1.554564862897751},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.29666791260242464,
#   'R2': 0.7646982734319366,
#   'MSPE': 1.5084383419404426},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.27343606576323515,
#   'R2': 0.7645505198175131,
#   'MSPE': 1.3419397704472595},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.2871459866563479,
#   'R2': 0.7643932999803623,
#   'MSPE': 1.4036468289453876},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.2755730715890725,
#   'R2': 0.763798237373679,
#   'MSPE': 1.2974860356424494},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.29353318785627686,
#   'R2': 0.7636806643568586,
#   'MSPE': 1.572286139778567},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.302132863799731,
#   'R2': 0.7636335780516408,
#   'MSPE': 1.6713425502971266},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.29251247371236483,
#   'R2': 0.7632991148739463,
#   'MSPE': 1.441565676394737},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.27993307262659073,
#   'R2': 0.7631970316585599,
#   'MSPE': 1.2779794665373334},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.29277817259232203,
#   'R2': 0.7627554524284939,
#   'MSPE': 1.5927258735014633},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.2801724411547184,
#   'R2': 0.7626356244974395,
#   'MSPE': 1.3839802607856313},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.29529480487108234,
#   'R2': 0.7624175558950813,
#   'MSPE': 1.5349674767654653},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.27980912874142333,
#   'R2': 0.76239909350443,
#   'MSPE': 1.3231155494547855},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.27610114961862564,
#   'R2': 0.7623192328515903,
#   'MSPE': 1.3683640424425554},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.2914689478774865,
#   'R2': 0.7620582199007215,
#   'MSPE': 1.3997397097674282},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.29514638384183256,
#   'R2': 0.7618858899974417,
#   'MSPE': 1.550538633771316},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.2890004500746727,
#   'R2': 0.7604960627718628,
#   'MSPE': 1.4635801634215047},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.3037688732147217,
#   'R2': 0.7603428312221929,
#   'MSPE': 1.463024804998904},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.2909582957625389,
#   'R2': 0.760260157533478,
#   'MSPE': 1.4006999506135327},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.2786549044152101,
#   'R2': 0.7601028218913455,
#   'MSPE': 1.3875951481550328},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.2827803713579973,
#   'R2': 0.7600460061581286,
#   'MSPE': 1.393715464180768},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.30383237401644386,
#   'R2': 0.7600242357804567,
#   'MSPE': 1.7085493885620378},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.2961175824205081,
#   'R2': 0.7596333203443646,
#   'MSPE': 1.4857896682194842},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.2893712192773819,
#   'R2': 0.759356571941343,
#   'MSPE': 1.4015905534133617},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.28230525404214857,
#   'R2': 0.7587048190371414,
#   'MSPE': 1.5515529560960002},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.2978977270424366,
#   'R2': 0.7584774809126426,
#   'MSPE': 1.6410472080337275},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.2928163637717565,
#   'R2': 0.7581493952416982,
#   'MSPE': 1.41646425813587},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.28907000174125036,
#   'R2': 0.7578524795071544,
#   'MSPE': 1.3625957819661407},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.28220873996615414,
#   'R2': 0.7572790418957276,
#   'MSPE': 1.346515368039936},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.3195435002446175,
#   'R2': 0.7568453643650536,
#   'MSPE': 1.609098750702811},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.2888811275362968,
#   'R2': 0.7567889459047556,
#   'MSPE': 1.3820537125146148},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.28008868992328645,
#   'R2': 0.7567704958251074,
#   'MSPE': 1.277712414774931},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.3037461832165718,
#   'R2': 0.7566256646229078,
#   'MSPE': 1.4979052930280115},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.2819360961516698,
#   'R2': 0.7565420725295212,
#   'MSPE': 1.359235578583497},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.2561137355864048,
#   'R2': 0.7564829938331542,
#   'MSPE': 1.2896378468157665},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.288419525573651,
#   'R2': 0.7564140126746414,
#   'MSPE': 1.433776351246945},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.2987378301719824,
#   'R2': 0.7559491801452526,
#   'MSPE': 1.4678750391296966},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.2666072790821393,
#   'R2': 0.7557642687151521,
#   'MSPE': 1.3101674367984137},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.32312036057313287,
#   'R2': 0.7555811075377707,
#   'MSPE': 1.6914863280500427},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.29951120068629583,
#   'R2': 0.7555782744732056,
#   'MSPE': 1.4340754328389662},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.2798059890667598,
#   'R2': 0.7551536714318017,
#   'MSPE': 1.2945814620741087},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.2884929259618123,
#   'R2': 0.7545548707225108,
#   'MSPE': 1.4279249539090828},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.3206242973605792,
#   'R2': 0.7545500233426206,
#   'MSPE': 1.6261686967930409},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.31575774649779,
#   'R2': 0.7544439566434458,
#   'MSPE': 1.6679118737352616},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.2713683652381102,
#   'R2': 0.7539927601395157,
#   'MSPE': 1.3159100400904813},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.2908687810103099,
#   'R2': 0.752842974906627,
#   'MSPE': 1.4982934242039168},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.3136638234059016,
#   'R2': 0.7523000881303923,
#   'MSPE': 1.6044871845856459},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.3154096702734629,
#   'R2': 0.7521454144716062,
#   'MSPE': 1.5708796504057112},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.26556308666865036,
#   'R2': 0.7512792841742826,
#   'MSPE': 1.2975246207130076},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.28637608240048085,
#   'R2': 0.7512313890522896,
#   'MSPE': 1.39249954767751},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.29879030336936313,
#   'R2': 0.7509965777912467,
#   'MSPE': 1.449550294571302},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.2937079711506764,
#   'R2': 0.7502973516264915,
#   'MSPE': 1.4417338437127944},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.29358025491237644,
#   'R2': 0.7501915347979031,
#   'MSPE': 1.4110493895155611},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.3062986969947815,
#   'R2': 0.749753128957149,
#   'MSPE': 1.4917306189020778},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.29729838619629545,
#   'R2': 0.7495880461315579,
#   'MSPE': 1.4483803800881057},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.2974096218744914,
#   'R2': 0.7495229046069095,
#   'MSPE': 1.3897107919734535},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.2963984730343024,
#   'R2': 0.7493935790856396,
#   'MSPE': 1.42603439180124},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.2915977622071902,
#   'R2': 0.7490953169687096,
#   'MSPE': 1.3747853252359412},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.30061825960874555,
#   'R2': 0.7479110638325492,
#   'MSPE': 1.4580749786186096},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.26151562357942265,
#   'R2': 0.747768486141144,
#   'MSPE': 1.2609759899270203},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.2865105298658212,
#   'R2': 0.7474559175395591,
#   'MSPE': 1.3868872233845218},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.3047900329033533,
#   'R2': 0.7467129602537972,
#   'MSPE': 1.5771344828071319},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.321014674504598,
#   'R2': 0.7456101977420622,
#   'MSPE': 1.6203906500918996},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.3206505589187146,
#   'R2': 0.7451301331230085,
#   'MSPE': 1.6596511202027102},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.2930757403373718,
#   'R2': 0.7449594723501618,
#   'MSPE': 1.3888022923522225},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.31107618163029355,
#   'R2': 0.7437553592960513,
#   'MSPE': 1.5268151017112863},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.2914559232691924,
#   'R2': 0.7437333371394086,
#   'MSPE': 1.4563850496867388},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.2962344547112783,
#   'R2': 0.7430575153534272,
#   'MSPE': 1.4443237850950523},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.3189514741301536,
#   'R2': 0.743052885022202,
#   'MSPE': 1.4678334179475452},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.3202543750405312,
#   'R2': 0.7424915599114166,
#   'MSPE': 1.6548579113764894},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.3202662100394567,
#   'R2': 0.7423879047408872,
#   'MSPE': 1.62213203323196},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.3106424957513809,
#   'R2': 0.7422776671326765,
#   'MSPE': 1.5483767942835889},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.3153584149976571,
#   'R2': 0.7410090646301631,
#   'MSPE': 1.461837456815622},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.31453597396612165,
#   'R2': 0.7406534830881384,
#   'MSPE': 1.6366276361349257},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.3011747196316719,
#   'R2': 0.7395883869406623,
#   'MSPE': 1.4963764432968216},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.27923559447129565,
#   'R2': 0.7392826427027336,
#   'MSPE': 1.3405330699746207},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.3012295328080654,
#   'R2': 0.7390471070925588,
#   'MSPE': 1.5111902956333423},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.29104727307955425,
#   'R2': 0.7384679435667726,
#   'MSPE': 1.4001681923753384},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.3053477759162585,
#   'R2': 0.7378616490137431,
#   'MSPE': 1.5254842445743502},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.30500322282314296,
#   'R2': 0.737834143830148,
#   'MSPE': 1.4865725917854544},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.3105003786583741,
#   'R2': 0.737528578697346,
#   'MSPE': 1.530913157774267},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.32603381127119063,
#   'R2': 0.7370850620063132,
#   'MSPE': 1.9132216035792922},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.3051061319808165,
#   'R2': 0.7358284036691389,
#   'MSPE': 1.5061433421391428},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.30568955739339193,
#   'R2': 0.7327523717776779,
#   'MSPE': 1.5012866480633469},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.31675138572851813,
#   'R2': 0.7322345358383279,
#   'MSPE': 1.5654259413066836},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.3106372738877933,
#   'R2': 0.7320359085608047,
#   'MSPE': 1.5711490189976465},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.2837430673340956,
#   'R2': 0.7298520144675407,
#   'MSPE': 1.3777715279579614},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.27645349701245625,
#   'R2': 0.7289343859270875,
#   'MSPE': 1.3115778667946354},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.3035367858906587,
#   'R2': 0.7286099819957063,
#   'MSPE': 1.4814751216144573},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.32278906007607777,
#   'R2': 0.7279181244019066,
#   'MSPE': 1.7309987427422193},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.33910959089795745,
#   'R2': 0.7276130888522625,
#   'MSPE': 1.5939964497029178},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.3177334249019622,
#   'R2': 0.7270205587142797,
#   'MSPE': 1.5889299361768998},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.33210827733079595,
#   'R2': 0.7216691658018396,
#   'MSPE': 1.4725423089670713},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.3172505170106888,
#   'R2': 0.7199474295179091,
#   'MSPE': 1.4672964955256744},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.2970374797781309,
#   'R2': 0.7174318301200776,
#   'MSPE': 1.4640123149229571},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.35625372330347693,
#   'R2': 0.7108924190995397,
#   'MSPE': 1.851512197536802},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.3815117531766494,
#   'R2': 0.7056015708560457,
#   'MSPE': 1.8373866914536314},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.36586884309848144,
#   'R2': 0.703205470176714,
#   'MSPE': 1.795030233233866},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.37294943332672126,
#   'R2': 0.7031164621794563,
#   'MSPE': 1.7771590027882893},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.3549044010539849,
#   'R2': 0.7027054883421857,
#   'MSPE': 1.5984759276563472},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.3463412001729012,
#   'R2': 0.7009360949925025,
#   'MSPE': 1.6284322678440748},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.38229506313800815,
#   'R2': 0.6956772915120579,
#   'MSPE': 1.9582877737103086},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.38438661222656567,
#   'R2': 0.6846179464630735,
#   'MSPE': 1.8850492781046964},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.40533652057250336,
#   'R2': 0.6844460458823823,
#   'MSPE': 1.9565731698101518},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.35458887318770094,
#   'R2': 0.6841471285441323,
#   'MSPE': 1.85707270167768},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.4011709238092105,
#   'R2': 0.6833440851324164,
#   'MSPE': 1.7822972543518802},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.41630413209398587,
#   'R2': 0.6809858211756525,
#   'MSPE': 2.1784477110839253},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.4010453852514426,
#   'R2': 0.6802297392609937,
#   'MSPE': 2.0154067151474226},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.4078705189128716,
#   'R2': 0.6686675038622452,
#   'MSPE': 2.0592679588989626},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.42563255280256274,
#   'R2': 0.6664003966199096,
#   'MSPE': 2.0208422205589636},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.428153125445048,
#   'R2': 0.6566980793503404,
#   'MSPE': 2.1158195389528767},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.43714419802029925,
#   'R2': 0.6552247960441504,
#   'MSPE': 1.9979132073131776},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.44471856355667116,
#   'R2': 0.652613187123098,
#   'MSPE': 2.044342642254901},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.45682914753754933,
#   'R2': 0.6495368460993468,
#   'MSPE': 2.340615076022317},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.45643368661403655,
#   'R2': 0.6488799122215074,
#   'MSPE': 2.1297562660442457},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.4493006855249405,
#   'R2': 0.6477508100421371,
#   'MSPE': 2.2145549017898363},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.43256742904583617,
#   'R2': 0.6440051482672753,
#   'MSPE': 2.133879980937851},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.43546711653470993,
#   'R2': 0.6439794303840654,
#   'MSPE': 2.025867583079621},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.4649044170975685,
#   'R2': 0.6435287559255186,
#   'MSPE': 2.1119563244847637},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.4427178492148717,
#   'R2': 0.6422271711411668,
#   'MSPE': 2.2254691411261307},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.4506145780285199,
#   'R2': 0.6418092491049185,
#   'MSPE': 2.1686837699903982},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.46411734869082777,
#   'R2': 0.6368887945893874,
#   'MSPE': 2.187437328105472},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.4489732826749483,
#   'R2': 0.6366865550007855,
#   'MSPE': 2.1277595091272485},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.4980149259169897,
#   'R2': 0.6355585146768656,
#   'MSPE': 2.388833888213743},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.46613832811514533,
#   'R2': 0.6348694196110137,
#   'MSPE': 2.2201653726097907},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.44941769788662594,
#   'R2': 0.6337630937818353,
#   'MSPE': 2.114677515558221},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.46742291996876395,
#   'R2': 0.6323990909994209,
#   'MSPE': 2.1872074115607476},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.4364707047740618,
#   'R2': 0.6321400487432777,
#   'MSPE': 2.0187845218437492},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.4578500109414259,
#   'R2': 0.6266185102170521,
#   'MSPE': 2.0760968494031466},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.468572657306989,
#   'R2': 0.6247446808654114,
#   'MSPE': 2.1694410694857136},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.48400702476501467,
#   'R2': 0.6232394105932938,
#   'MSPE': 2.461388073485307},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.443372110525767,
#   'R2': 0.6225338647654794,
#   'MSPE': 2.019651011008807},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.4728386849164964,
#   'R2': 0.6221379463713701,
#   'MSPE': 2.0952331374465216},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.46786429112156236,
#   'R2': 0.6181647715314024,
#   'MSPE': 2.1655029155351597},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.45142421176036207,
#   'R2': 0.6169310431575629,
#   'MSPE': 2.046297925966557},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.47914071083068854,
#   'R2': 0.6163197692001285,
#   'MSPE': 2.024127125100355},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.4640102614959082,
#   'R2': 0.6162557592670126,
#   'MSPE': 2.185931319013388},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.48887809664011,
#   'R2': 0.6153755075839517,
#   'MSPE': 2.3327977989207613},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.4832891722520193,
#   'R2': 0.6151800548355093,
#   'MSPE': 2.1462118004759154},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.49242142736911776,
#   'R2': 0.6120496491662999,
#   'MSPE': 2.18935599400088},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.45921894808610286,
#   'R2': 0.6084636472823416,
#   'MSPE': 1.9988431639480169},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.46076300640900925,
#   'R2': 0.6060875221374366,
#   'MSPE': 2.113668727453309},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.4392399311065674,
#   'R2': 0.6055821843266961,
#   'MSPE': 2.0592128434641794},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.5078878919283549,
#   'R2': 0.6040183637035368,
#   'MSPE': 2.5514000737945537},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.46083315064509706,
#   'R2': 0.6007494329158665,
#   'MSPE': 2.2952719620720607},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.47921750545501707,
#   'R2': 0.6005685868736349,
#   'MSPE': 2.389166499629165},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.5318806529045106,
#   'R2': 0.5951668123701207,
#   'MSPE': 2.1290774043235507},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.5152450223763784,
#   'R2': 0.5928702965382141,
#   'MSPE': 2.5138863963498315},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.4907850493987402,
#   'R2': 0.5913712262289431,
#   'MSPE': 2.224238884512975},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.5393525933225949,
#   'R2': 0.588273055687581,
#   'MSPE': 2.52368594143502},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.526440279185772,
#   'R2': 0.5852753992694286,
#   'MSPE': 2.4151616563286744},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.49506877958774564,
#   'R2': 0.5687346445540331,
#   'MSPE': 2.0675078666571416},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.5127624243497848,
#   'R2': 0.5617461839857089,
#   'MSPE': 2.4871655212094383},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.1,
#   'MSE': 0.5170574267705281,
#   'R2': 0.5552597278131688,
#   'MSPE': 2.1458304705888485},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.5979713569084804,
#   'R2': 0.516090689869696,
#   'MSPE': 2.7788161311411494},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.6383176694313685,
#   'R2': 0.505667344858195,
#   'MSPE': 3.1396172223894885},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.6401743710041046,
#   'R2': 0.48419828011086474,
#   'MSPE': 3.0866959273363603},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.651260131597519,
#   'R2': 0.4832859523297851,
#   'MSPE': 3.1233442544636096},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.6404296492536863,
#   'R2': 0.4767817666831136,
#   'MSPE': 3.0997125657670423},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.6448573340972266,
#   'R2': 0.47532429128796094,
#   'MSPE': 3.0808565489044692},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.6461367865403493,
#   'R2': 0.46525027098437227,
#   'MSPE': 3.0153131291194994},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.6045774946610133,
#   'R2': 0.4643595558258887,
#   'MSPE': 3.1740501451522416},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.6376119780043761,
#   'R2': 0.4603702729522248,
#   'MSPE': 2.869903241105453},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.7193225463231405,
#   'R2': 0.4489534675911518,
#   'MSPE': 3.3027543851898775},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.7039451628923417,
#   'R2': 0.4455353120926235,
#   'MSPE': 3.059706519160307},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.6797706047693889,
#   'R2': 0.4391412213102142,
#   'MSPE': 3.0185279180530946},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.7300204289456209,
#   'R2': 0.438777989315515,
#   'MSPE': 3.1923190348151356},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.7239603579044342,
#   'R2': 0.4382065643703739,
#   'MSPE': 3.337574480948123},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.6766906380653381,
#   'R2': 0.43542941607329694,
#   'MSPE': 3.108137726520348},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.6796710560719171,
#   'R2': 0.4321203916826092,
#   'MSPE': 3.0928523857334644},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.6901666929324468,
#   'R2': 0.43037934200042993,
#   'MSPE': 3.288248475603383},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 64,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.7222910275061926,
#   'R2': 0.4259761041341438,
#   'MSPE': 3.250613996966018},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.7627199977636338,
#   'R2': 0.4147614432634409,
#   'MSPE': 3.6834925174186326},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.0001,
#   'momentum': 0.99,
#   'weight_decay': 0.5,
#   'MSE': 0.7685425678888957,
#   'R2': 0.40809469578358054,
#   'MSPE': 3.183243681648464},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.01,
#   'MSE': 0.7147583141922952,
#   'R2': 0.40541643013972334,
#   'MSPE': 3.113880180330439},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.7743170713384947,
#   'R2': 0.400650070050433,
#   'MSPE': 4.075710462650868},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.7912521759668987,
#   'R2': 0.3987547973098255,
#   'MSPE': 3.8021648953659364},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.7858529672026634,
#   'R2': 0.39562178340429,
#   'MSPE': 3.868272131064324},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.8043655316034952,
#   'R2': 0.39369300601591556,
#   'MSPE': 3.5911405447757603},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.8257550845543543,
#   'R2': 0.39262769238721307,
#   'MSPE': 4.082884302908423},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 0.7069946885108948,
#   'R2': 0.3879827206636672,
#   'MSPE': 3.7025027731997953},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.7752914746602377,
#   'R2': 0.38287378121696225,
#   'MSPE': 3.5340964049100876},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 1e-05,
#   'MSE': 0.7885004848241806,
#   'R2': 0.3798449268173054,
#   'MSPE': 3.8299546059634957},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.785241142908732,
#   'R2': 0.3772908899367525,
#   'MSPE': 3.230452584384969},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.8135547637939453,
#   'R2': 0.37250109728594555,
#   'MSPE': 3.7365031296932933},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.7295434584220251,
#   'R2': 0.3718111406441908,
#   'MSPE': 3.370985601925187},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.7754119038581848,
#   'R2': 0.36991984137007344,
#   'MSPE': 3.8934521401545625},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.7762346367041271,
#   'R2': 0.36884236481885585,
#   'MSPE': 3.570074255418296},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.8465916951497394,
#   'R2': 0.36314810038551004,
#   'MSPE': 4.401083561507138},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 0.8319656898578007,
#   'R2': 0.3600353232710037,
#   'MSPE': 3.9115263467108967},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.8051259701450666,
#   'R2': 0.3563482518215214,
#   'MSPE': 3.9154331762381274},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.7843132515748342,
#   'R2': 0.3523899988355199,
#   'MSPE': 3.682336323527676},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.8004551142454147,
#   'R2': 0.3515958457261288,
#   'MSPE': 3.6913879522395256},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 32,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.7702844272057214,
#   'R2': 0.3461947569902436,
#   'MSPE': 3.727453425338472},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.830386303861936,
#   'R2': 0.3321341329537864,
#   'MSPE': 3.6741405386816366},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.7815490424633026,
#   'R2': 0.3228537893713919,
#   'MSPE': 3.508979133377322},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.860820072889328,
#   'R2': 0.31895236682879047,
#   'MSPE': 3.8404637046459342},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 0.8802626033624014,
#   'R2': 0.3184082672783092,
#   'MSPE': 4.360958721977894},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 0.8153032312790552,
#   'R2': 0.31767458212283356,
#   'MSPE': 3.787856078847791},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.8267142375310261,
#   'R2': 0.29021872398232135,
#   'MSPE': 3.8419193637115177},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 0.8723186453183492,
#   'R2': 0.28947881969586914,
#   'MSPE': 4.106247493752627},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.001,
#   'MSE': 0.9288565476735433,
#   'R2': 0.2661623061043307,
#   'MSPE': 4.407254293410465},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 16,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.0001,
#   'MSE': 0.9076090534528095,
#   'R2': 0.24994153548766831,
#   'MSPE': 3.938371169973503},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 0.9351383745670319,
#   'R2': 0.22772972443267858,
#   'MSPE': 4.246546307371721},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 0.001,
#   'momentum': 0.99,
#   'weight_decay': 0.001,
#   'MSE': 1.2316417346398034,
#   'R2': 0.04612934681488044,
#   'MSPE': 5.794474756947219},
#  {'num_hidden_layers': 1,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 1e-05,
#   'MSE': 1.506544715166092,
#   'R2': -0.10082205577140044,
#   'MSPE': 5.32199385321953},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.0001,
#   'MSE': 1.5909140398104988,
#   'R2': -0.2957832406634227,
#   'MSPE': 5.727947088090157},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.01,
#   'MSE': 1.7476111729939778,
#   'R2': -0.42795251114875177,
#   'MSPE': 6.7951512468433135},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.1,
#   'MSE': 1.6786820769309998,
#   'R2': -0.4668385707717097,
#   'MSPE': 6.1665751435088385},
#  {'num_hidden_layers': 2,
#   'num_nodes_per_layer': 8,
#   'lr': 1e-05,
#   'momentum': 0.9,
#   'weight_decay': 0.5,
#   'MSE': 1.751923614740372,
#   'R2': -0.49006174760724086,
#   'MSPE': 6.138147420127585}]

# %% [markdown]
# As we can see the best parameters is 2 hidden layers with 64 nodes and a learning rate of 1e-3, a momentum of 0.9, and a weight decay of 1e-5.

# %%
train_dataset = DataLoader(TensorDataset(torch.Tensor(x_train), torch.Tensor(y_train)), batch_size=64, shuffle=True)
test_dataset = DataLoader(TensorDataset(torch.Tensor(x_test), torch.Tensor(y_test)), batch_size=64, shuffle=True)
best_model = NeuralNetwork(len(x_train[0]), 2, 64)
train_loop(train_dataset, best_model, lr=1e-3, momentum=0.9, weight_decay=1e-5, early_stopping=25)
result = {
    "MSE": [],
    "R2": [],
    "MSPE": []
}
test_loop(test_dataset, best_model, result)
print(f"MSE: {result['MSE']}")
print(f"R2: {result['R2']}")
print(f"MSPE: {result['MSPE']}")
# Out:
# MSE: [0.2698853512605031]
# R2: [0.7858209999660349]
# MSPE: [1.2194186676707532]

# %% [markdown]
# Another option is 1 layer 32 nodes, a learning rate of 1e-4, a momentum of 0.99 and a weight decay of 1e-5

# %%
train_dataset = DataLoader(TensorDataset(torch.Tensor(x_train), torch.Tensor(y_train)), batch_size=64, shuffle=True)
test_dataset = DataLoader(TensorDataset(torch.Tensor(x_test), torch.Tensor(y_test)), batch_size=64, shuffle=True)
best_model = NeuralNetwork(len(x_train[0]), 1, 32)
train_loop(train_dataset, best_model, lr=1e-4, momentum=0.99, weight_decay=1e-5, early_stopping=25)
result = {
    "MSE": [],
    "R2": [],
    "MSPE": []
}
test_loop(test_dataset, best_model, result)
print(f"MSE: {result['MSE']}")
print(f"R2: {result['R2']}")
print(f"MSPE: {result['MSPE']}")
# Out:
# MSE: [0.29371871054172516]
# R2: [0.7681177284800315]
# MSPE: [1.3682486178974311]
